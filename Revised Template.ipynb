# %%
# Creator: JID Espenorio
# Requestor: Data Analyst - Autodist
# Created: July 9, 2024


import pandas as pd

# Define a class for the Autodistribution template
class Autodist_temp:
    def __init__(self, make, model, year, mpn, sku, position, pro_type, vendor, vendorcode, vendornotes):
        self.make = make
        self.model = model
        self.year = year
        self.mpn = mpn
        self.sku = sku
        self.position = position
        self.pro_type = pro_type
        self.vendor = vendor
        self.vendorcode = vendorcode
        self.vendornotes = vendornotes
        
    def to_dict(self):
        return {
            'Make': self.make,
            'Model': self.model,
            'Vendor': self.vendor,
            'Vendor Code': self.vendorcode,
            'Product Type': self.pro_type,
            'Position': self.position,
            'SKU': self.sku,
            'MPN': self.mpn,
            'Year': self.year,
            'Vendor Notes': self.vendornotes
        }

# %%
# Define a class for generating Autodistribution data
class AutodistGenerator:
    def __init__(self, autodist_template, list_models, years):
        self.autodist_template = autodist_template
        self.list_models = list_models
        self.years = years
    
    def generate_autodist(self):
        data = []
        for model in self.list_models:
            for year in self.years:
                autodist_data = {
                    'Make': self.autodist_template.make,
                    'Model': model,
                    'Year': year,
                    'Vendor': self.autodist_template.vendor,
                    'Vendor Code': self.autodist_template.vendorcode,
                    'Position': self.autodist_template.position,
                    'MPN': self.autodist_template.mpn,
                    'SKU': self.autodist_template.sku,
                    'Product Type': self.autodist_template.pro_type,
                    'Vendor Notes': self.autodist_template.vendornotes,
                }
                data.append(autodist_data)
        return pd.DataFrame(data)

# %%
# Create an instance of Autodist_temp for the template
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-311',
    sku='236401',
    pro_type='FAN BELT',
    vendornotes='SIZE: 10 X 535 (13L X 21)'
)

# List of specific models for which autodistribution data will be generated
list_models = [
    'Expedition 550F Sport', 
    'Expedition Sport 550F', 
    'Freestyle Back Country 550F',
]

# Range of years for which autodistribution data will be generated
years = list(range(1980, 2023))

# Create an instance of AutodistGenerator using the template, models, and years
generator = AutodistGenerator(autodist_template, list_models, years)

# Generate autodistribution data and store it in final_df
final_df = generator.generate_autodist()

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#            Make                        Model  Year Vendor Vendor Code  \
# 0    Arctic Cat        Expedition 550F Sport  1980
# 1    Arctic Cat        Expedition 550F Sport  1981
# 2    Arctic Cat        Expedition 550F Sport  1982
# 3    Arctic Cat        Expedition 550F Sport  1983
# 4    Arctic Cat        Expedition 550F Sport  1984
# ..          ...                          ...   ...    ...         ...
# 124  Arctic Cat  Freestyle Back Country 550F  2018
# 125  Arctic Cat  Freestyle Back Country 550F  2019
# 126  Arctic Cat  Freestyle Back Country 550F  2020
# 127  Arctic Cat  Freestyle Back Country 550F  2021
# 128  Arctic Cat  Freestyle Back Country 550F  2022
#
#     Position     MPN     SKU Product Type               Vendor Notes
# 0             09-311  236401     FAN BELT  SIZE: 10 X 535 (13L X 21)
# 1             09-311  236401     FAN BELT  SIZE: 10 X 535 (13L X 21)
# 2             09-311  236401     FAN BELT  SIZE: 10 X 535 (13L X 21)
# ...

# %%
# Create an instance of Autodist_temp for the template
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09452',
    sku='127976',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM# 420834355'
)

# List of specific models for which autodistribution data will be generated
list_models = [
    'Expedition LE E-TEC 600R', 
    'Expedition SE E-TEC 600 HO', 
    'Expedition SE E-TEC 600R', 
    'Expedition LE E-TEC 600 HO', 
    'Formula Deluxe 500', 
    'Formula Deluxe 500 Fan', 
    'Formula Deluxe 500 LC', 
    'Formula Deluxe 600', 
    'Formula Deluxe 600 GSE', 
    'Formula Deluxe 700', 
    'Formula Deluxe 700 GS', 
    'Formula Deluxe 700 GSE', 
    'Grand Touring 500', 
    'Grand Touring 500 Fan', 
    'Grand Touring 500 Sport', 
    'Grand Touring 550 Fan', 
    'Grand Touring 550F Sport', 
    'Grand Touring 600', 
    'Grand Touring 600 GS', 
    'Grand Touring 600 LE', 
    'Grand Touring 600 SE', 
    'Grand Touring 600 Sport', 
    'Grand Touring 700', 
    'Grand Touring 700 GS', 
    'Grand Touring 700 SE', 
    'Grand Touring 700 Sport', 
    'Grand Touring 800 SE', 
    'Grand Touring LE E-TEC 600 HO', 
    'GTX 600', 
    'GTX 600 Limited', 
    'GTX 600 Sport', 
    'GTX 800', 
    'GTX 800 Limited', 
    'Legend 500 Fan', 
    'Legend 500 Sport', 
    'Legend 600 GS', 
    'Legend 600 SE', 
    'Legend 600 Sport', 
    'Legend 700 GS', 
    'Legend 700 SE', 
    'Legend 700 Sport', 
    'Legend 800 SE', 
    'Legend 800 SE SDI', 
    'MX Z 500', 
    'MX Z 500 Adrenaline', 
    'MX Z 500 Fan', 
    'MX Z 500 R Sport', 
    'MX Z 500 R Trail', 
    'MX Z 500 Renegade', 
    'MX Z 500 Sport', 
    'MX Z 500 TNT', 
    'MX Z 500 Trail', 
    'MX Z 500 X', 
    'MX Z 600', 
    'MX Z 600 50th Anniversary', 
    'MX Z 600 Adrenaline', 
    'MX Z 600 Blizzard', 
    'MX Z 600 R Sport', 
    'MX Z 600 R X', 
    'MX Z 600 Renegade', 
    'MX Z 600 Renegade X', 
    'MX Z 600 Sport', 
    'MX Z 600 TNT', 
    'MX Z 600 TNT Early Edition', 
    'MX Z 600 Trail', 
    'MX Z 600 X', 
    'MX Z 600 X-RS', 
    'MX Z 600RS', 
    'MX Z 700', 
    'MX Z 700 Adrenaline', 
    'MX Z 700 R Sport', 
    'MX Z 700 R X', 
    'MX Z 700 Renegade', 
    'MX Z 700 Sport', 
    'MX Z 700 Trail', 
    'MX Z 700 X', 
    'MX Z 800', 
    'MX Z 800 Adrenaline', 
    'MX Z 800 Blizzard', 
    'MX Z 800 R', 
    'MX Z 800 R Adrenaline', 
    'MX Z 800 R Sport', 
    'MX Z 800 R X', 
    'MX Z 800 Renegade', 
    'MX Z 800 Renegade X', 
    'MX Z 800 Sport', 
    'MX Z 800 Trail', 
    'MX Z 800 X', 
    'MX Z 800 X-RS', 
    'MX Z 800R Renegade', 
    'MX Z 800R Renegade X', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT 800R Power TEC', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z TNT E-TEC 600R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X E-TEC 600R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS 600', 
    'MX Z X-RS 800R', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600R', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600R', 
    'Renegade X E-TEC 600 HO', 
    'Renegade X E-TEC 600R', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit SP E-TEC 600R 146', 
    'Summit SP E-TEC 600R 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 
    'Skandic 600 SUV', 
    'Summit 600', 
    'Summit 600 Adrenaline', 
    'Summit 600 Everest', 
    'Summit 600 Everest 146', 
    'Summit 600 R Sport', 
    'Summit 600 Sport', 
    'Summit 600 X', 
    'Summit 600 X 154', 
    'Summit 670 X', 
    'Summit 700', 
    'Summit 700 Adrenaline', 
    'Summit 700 Highmark', 
    'Summit 700 R Sport', 
    'Summit 700 Sport', 
    'Summit 700 X', 
    'Summit 800', 
    'Summit 800 Adrenaline 144', 
    'Summit 800 Adrenaline 151', 
    'Summit 800 Everest 146', 
    'Summit 800 Everest 154', 
    'Summit 800 Everest 163', 
    'Summit 800 Foothill', 
    'Summit 800 Highmark', 
    'Summit 800 Highmark X', 
    'Summit 800 Highmark Xtreme', 
    'Summit 800 Hill Climb', 
    'Summit 800 R 50th Anniversary', 
    'Summit 800 R Everest', 
    'Summit 800 R Highmark', 
    'Summit 800 R Highmark X', 
    'Summit 800 R Sport', 
    'Summit 800 R X', 
    'Summit 800 Sport', 
    'Summit 800 X', 
    'Summit 800 X 144', 
    'Summit 800 X 146', 
    'Summit 800 X 151', 
    'Summit 800 X 154', 
    'Summit 800 X 159', 
    'Summit 800 X 163', 
    'Summit 800 XRS 151', 
    'Summit 800 XRS 159', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit Sport Power TEK 800R', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 

]

# Range of years for which autodistribution data will be generated
years = list(range(1999, 2021))

# Create an instance of AutodistGenerator using the template, models, and years
generator = AutodistGenerator(autodist_template, list_models, years)

# Generate autodistribution data and store it in final_df
final_df = generator.generate_autodist()

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#          Make                     Model  Year Vendor Vendor Code Position  \
# 0     Ski-Doo  Expedition LE E-TEC 600R  1999
# 1     Ski-Doo  Expedition LE E-TEC 600R  2000
# 2     Ski-Doo  Expedition LE E-TEC 600R  2001
# 3     Ski-Doo  Expedition LE E-TEC 600R  2002
# 4     Ski-Doo  Expedition LE E-TEC 600R  2003
# ...       ...                       ...   ...    ...         ...      ...
# 3955  Ski-Doo   Summit X E-TEC 800R 174  2016
# 3956  Ski-Doo   Summit X E-TEC 800R 174  2017
# 3957  Ski-Doo   Summit X E-TEC 800R 174  2018
# 3958  Ski-Doo   Summit X E-TEC 800R 174  2019
# 3959  Ski-Doo   Summit X E-TEC 800R 174  2020
#
#            MPN     SKU          Product Type    Vendor Notes
# 0     SM-09452  127976  Oil Pump Drive Gears  OEM# 420834355
# 1     SM-09452  127976  Oil Pump Drive Gears  OEM# 420834355
# 2     SM-09452  127976  Oil Pump Drive Gears  OEM# 420834355
# 3     SM-09452  127976  Oil Pump Drive Gears  OEM# 420834355
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(09)SECTION 09 - OIL PUMP DRIVE GEARS ( 06-28-23 )\Merge Template 3\SM-09452.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09255',
    sku='127199',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM# 3007-885'
)

list_models = [
    'Crossfire 800 EFI', 
    'Crossfire 800 EFI Limited', 
    'Crossfire 800 EFI Sno Pro', 
    'Crossfire R 8', 
    'Crossfire R 8 LE', 
    'F8 EFI', 
    'F8 EFI LXR', 
    'F8 EFI Sno Pro', 
    'F8 EXT', 
    'F8 Sno Pro Limited', 
    'ProCross F 800 LXR', 
    'ProCross F 800 Sno Pro', 
    'ProCross F 800 Sno Pro Limited', 
    'ProCross F 800 Sno Pro RR', 
    'ProCross F 800 Tucker Hibbert Race Replica', 
    'M 8000 153', 
    'M 8000 David McClure SE', 
    'M 8000 HCR 153', 
    'M 8000 Limited 153', 
    'M 8000 Limited 162', 
    'M 8000 Limited ES 153', 
    'M 8000 Limited ES 162', 
    'M 8000 Mountain Cat 153', 
    'M 8000 Mountain Cat 162', 
    'M 8000 Mountain Cat ES 153', 
    'M 8000 Mountain Cat ES 162', 
    'M 8000 Rob Kincaid SE', 
    'M 8000 SE 141', 
    'M 8000 SE 153', 
    'M 8000 SE ES 153', 
    'M 8000 SE ES 162', 
    'M8 153', 
    'M8 153 Limited', 
    'M8 162', 
    'M8 EFI 153', 
    'M8 EFI 153 Sno Pro', 
    'M8 EFI 162', 
    'M8 EFI 162 Sno Pro', 
    'M8 HCR 153', 
    'M8 Sno Pro 153', 
    'M8 Sno Pro 162', 
    'ProClimb XF 800 Sno Pro High Country', 
    'ProClimb XF 800 Sno Pro High Country Ltd', 
    'ProCross XF 800 Crosstour', 
    'ProCross XF 800 LXR', 
    'ProCross XF 800 Sno Pro', 
    'ProCross XF 800 Sno Pro Limited', 
    'XF 8000 Cross Country', 
    'XF 8000 Cross Country Limited', 
    'XF 8000 Cross Country Limited ES', 
    'XF 8000 Cross Country Sno Pro', 
    'XF 8000 Crosstour', 
    'XF 8000 Crosstrek', 
    'XF 8000 Crosstrek ES', 
    'XF 8000 High Country', 
    'XF 8000 High Country Limited', 
    'XF 8000 High Country Limited ES 141', 
    'XF 8000 High Country Limited ES 153', 
    'XF 8000 High Country Sno Pro', 
    'XF 8000 Limited', 
    'XF 8000 LXR', 
    'XF 8000 Sno Pro', 
    'ZR 8000 El Tigre', 
    'ZR 8000 El Tigre ES 129', 
    'ZR 8000 El Tigre ES 137', 
    'ZR 8000 Limited 129', 
    'ZR 8000 Limited 137', 
    'ZR 8000 Limited ES 129', 
    'ZR 8000 Limited ES 137', 
    'ZR 8000 LXR 129', 
    'ZR 8000 LXR 137', 
    'ZR 8000 LXR ES 129', 
    'ZR 8000 LXR ES 137', 
    'ZR 8000 RR', 
    'ZR 8000 RR ES 129', 
    'ZR 8000 RR ES 137', 
    'ZR 8000 Sno Pro 129', 
    'ZR 8000 Sno Pro 137', 
    'ZR 8000 Sno Pro ES 129', 
    'ZR 8000 Sno Pro ES 137', 




   


]

years = list(range(2010, 2018))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#            Make                   Model  Year Vendor Vendor Code Position  \
# 0    Arctic Cat       Crossfire 800 EFI  2010
# 1    Arctic Cat       Crossfire 800 EFI  2011
# 2    Arctic Cat       Crossfire 800 EFI  2012
# 3    Arctic Cat       Crossfire 800 EFI  2013
# 4    Arctic Cat       Crossfire 800 EFI  2014
# ..          ...                     ...   ...    ...         ...      ...
# 635  Arctic Cat  ZR 8000 Sno Pro ES 137  2013
# 636  Arctic Cat  ZR 8000 Sno Pro ES 137  2014
# 637  Arctic Cat  ZR 8000 Sno Pro ES 137  2015
# 638  Arctic Cat  ZR 8000 Sno Pro ES 137  2016
# 639  Arctic Cat  ZR 8000 Sno Pro ES 137  2017
#
#           MPN     SKU          Product Type   Vendor Notes
# 0    SM-09255  127199  Oil Pump Drive Gears  OEM# 3007-885
# 1    SM-09255  127199  Oil Pump Drive Gears  OEM# 3007-885
# 2    SM-09255  127199  Oil Pump Drive Gears  OEM# 3007-885
# 3    SM-09255  127199  Oil Pump Drive Gears  OEM# 3007-885
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(09)SECTION 09 - OIL PUMP DRIVE GEARS ( 06-28-23 )\Merge Template 3\SM-09255.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09453',
    sku='129154',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM# 0905-041; 7 TEETH'
)

list_models = [
    
    'M 8000 153', 
    'M 8000 David McClure SE', 
    'M 8000 HCR 153', 
    'M 8000 Limited 153', 
    'M 8000 Limited 162', 
    'M 8000 Limited ES 153', 
    'M 8000 Limited ES 162', 
    'M 8000 Mountain Cat 153', 
    'M 8000 Mountain Cat 162', 
    'M 8000 Mountain Cat ES 153', 
    'M 8000 Mountain Cat ES 162', 
    'M 8000 Rob Kincaid SE', 
    'M 8000 SE 141', 
    'M 8000 SE 153', 
    'M 8000 SE ES 153', 
    'M 8000 SE ES 162', 
    'M8 153', 
    'M8 153 Limited', 
    'M8 162', 
    'M8 EFI 153', 
    'M8 EFI 153 Sno Pro', 
    'M8 EFI 162', 
    'M8 EFI 162 Sno Pro', 
    'M8 HCR 153', 
    'M8 Sno Pro 153', 
    'M8 Sno Pro 162', 
    'ProClimb XF 800 Sno Pro High Country', 
    'ProClimb XF 800 Sno Pro High Country Ltd', 
    'ProCross XF 800 Crosstour', 
    'ProCross XF 800 LXR', 
    'ProCross XF 800 Sno Pro', 
    'ProCross XF 800 Sno Pro Limited', 
    'XF 8000 Cross Country', 
    'XF 8000 Cross Country Limited', 
    'XF 8000 Cross Country Limited ES', 
    'XF 8000 Cross Country Sno Pro', 
    'XF 8000 Crosstour', 
    'XF 8000 Crosstrek', 
    'XF 8000 Crosstrek ES', 
    'XF 8000 High Country', 
    'XF 8000 High Country Limited', 
    'XF 8000 High Country Limited ES 141', 
    'XF 8000 High Country Limited ES 153', 
    'XF 8000 High Country Sno Pro', 
    'XF 8000 Limited', 
    'XF 8000 LXR', 
    'XF 8000 Sno Pro', 
    'ZR 8000 El Tigre', 
    'ZR 8000 El Tigre ES 129', 
    'ZR 8000 El Tigre ES 137', 
    'ZR 8000 Limited 129', 
    'ZR 8000 Limited 137', 
    'ZR 8000 Limited ES 129', 
    'ZR 8000 Limited ES 137', 
    'ZR 8000 LXR 129', 
    'ZR 8000 LXR 137', 
    'ZR 8000 LXR ES 129', 
    'ZR 8000 LXR ES 137', 
    'ZR 8000 RR', 
    'ZR 8000 RR ES 129', 
    'ZR 8000 RR ES 137', 
    'ZR 8000 Sno Pro 129', 
    'ZR 8000 Sno Pro 137', 
    'ZR 8000 Sno Pro ES 129', 
    'ZR 8000 Sno Pro ES 137', 
    'Expedition LE E-TEC 600R', 
    'Expedition SE E-TEC 600 HO', 
    'Expedition SE E-TEC 600R', 
    'Expedition LE E-TEC 600 HO', 
    'Formula Deluxe 500', 
    'Formula Deluxe 500 Fan', 
    'Formula Deluxe 500 LC', 
    'Formula Deluxe 600', 
    'Formula Deluxe 600 GSE', 
    'Formula Deluxe 700', 
    'Formula Deluxe 700 GS', 
    'Formula Deluxe 700 GSE', 
    'Grand Touring 500', 
    'Grand Touring 500 Fan', 
    'Grand Touring 500 Sport', 
    'Grand Touring 550 Fan', 
    'Grand Touring 550F Sport', 
    'Grand Touring 600', 
    'Grand Touring 600 GS', 
    'Grand Touring 600 LE', 
    'Grand Touring 600 SE', 
    'Grand Touring 600 Sport', 
    'Grand Touring 700', 
    'Grand Touring 700 GS', 
    'Grand Touring 700 SE', 
    'Grand Touring 700 Sport', 
    'Grand Touring 800 SE', 
    'Grand Touring LE E-TEC 600 HO', 
    'GTX 600', 
    'GTX 600 Limited', 
    'GTX 600 Sport', 
    'GTX 800', 
    'GTX 800 Limited', 
    'Legend 500 Fan', 
    'Legend 500 Sport', 
    'Legend 600 GS', 
    'Legend 600 SE', 
    'Legend 600 Sport', 
    'Legend 700 GS', 
    'Legend 700 SE', 
    'Legend 700 Sport', 
    'Legend 800 SE', 
    'Legend 800 SE SDI', 
    'MX Z 500', 
    'MX Z 500 Adrenaline', 
    'MX Z 500 Fan', 
    'MX Z 500 R Sport', 
    'MX Z 500 R Trail', 
    'MX Z 500 Renegade', 
    'MX Z 500 Sport', 
    'MX Z 500 TNT', 
    'MX Z 500 Trail', 
    'MX Z 500 X', 
    'MX Z 600', 
    'MX Z 600 50th Anniversary', 
    'MX Z 600 Adrenaline', 
    'MX Z 600 Blizzard', 
    'MX Z 600 R Sport', 
    'MX Z 600 R X', 
    'MX Z 600 Renegade', 
    'MX Z 600 Renegade X', 
    'MX Z 600 Sport', 
    'MX Z 600 TNT', 
    'MX Z 600 TNT Early Edition', 
    'MX Z 600 Trail', 
    'MX Z 600 X', 
    'MX Z 600 X-RS', 
    'MX Z 600RS', 
    'MX Z 700', 
    'MX Z 700 Adrenaline', 
    'MX Z 700 R Sport', 
    'MX Z 700 R X', 
    'MX Z 700 Renegade', 
    'MX Z 700 Sport', 
    'MX Z 700 Trail', 
    'MX Z 700 X', 
    'MX Z 800', 
    'MX Z 800 Adrenaline', 
    'MX Z 800 Blizzard', 
    'MX Z 800 R', 
    'MX Z 800 R Adrenaline', 
    'MX Z 800 R Sport', 
    'MX Z 800 R X', 
    'MX Z 800 Renegade', 
    'MX Z 800 Renegade X', 
    'MX Z 800 Sport', 
    'MX Z 800 Trail', 
    'MX Z 800 X', 
    'MX Z 800 X-RS', 
    'MX Z 800R Renegade', 
    'MX Z 800R Renegade X', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT 800R Power TEC', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z TNT E-TEC 600R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X E-TEC 600R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS 600', 
    'MX Z X-RS 800R', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600R', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600R', 
    'Renegade X E-TEC 600 HO', 
    'Renegade X E-TEC 600R', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit SP E-TEC 600R 146', 
    'Summit SP E-TEC 600R 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 
    'Skandic 600 SUV', 
    'Summit 600', 
    'Summit 600 Adrenaline', 
    'Summit 600 Everest', 
    'Summit 600 Everest 146', 
    'Summit 600 R Sport', 
    'Summit 600 Sport', 
    'Summit 600 X', 
    'Summit 600 X 154', 
    'Summit 670 X', 
    'Summit 700', 
    'Summit 700 Adrenaline', 
    'Summit 700 Highmark', 
    'Summit 700 R Sport', 
    'Summit 700 Sport', 
    'Summit 700 X', 
    'Summit 800', 
    'Summit 800 Adrenaline 144', 
    'Summit 800 Adrenaline 151', 
    'Summit 800 Everest 146', 
    'Summit 800 Everest 154', 
    'Summit 800 Everest 163', 
    'Summit 800 Foothill', 
    'Summit 800 Highmark', 
    'Summit 800 Highmark X', 
    'Summit 800 Highmark Xtreme', 
    'Summit 800 Hill Climb', 
    'Summit 800 R 50th Anniversary', 
    'Summit 800 R Everest', 
    'Summit 800 R Highmark', 
    'Summit 800 R Highmark X', 
    'Summit 800 R Sport', 
    'Summit 800 R X', 
    'Summit 800 Sport', 
    'Summit 800 X', 
    'Summit 800 X 144', 
    'Summit 800 X 146', 
    'Summit 800 X 151', 
    'Summit 800 X 154', 
    'Summit 800 X 159', 
    'Summit 800 X 163', 
    'Summit 800 XRS 151', 
    'Summit 800 XRS 159', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit Sport Power TEK 800R', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'M 600 Alpha One 154 2.6in.', 
    'M 600 Alpha One 154 3.0in.', 
    'M 600 Alpha One ES 146', 
    'M 600 Alpha One ES 154 2.6in.', 
    'M 600 Alpha One ES 154 3.0in.', 
    'M 6000 141', 
    'M 6000 153', 
    'M 6000 ES 153', 
    'M 6000 Limited 153', 
    'M 6000 SE 141', 
    'M 6000 SE 153', 
    'M 6000 SE ES 141', 
    'M 6000 SE ES 153', 
    'M 6000 Sno Pro 141', 
    'M 6000 Sno Pro 153', 
    'M 6000 Sno Pro ES 153', 
    'Norseman 6000 ES', 
    'Norseman X 6000', 
    'Norseman X 8000', 
    'Pantera 6000 ES', 
    'Riot 600 1.6in.', 
    'Riot 600 1.75in.', 
    'Riot 600 ATAC 1.6in.', 
    'Riot 600 ATAC 1.75in.', 
    'Riot 6000', 
    'Riot 6000 1.35in.', 
    'Riot 8000', 
    'Riot 8000 1.35in.', 
    'Riot 8000 1.6in.', 
    'Riot 8000 ATAC', 
    'Riot 8000 ATAC 1.6in.', 
    'Riot X 8000', 
    'Riot X 8000 ATAC', 
    'XF 6000 Cross Country', 
    'XF 6000 Cross Country Limited ES', 
    'XF 6000 Crosstour', 
    'XF 6000 Crosstour ES', 
    'XF 6000 Crosstrek', 
    'XF 6000 Crosstrek ES', 
    'XF 6000 High Country', 
    'XF 6000 High Country ES', 
    'XF 6000 High Country Limited ES', 
    'XF 6000 Limited', 
    'XF 6000 LXR', 
    'XF 6000 Sno Pro', 
    'ZR 600 ATAC ES 129', 
    'ZR 600 ATAC ES 137', 
    'ZR 600 ES 129', 
    'ZR 600 ES 137', 
    'ZR 600 R-XC', 
    'ZR 600 R-XC ES', 
    'ZR 6000', 
    'ZR 6000 El Tigre', 
    'ZR 6000 El Tigre ES', 
    'ZR 6000 El Tigre ES 129', 
    'ZR 6000 El Tigre ES 137', 
    'ZR 6000 ES 129', 
    'ZR 6000 ES 137', 
    'ZR 6000 Limited 129', 
    'ZR 6000 Limited 137', 
    'ZR 6000 Limited ES 129', 
    'ZR 6000 Limited ES 129 iACT', 
    'ZR 6000 Limited ES 137', 
    'ZR 6000 Limited ES 137 iACT', 
    'ZR 6000 Limited ES ATAC 137', 
    'ZR 6000 LXR 129', 
    'ZR 6000 LXR 137', 
    'ZR 6000 LXR ES 129', 
    'ZR 6000 LXR ES 137', 
    'ZR 6000 R-XC', 
    'ZR 6000 R-XC ES', 
    'ZR 6000 R XC', 
    'ZR 6000 R XC 129', 
    'ZR 6000 RR', 
    'ZR 6000 RR ES 129', 
    'ZR 6000 RR ES 137', 
    'ZR 6000 RS', 
    'ZR 6000 Sno Pro 129', 
    'ZR 6000 Sno Pro 137', 
    'ZR 6000 Sno Pro ES 129', 
    'ZR 6000 Sno Pro ES 137', 
    'ZR 6000 Tucker Hibbert RR', 



   


]

years = list(range(2014, 2025))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#             Make                      Model  Year Vendor Vendor Code Position  \
# 0     Arctic Cat                 M 8000 153  2014
# 1     Arctic Cat                 M 8000 153  2015
# 2     Arctic Cat                 M 8000 153  2016
# 3     Arctic Cat                 M 8000 153  2017
# 4     Arctic Cat                 M 8000 153  2018
# ...          ...                        ...   ...    ...         ...      ...
# 3592  Arctic Cat  ZR 6000 Tucker Hibbert RR  2020
# 3593  Arctic Cat  ZR 6000 Tucker Hibbert RR  2021
# 3594  Arctic Cat  ZR 6000 Tucker Hibbert RR  2022
# 3595  Arctic Cat  ZR 6000 Tucker Hibbert RR  2023
# 3596  Arctic Cat  ZR 6000 Tucker Hibbert RR  2024
#
#            MPN     SKU          Product Type            Vendor Notes
# 0     SM-09453  129154  Oil Pump Drive Gears  OEM# 0905-041; 7 TEETH
# 1     SM-09453  129154  Oil Pump Drive Gears  OEM# 0905-041; 7 TEETH
# 2     SM-09453  129154  Oil Pump Drive Gears  OEM# 0905-041; 7 TEETH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(09)SECTION 09 - OIL PUMP DRIVE GEARS ( 06-28-23 )\Merge Template 3\SM-09453.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='PTO SIDE',
    mpn='SM-09188-4A',
    sku='127354',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; CRANK WEB O.D. 120MM; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM; NUT:M22 X PITCH 1.5; DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'GSX SE E-TEC 800R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade X E-TEC 800R', 
    'Renegade X-RS E-TEC 800R', 
    'Summit Burton E-TEC 800R', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                        Model  Year Vendor Vendor Code  Position  \
# 0    Ski-Doo      Freeride E-TEC 800R 137  2009                     PTO SIDE
# 1    Ski-Doo      Freeride E-TEC 800R 137  2010                     PTO SIDE
# 2    Ski-Doo      Freeride E-TEC 800R 137  2011                     PTO SIDE
# 3    Ski-Doo      Freeride E-TEC 800R 137  2012                     PTO SIDE
# 4    Ski-Doo      Freeride E-TEC 800R 137  2013                     PTO SIDE
# ..       ...                          ...   ...    ...         ...       ...
# 413  Ski-Doo  Summit Sport Power TEK 800R  2015                     PTO SIDE
# 414  Ski-Doo  Summit Sport Power TEK 800R  2016                     PTO SIDE
# 415  Ski-Doo  Summit Sport Power TEK 800R  2017                     PTO SIDE
# 416  Ski-Doo  Summit Sport Power TEK 800R  2018                     PTO SIDE
# 417  Ski-Doo  Summit Sport Power TEK 800R  2019                     PTO SIDE
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09188-4A.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAG SIDE',
    mpn='SM-09188-5A',
    sku='125347',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; CRANK WEB O.D. 120MM; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM; NUT:M22 X PITCH 1.5; DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'GSX SE E-TEC 800R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade X E-TEC 800R', 
    'Renegade X-RS E-TEC 800R', 
    'Summit Burton E-TEC 800R', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                        Model  Year Vendor Vendor Code  Position  \
# 0    Ski-Doo      Freeride E-TEC 800R 137  2009                     MAG SIDE
# 1    Ski-Doo      Freeride E-TEC 800R 137  2010                     MAG SIDE
# 2    Ski-Doo      Freeride E-TEC 800R 137  2011                     MAG SIDE
# 3    Ski-Doo      Freeride E-TEC 800R 137  2012                     MAG SIDE
# 4    Ski-Doo      Freeride E-TEC 800R 137  2013                     MAG SIDE
# ..       ...                          ...   ...    ...         ...       ...
# 413  Ski-Doo  Summit Sport Power TEK 800R  2015                     MAG SIDE
# 414  Ski-Doo  Summit Sport Power TEK 800R  2016                     MAG SIDE
# 415  Ski-Doo  Summit Sport Power TEK 800R  2017                     MAG SIDE
# 416  Ski-Doo  Summit Sport Power TEK 800R  2018                     MAG SIDE
# 417  Ski-Doo  Summit Sport Power TEK 800R  2019                     MAG SIDE
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09188-5A.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='PTO SIDE',
    mpn='SM-09374',
    sku='125325',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 


   



   


]

years = list(range(2004, 2021))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code  Position  \
# 0    Ski-Doo  Expedition SE E-TEC 600 HO  2004                     PTO SIDE
# 1    Ski-Doo  Expedition SE E-TEC 600 HO  2005                     PTO SIDE
# 2    Ski-Doo  Expedition SE E-TEC 600 HO  2006                     PTO SIDE
# 3    Ski-Doo  Expedition SE E-TEC 600 HO  2007                     PTO SIDE
# 4    Ski-Doo  Expedition SE E-TEC 600 HO  2008                     PTO SIDE
# ..       ...                         ...   ...    ...         ...       ...
# 352  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2016                     PTO SIDE
# 353  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2017                     PTO SIDE
# 354  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2018                     PTO SIDE
# 355  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2019                     PTO SIDE
# 356  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2020                     PTO SIDE
#
#           MPN     SKU          Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09374.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAG SIDE',
    mpn='SM-09375',
    sku='125326',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 


   



   


]

years = list(range(2004, 2021))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code  Position  \
# 0    Ski-Doo  Expedition SE E-TEC 600 HO  2004                     MAG SIDE
# 1    Ski-Doo  Expedition SE E-TEC 600 HO  2005                     MAG SIDE
# 2    Ski-Doo  Expedition SE E-TEC 600 HO  2006                     MAG SIDE
# 3    Ski-Doo  Expedition SE E-TEC 600 HO  2007                     MAG SIDE
# 4    Ski-Doo  Expedition SE E-TEC 600 HO  2008                     MAG SIDE
# ..       ...                         ...   ...    ...         ...       ...
# 352  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2016                     MAG SIDE
# 353  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2017                     MAG SIDE
# 354  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2018                     MAG SIDE
# 355  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2019                     MAG SIDE
# 356  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2020                     MAG SIDE
#
#           MPN     SKU          Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09375.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09188-5A',
    sku='125347',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; CRANK WEB O.D. 120MM; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM; NUT:M22 X PITCH 1.5; DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'GSX SE E-TEC 800R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade X E-TEC 800R', 
    'Renegade X-RS E-TEC 800R', 
    'Summit Burton E-TEC 800R', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                        Model  Year Vendor Vendor Code Position  \
# 0    Ski-Doo      Freeride E-TEC 800R 137  2009
# 1    Ski-Doo      Freeride E-TEC 800R 137  2010
# 2    Ski-Doo      Freeride E-TEC 800R 137  2011
# 3    Ski-Doo      Freeride E-TEC 800R 137  2012
# 4    Ski-Doo      Freeride E-TEC 800R 137  2013
# ..       ...                          ...   ...    ...         ...      ...
# 413  Ski-Doo  Summit Sport Power TEK 800R  2015
# 414  Ski-Doo  Summit Sport Power TEK 800R  2016
# 415  Ski-Doo  Summit Sport Power TEK 800R  2017
# 416  Ski-Doo  Summit Sport Power TEK 800R  2018
# 417  Ski-Doo  Summit Sport Power TEK 800R  2019
#
#              MPN     SKU          Product Type  \
# 0    SM-09188-5A  125347  Oil Pump Drive Gears
# 1    SM-09188-5A  125347  Oil Pump Drive Gears
# 2    SM-09188-5A  125347  Oil Pump Drive Gears
# 3    SM-09188-5A  125347  Oil Pump Drive Gears
# 4    SM-09188-5A  125347  Oil Pump Drive Gears
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09378.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='Woodruf Key',
    mpn='SM-09378C-1',
    sku='128576',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; CRANK WEB O.D. 120MM; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM; NUT:M22 X PITCH 1.5; DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'GSX SE E-TEC 800R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade X E-TEC 800R', 
    'Renegade X-RS E-TEC 800R', 
    'Summit Burton E-TEC 800R', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                        Model  Year Vendor Vendor Code  \
# 0    Ski-Doo      Freeride E-TEC 800R 137  2009
# 1    Ski-Doo      Freeride E-TEC 800R 137  2010
# 2    Ski-Doo      Freeride E-TEC 800R 137  2011
# 3    Ski-Doo      Freeride E-TEC 800R 137  2012
# 4    Ski-Doo      Freeride E-TEC 800R 137  2013
# ..       ...                          ...   ...    ...         ...
# 413  Ski-Doo  Summit Sport Power TEK 800R  2015
# 414  Ski-Doo  Summit Sport Power TEK 800R  2016
# 415  Ski-Doo  Summit Sport Power TEK 800R  2017
# 416  Ski-Doo  Summit Sport Power TEK 800R  2018
# 417  Ski-Doo  Summit Sport Power TEK 800R  2019
#
#         Position          MPN     SKU          Product Type  \
# 0    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 1    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 2    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 3    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SSM-09378C-1-a.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='Woodruf Key',
    mpn='SM-09378C-1',
    sku='128576',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098;  SHAFT LENGTH:415MM;  WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code  \
# 0    Ski-Doo  Expedition SE E-TEC 600 HO  2009
# 1    Ski-Doo  Expedition SE E-TEC 600 HO  2010
# 2    Ski-Doo  Expedition SE E-TEC 600 HO  2011
# 3    Ski-Doo  Expedition SE E-TEC 600 HO  2012
# 4    Ski-Doo  Expedition SE E-TEC 600 HO  2013
# ..       ...                         ...   ...    ...         ...
# 226  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2015
# 227  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2016
# 228  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2017
# 229  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2018
# 230  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2019
#
#         Position          MPN     SKU          Product Type  \
# 0    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 1    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 2    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# 3    Woodruf Key  SM-09378C-1  128576  Oil Pump Drive Gears
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SSM-09378C-1-b.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='Center Web Set',
    mpn='SM-09378D',
    sku='129151',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; CRANK WEB O.D. 120MM; SHAFT LENGTH:415MM; WASHER:22.6 X 35 X 3.2/4MM; NUT:M22 X PITCH 1.5; DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'GSX SE E-TEC 800R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade X E-TEC 800R', 
    'Renegade X-RS E-TEC 800R', 
    'Summit Burton E-TEC 800R', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                        Model  Year Vendor Vendor Code  \
# 0    Ski-Doo      Freeride E-TEC 800R 137  2009
# 1    Ski-Doo      Freeride E-TEC 800R 137  2010
# 2    Ski-Doo      Freeride E-TEC 800R 137  2011
# 3    Ski-Doo      Freeride E-TEC 800R 137  2012
# 4    Ski-Doo      Freeride E-TEC 800R 137  2013
# ..       ...                          ...   ...    ...         ...
# 413  Ski-Doo  Summit Sport Power TEK 800R  2015
# 414  Ski-Doo  Summit Sport Power TEK 800R  2016
# 415  Ski-Doo  Summit Sport Power TEK 800R  2017
# 416  Ski-Doo  Summit Sport Power TEK 800R  2018
# 417  Ski-Doo  Summit Sport Power TEK 800R  2019
#
#            Position        MPN     SKU          Product Type  \
# 0    Center Web Set  SM-09378D  129151  Oil Pump Drive Gears
# 1    Center Web Set  SM-09378D  129151  Oil Pump Drive Gears
# 2    Center Web Set  SM-09378D  129151  Oil Pump Drive Gears
# 3    Center Web Set  SM-09378D  129151  Oil Pump Drive Gears
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09378D.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09379',
    sku='129152',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098;  SHAFT LENGTH:415MM;  WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code Position  \
# 0    Ski-Doo  Expedition SE E-TEC 600 HO  2009
# 1    Ski-Doo  Expedition SE E-TEC 600 HO  2010
# 2    Ski-Doo  Expedition SE E-TEC 600 HO  2011
# 3    Ski-Doo  Expedition SE E-TEC 600 HO  2012
# 4    Ski-Doo  Expedition SE E-TEC 600 HO  2013
# ..       ...                         ...   ...    ...         ...      ...
# 226  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2015
# 227  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2016
# 228  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2017
# 229  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2018
# 230  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2019
#
#           MPN     SKU          Product Type  \
# 0    SM-09379  129152  Oil Pump Drive Gears
# 1    SM-09379  129152  Oil Pump Drive Gears
# 2    SM-09379  129152  Oil Pump Drive Gears
# 3    SM-09379  129152  Oil Pump Drive Gears
# 4    SM-09379  129152  Oil Pump Drive Gears
# ..        ...     ...                   ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09379.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='Center Web Set',
    mpn='SM-09379B',
    sku='129153',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098;  SHAFT LENGTH:415MM;  WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 

   



   


]

years = list(range(2009, 2020))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code  \
# 0    Ski-Doo  Expedition SE E-TEC 600 HO  2009
# 1    Ski-Doo  Expedition SE E-TEC 600 HO  2010
# 2    Ski-Doo  Expedition SE E-TEC 600 HO  2011
# 3    Ski-Doo  Expedition SE E-TEC 600 HO  2012
# 4    Ski-Doo  Expedition SE E-TEC 600 HO  2013
# ..       ...                         ...   ...    ...         ...
# 226  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2015
# 227  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2016
# 228  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2017
# 229  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2018
# 230  Ski-Doo  Tundra Xtreme E-TEC 600 HO  2019
#
#            Position        MPN     SKU          Product Type  \
# 0    Center Web Set  SM-09379B  129153  Oil Pump Drive Gears
# 1    Center Web Set  SM-09379B  129153  Oil Pump Drive Gears
# 2    Center Web Set  SM-09379B  129153  Oil Pump Drive Gears
# 3    Center Web Set  SM-09379B  129153  Oil Pump Drive Gears
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(05)SECTION 09 - CRANKSHAFT (05-21-23 )\Meged Template 4\SM-09379B.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='Center Web Set',
    mpn='SM-09379B',
    sku='129153',
    pro_type='Oil Pump Drive Gears',
    vendornotes='OEM#: 420893097, 420893480, 421000668, 421000705; OEM# 420889098;  SHAFT LENGTH:415MM;  WASHER:22.6 X 35 X 3.2/4MM;  NUT:M22 X PITCH 1.5;  DEGREE KEY: 12.3(W) X 3.0(T) X 5.0(H)MM;  HARDNESS:45-50 DEGREE'
)

list_models = [
    
    '400 SKS', 
    '650', 
    '440', 
    '440 Pro X', 
    '440 Pro X Fan', 
    '440 Pro XR', 
    '440 SKS', 
    '440 XC', 
    '440 XC SP', 
    '440 XCR', 
    '440 XCR SP', 
    '500', 
    '500 SKS', 
    '500 SP', 
    '500 SP EFI', 
    '500 SPX', 
    '500 EFI RMK', 
    '500 EFI SKS', 
    '500 RMK', 
    '500 Carb', 
    '500 Carb RMK', 
    '500 Carb SKS', 
    '550 Classic', 
    '600', 
    '600 Triumph', 
    '600 XC', 
    '600 XC Deluxe', 
    '600 XC SP', 
    '600 XCR', 
    '600 XCR SE', 
    '600 XCR SP', 
    '650 RXL', 
    '650 RXL LT', 
    '650 RXL SKS', 
    '650 RXL Touring', 
    '650 SKS', 
    'Classic Touring', 
    'Sport Touring', 
    'Sport', 
    'Super Sport', 
    'Super Sport X', 
    'Supersport M-10', 
    'Trail', 
    'Trail Deluxe', 
    'Trail ES', 
    'Trail RMK', 
    'Trail SKS', 
    'Trail SP', 
    'Trail Super Trak', 
    'Trail Touring', 
    'Trail Touring DLX', 
    'Trail Wide Trak', 
    'Tran Sport', 
    'Wide Trak', 
    'Wide Trak GT', 
    'Wide Trak LX', 
    'XCF', 
    'XCF SP', 
    'XLT', 
    'XLT Classic', 
    'XLT LTD', 
    'XLT LTD SP', 
    'XLT RMK', 
    'XLT SKS', 
    'XLT SP', 
    'XLT SP LT', 
    'XLT SP Xtra', 
    'XLT Touring', 


   



   


]

years = list(range(1985, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make        Model  Year Vendor Vendor Code        Position  \
# 0     Ski-Doo      400 SKS  1985                     Center Web Set
# 1     Ski-Doo      400 SKS  1986                     Center Web Set
# 2     Ski-Doo      400 SKS  1987                     Center Web Set
# 3     Ski-Doo      400 SKS  1988                     Center Web Set
# 4     Ski-Doo      400 SKS  1989                     Center Web Set
# ...       ...          ...   ...    ...         ...             ...
# 1491  Ski-Doo  XLT Touring  2002                     Center Web Set
# 1492  Ski-Doo  XLT Touring  2003                     Center Web Set
# 1493  Ski-Doo  XLT Touring  2004                     Center Web Set
# 1494  Ski-Doo  XLT Touring  2005                     Center Web Set
# 1495  Ski-Doo  XLT Touring  2006                     Center Web Set
#
#             MPN     SKU          Product Type  \
# 0     SM-09379B  129153  Oil Pump Drive Gears
# 1     SM-09379B  129153  Oil Pump Drive Gears
# ...

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09249',
    sku='129150',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72/47.8; WIDTH: 24/17; OEM#: 3514310; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    '440 XC SP', 
    '440 XCR', 
    '440 XCR SP', 
    '500 Classic', 
    '500 Classic Touring', 
    '500 RMK', 
    '500 XC', 
    '500 XC SP', 
    '600 Classic', 
    '600 Classic Touring', 
    '600 Dragon SP', 
    '600 Dragon SwitchBack', 
    '600 HO Fusion', 
    '600 HO IQ', 
    '600 HO IQ CFI', 
    '600 HO IQ LX CFI', 
    '600 HO IQ Touring', 
    '600 INDY', 
    '600 INDY Adventure 137', 
    '600 INDY SP', 
    '600 INDY SP 129', 
    '600 INDY SP 137', 
    '600 INDY SP LE', 
    '600 INDY SP TD Series LE', 
    '600 INDY Voyager', 
    '600 INDY Voyageur', 
    '600 INDY XC 129', 
    '600 INDY XC 137', 
    '600 INDY XCR', 
    '600 IQ', 
    '600 IQ LX', 
    '600 IQ LXT', 
    '600 IQ Racer', 
    '600 IQ Shift', 
    '600 IQ Shift 136', 
    '600 IQ Touring', 
    '600 IQ Widetrack', 
    '600 IQ Widetrak', 
    '600 LX', 
    '600 PRO-RMK 155', 
    '600 PRO X', 
    '600 PRO X2', 
    '600 RMK', 
    '600 RMK 144', 
    '600 RMK 155', 
    '600 RR', 
    '600 Rush', 
    '600 Rush LX', 
    '600 Rush PRO-R', 
    '600 Rush PRO-S', 
    '600 Rush XCR', 
    '600 Shift 136', 
    '600 SwitchBack', 
    '600 SwitchBack Adventure', 
    '600 SwitchBack Assault 144', 
    '600 SwitchBack PRO-R', 
    '600 SwitchBack PRO-S', 
    '600 SwitchBack SP 144', 
    '600 SwitchBack XCR', 
    '600 Touring', 
    '600 Voyageur 144', 
    '600 XC', 
    '600 XC Deluxe', 
    '600 XC SP', 
    'Wide Track IQ 600', 
    '700 Classic', 
    '700 Classic Touring', 
    '700 Dragon', 
    '700 Dragon IQ', 
    '700 Dragon RMK 155', 
    '700 Dragon RMK 163', 
    '700 Dragon SwitchBack', 
    '700 Edge Touring', 
    '700 IQ', 
    '700 PRO X', 
    '700 PRO X2', 
    '700 RMK', 
    '700 RMK 144', 
    '700 RMK 151', 
    '700 RMK 155', 
    '700 RMK 159', 
    '700 SKS', 
    '700 SwitchBack', 
    '700 XC', 
    '700 XC Deluxe', 
    '700 XC SP', 
    '700 XCR', 
    '800 Classic', 
    '800 Classic Touring', 
    '800 LE', 
    '800 PRO X', 
    '800 PRO X2', 
    '800 PRO XR', 
    '800 RMK', 
    '800 RMK 144', 
    '800 RMK 155', 
    '800 RMK Assault 155', 
    '800 RMK Assault 155 3in.', 
    '800 RMK Assault 155 LE', 
    '800 RMK KHAOS 155', 
    '800 RMK KHAOS 155 3in.', 
    '800 RMK SP 144', 
    '800 RMK SP 151', 
    '800 SKS', 
    '800 SKS 146', 
    '800 SKS 155', 
    '800 SwitchBack', 
    '800 SwitchBack Adventure', 
    '800 SwitchBack Assault 144', 
    '800 SwitchBack Assault 144 TD Series LE', 
    '800 SwitchBack Assault LE', 
    '800 SwitchBack PRO-R', 
    '800 SwitchBack PRO-R LE', 
    '800 SwitchBack PRO-S', 
    '800 SwitchBack PRO-S LE', 
    '800 SwitchBack PRO-X', 
    '800 SwitchBack XCR', 
    '800 XC', 
    '800 XC SP', 
    '800 XCR', 
    '800 Dragon RMK 155', 
    '800 Dragon RMK 163', 
    'Frontier Classic', 
    'Frontier Touring', 
    'IQ Shift', 



   



   


]

years = list(range(1985, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make      Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0     Polaris  440 XC SP  1985                              SM-09249  129150
# 1     Polaris  440 XC SP  1986                              SM-09249  129150
# 2     Polaris  440 XC SP  1987                              SM-09249  129150
# 3     Polaris  440 XC SP  1988                              SM-09249  129150
# 4     Polaris  440 XC SP  1989                              SM-09249  129150
# ...       ...        ...   ...    ...         ...      ...       ...     ...
# 2745  Polaris   IQ Shift  2002                              SM-09249  129150
# 2746  Polaris   IQ Shift  2003                              SM-09249  129150
# 2747  Polaris   IQ Shift  2004                              SM-09249  129150
# 2748  Polaris   IQ Shift  2005                              SM-09249  129150
# 2749  Polaris   IQ Shift  2006                              SM-09249  129150
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\SM-09249.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UB-09023',
    sku='128178',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 40; OD: 80; WIDTH: 21; OEM#: 420832602, 420832605, 420832606, 420832607, 420832608; Matched - FAG BEARING TAIWAN P/N# UP-09023 IS NO LONGER AVAILABLE FROM 2023'
)

list_models = [
    
    'Expedition LE E-TEC 600 HO', 
    'Expedition SE E-TEC 600 HO', 
    'Grand Touring LE E-TEC 600 HO', 
    'GSX LE E-TEC 600 HO', 
    'GSX SE E-TEC 600 HO', 
    'MX Z Blizzard E-TEC 600 HO', 
    'MX Z TNT E-TEC 600 HO', 
    'MX Z X E-TEC 600 HO', 
    'MX Z X-RS E-TEC 600 HO', 
    'MX Z X-RS Iron Dog E-TEC 600 HO', 
    'Renegade Adrenaline E-TEC 600 HO', 
    'Renegade Backcountry E-TEC 600 HO', 
    'Renegade Backcountry X E-TEC 600 HO', 
    'Renegade Enduro E-TEC 600 HO', 
    'Renegade X E-TEC 600 HO', 
    'Skandic SWT E-TEC 600 HO', 
    'Skandic WT E-TEC 600 HO', 
    'Summit Everest E-TEC 600 HO', 
    'Summit SP E-TEC 600 HO 146', 
    'Summit SP E-TEC 600 HO 154', 
    'Summit X E-TEC 600 HO', 
    'Tundra Xtreme E-TEC 600 HO', 
    'Backcountry E-TEC 600R', 
    'Backcountry E-TEC 850', 
    'Backcountry X E-TEC 850', 
    'Backcountry X-RS E-TEC 850 146', 
    'Backcountry X-RS E-TEC 850 154', 
    'Expedition 4-Tec', 
    'Expedition LE 4-TEC 1200', 
    'Expedition LE E-TEC 600R', 
    'Expedition SE 4-TEC 1200', 
    'Expedition SE E-TEC 600R', 
    'Expedition SE E-TEC 850', 
    'Expedition SWT E-TEC 600R', 
    'Expedition Xtreme E-TEC 800R', 
    'Expedition Xtreme E-TEC 850', 
    'Freeride E-TEC 800R 137', 
    'Freeride E-TEC 800R 146', 
    'Freeride E-TEC 800R 154', 
    'Freeride E-TEC 850 137', 
    'Freeride E-TEC 850 146', 
    'Freeride E-TEC 850 154', 
    'Freeride E-TEC 850 165', 
    'Freeride E-TEC 850 Turbo 146', 
    'Freeride E-TEC 850 Turbo 154', 
    'Freeride E-TEC 850 Turbo 165', 
    'Freeride E-TEC 850 Turbo R 146', 
    'Freeride E-TEC 850 Turbo R 154', 
    'Freeride E-TEC 850 Turbo R 165', 
    'Freeride S-38 E-TEC 850 154', 
    'Grand Touring LE 4-TEC 1200', 
    'Grand Touring Limited E-TEC 600R', 
    'Grand Touring SE 4-TEC 1200', 
    'GSX LE 4-TEC 1200', 
    'GSX SE 4-TEC 1200', 
    'GSX SE E-TEC 800R', 
    'Mach Z Tech Plus', 
    'MX Z Blizzard 4-TEC 1200', 
    'MX Z Blizzard E-TEC 600R', 
    'MX Z Blizzard E-TEC 800R', 
    'MX Z Blizzard E-TEC 850', 
    'MX Z TNT 4-TEC 1200', 
    'MX Z TNT 800R Power TEC', 
    'MX Z TNT E-TEC 600R', 
    'MX Z TNT E-TEC 800R', 
    'MX Z TNT E-TEC 850', 
    'MX Z X 4-TEC 1200', 
    'MX Z X-RS E-TEC 600R', 
    'MX Z X E-TEC 600R', 
    'MX Z X E-TEC 800R', 
    'MX Z X-RS E-TEC 850', 
    'MX Z X E-TEC 850', 
    'MX Z X-RS E-TEC 800R', 
    'Renegade Adrenaline 4-TEC 1200', 
    'Renegade Adrenaline E-TEC 600R', 
    'Renegade Adrenaline E-TEC 800R', 
    'Renegade Adrenaline E-TEC 850', 
    'Renegade Backcountry E-TEC 800R', 
    'Renegade Backcountry E-TEC 850', 
    'Renegade Backcountry X E-TEC 800R', 
    'Renegade Backcountry X E-TEC 850', 
    'Renegade Enduro 4-TEC 1200', 
    'Renegade Enduro E-TEC 600R', 
    'Renegade Enduro E-TEC 800R', 
    'Renegade Enduro E-TEC 850', 
    'Renegade X 4-TEC 1200', 
    'Renegade X-RS E-TEC 850', 
    'Renegade X-RS with Comp Package E-TEC 600R', 
    'Renegade X E-TEC 600R', 
    'Renegade X E-TEC 800R', 
    'Renegade X E-TEC 850', 
    'Renegade X-RS E-TEC 800R', 
    'Skandic LE E-TEC 600R', 
    'Skandic SE E-TEC 600R', 
    'Skandic SWT E-TEC 600R', 
    'Skandic WT E-TEC 600R', 
    'Summit Burton E-TEC 800R', 
    'Summit Edge E-TEC 850 154', 
    'Summit Edge E-TEC 850 165', 
    'Summit Edge E-TEC 850 175', 
    'Summit Everest E-TEC 800R', 
    'Summit Freeride E-TEC 800R', 
    'Summit SP E-TEC 600R 146', 
    'Summit SP E-TEC 600R 154', 
    'Summit SP E-TEC 800R 146', 
    'Summit SP E-TEC 800R 154', 
    'Summit SP E-TEC 800R 163', 
    'Summit SP E-TEC 800R 174', 
    'Summit SP E-TEC 850 146', 
    'Summit SP E-TEC 850 154', 
    'Summit SP E-TEC 850 165', 
    'Summit SP E-TEC 850 175', 
    'Summit SP T3 Package E-TEC 800R 154', 
    'Summit SP T3 Package E-TEC 800R 163', 
    'Summit SP T3 Package E-TEC 800R 174', 
    'Summit X E-TEC 800R 146', 
    'Summit X E-TEC 800R 154', 
    'Summit X E-TEC 800R 163', 
    'Summit X E-TEC 800R 174', 
    'Summit X E-TEC 850 154', 
    'Summit X E-TEC 850 165', 
    'Summit X E-TEC 850 175', 
    'Summit X E-TEC 850 Turbo 154', 
    'Summit X E-TEC 850 Turbo 165', 
    'Summit X E-TEC 850 Turbo R 154', 
    'Summit X E-TEC 850 Turbo R 165', 
    'Summit X T3 Package E-TEC 800R 154', 
    'Summit X T3 Package E-TEC 800R 163', 
    'Summit X T3 Package E-TEC 800R 174', 
    'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5', 
    'Summit X with Expert Package E-TEC 850 154', 
    'Summit X with Expert Package E-TEC 850 154 2.5', 
    'Summit X with Expert Package E-TEC 850 165', 
    'Summit X with Expert Package E-TEC 850 175', 
    'Summit X with Expert Package E-TEC 850 Turbo 154', 
    'Summit X with Expert Package E-TEC 850 Turbo 165', 
    'Summit X with Expert Package E-TEC 850 Turbo 175', 
    'Summit X with Expert Package E-TEC 850 Turbo R 154', 
    'Summit X with Expert Package E-TEC 850 Turbo R 165', 
    'Summit X with Expert Package E-TEC 850 Turbo R 175', 
    'Renegade Adrenaline 800R Power TEK', 
    'Renegade Backcountry 800R Power TEK', 
    'Renegade SP 800R Power TEK', 
    'Summit Everest 800R Power TEK 146', 
    'Summit Everest 800R Power TEK 154', 
    'Summit Everest 800R Power TEK 163', 
    'Summit Sport Power TEK 800R', 
    'GSX 600 Sport SDI', 
    'Legend 800 SE SDI', 





]

years = list(range(2002, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make                       Model  Year Vendor Vendor Code Position  \
# 0     Ski Doo  Expedition LE E-TEC 600 HO  2002
# 1     Ski Doo  Expedition LE E-TEC 600 HO  2003
# 2     Ski Doo  Expedition LE E-TEC 600 HO  2004
# 3     Ski Doo  Expedition LE E-TEC 600 HO  2005
# 4     Ski Doo  Expedition LE E-TEC 600 HO  2006
# ...       ...                         ...   ...    ...         ...      ...
# 3273  Ski Doo           Legend 800 SE SDI  2019
# 3274  Ski Doo           Legend 800 SE SDI  2020
# 3275  Ski Doo           Legend 800 SE SDI  2021
# 3276  Ski Doo           Legend 800 SE SDI  2022
# 3277  Ski Doo           Legend 800 SE SDI  2023
#
#            MPN     SKU        Product Type  \
# 0     UB-09023  128178  CRANKSHAFT BEARING
# 1     UB-09023  128178  CRANKSHAFT BEARING
# 2     UB-09023  128178  CRANKSHAFT BEARING
# 3     UB-09023  128178  CRANKSHAFT BEARING
# 4     UB-09023  128178  CRANKSHAFT BEARING
# ...        ...     ...                 ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09023.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski Doo | Bombardier',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'Skandic 277', 
'Tundra II LT', 
'Safari Citation', 
'Safari Citation E', 


]

years = list(range(1971, 1999))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#                      Make              Model  Year Vendor Vendor Code  \
# 0    Ski Doo | Bombardier        Skandic 277  1971
# 1    Ski Doo | Bombardier        Skandic 277  1972
# 2    Ski Doo | Bombardier        Skandic 277  1973
# 3    Ski Doo | Bombardier        Skandic 277  1974
# 4    Ski Doo | Bombardier        Skandic 277  1975
# ..                    ...                ...   ...    ...         ...
# 107  Ski Doo | Bombardier  Safari Citation E  1994
# 108  Ski Doo | Bombardier  Safari Citation E  1995
# 109  Ski Doo | Bombardier  Safari Citation E  1996
# 110  Ski Doo | Bombardier  Safari Citation E  1997
# 111  Ski Doo | Bombardier  Safari Citation E  1998
#
#     Position       MPN     SKU        Product Type Vendor Notes
# 0     CENTER  UB-09202  999855  CRANKSHAFT BEARING
# 1     CENTER  UB-09202  999855  CRANKSHAFT BEARING
# 2     CENTER  UB-09202  999855  CRANKSHAFT BEARING
# 3     CENTER  UB-09202  999855  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERSKIDOO.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='John Deere',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'400', 
'JDX4', 
'JDX6', 
'JDX8', 
'Liquifire 340', 
'Liquifire 440', 
'Snowfire', 
'Spitfire 340', 
'Sportfire', 
'Sprintfire', 
'Trailfire 340', 
'Trailfire 440', 



]

years = list(range(1972, 1985))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#            Make          Model  Year Vendor Vendor Code Position       MPN  \
# 0    John Deere            400  1972                      CENTER  UB-09202
# 1    John Deere            400  1973                      CENTER  UB-09202
# 2    John Deere            400  1974                      CENTER  UB-09202
# 3    John Deere            400  1975                      CENTER  UB-09202
# 4    John Deere            400  1976                      CENTER  UB-09202
# ..          ...            ...   ...    ...         ...      ...       ...
# 151  John Deere  Trailfire 440  1980                      CENTER  UB-09202
# 152  John Deere  Trailfire 440  1981                      CENTER  UB-09202
# 153  John Deere  Trailfire 440  1982                      CENTER  UB-09202
# 154  John Deere  Trailfire 440  1983                      CENTER  UB-09202
# 155  John Deere  Trailfire 440  1984                      CENTER  UB-09202
#
#         SKU        Product Type Vendor Notes
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERJOHNDEERE.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Moto-Ski',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'ZEPHYR 340'




]

years = list(range(1972, 1974))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make       Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0  Moto-Ski  ZEPHYR 340  1972                      CENTER  UB-09202  999855
# 1  Moto-Ski  ZEPHYR 340  1973                      CENTER  UB-09202  999855
#
#          Product Type Vendor Notes
# 0  CRANKSHAFT BEARING
# 1  CRANKSHAFT BEARING

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERzephyr.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski Doo | Bombardier',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAGNETO SIDE',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'Skandic 277', 
'Tundra II LT', 
'Safari Citation', 
'Safari Citation E', 


]

years = list(range(1971, 1999))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#                      Make              Model  Year Vendor Vendor Code  \
# 0    Ski Doo | Bombardier        Skandic 277  1971
# 1    Ski Doo | Bombardier        Skandic 277  1972
# 2    Ski Doo | Bombardier        Skandic 277  1973
# 3    Ski Doo | Bombardier        Skandic 277  1974
# 4    Ski Doo | Bombardier        Skandic 277  1975
# ..                    ...                ...   ...    ...         ...
# 107  Ski Doo | Bombardier  Safari Citation E  1994
# 108  Ski Doo | Bombardier  Safari Citation E  1995
# 109  Ski Doo | Bombardier  Safari Citation E  1996
# 110  Ski Doo | Bombardier  Safari Citation E  1997
# 111  Ski Doo | Bombardier  Safari Citation E  1998
#
#          Position       MPN     SKU        Product Type Vendor Notes
# 0    MAGNETO SIDE  UB-09202  999855  CRANKSHAFT BEARING
# 1    MAGNETO SIDE  UB-09202  999855  CRANKSHAFT BEARING
# 2    MAGNETO SIDE  UB-09202  999855  CRANKSHAFT BEARING
# 3    MAGNETO SIDE  UB-09202  999855  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-MAGNETOSIDESKIDOO.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='John Deere',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAGNETO SIDE',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'400', 
'JDX4', 
'JDX6', 
'JDX8', 
'Liquifire 340', 
'Liquifire 440', 
'Snowfire', 
'Spitfire 340', 
'Sportfire', 
'Sprintfire', 
'Trailfire 340', 
'Trailfire 440', 



]

years = list(range(1972, 1985))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#            Make          Model  Year Vendor Vendor Code      Position  \
# 0    John Deere            400  1972                     MAGNETO SIDE
# 1    John Deere            400  1973                     MAGNETO SIDE
# 2    John Deere            400  1974                     MAGNETO SIDE
# 3    John Deere            400  1975                     MAGNETO SIDE
# 4    John Deere            400  1976                     MAGNETO SIDE
# ..          ...            ...   ...    ...         ...           ...
# 151  John Deere  Trailfire 440  1980                     MAGNETO SIDE
# 152  John Deere  Trailfire 440  1981                     MAGNETO SIDE
# 153  John Deere  Trailfire 440  1982                     MAGNETO SIDE
# 154  John Deere  Trailfire 440  1983                     MAGNETO SIDE
# 155  John Deere  Trailfire 440  1984                     MAGNETO SIDE
#
#           MPN     SKU        Product Type Vendor Notes
# 0    UB-09202  999855  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-MAGNETOSIDEJOHNDEERE.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='KAWASAKI',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAGNETO SIDE',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes=''
)

list_models = [
    
    
'Drifter 440', 
'Intruder 440', 
'Invader 440', 
'Invader 340', 





]

years = list(range(1978, 1998))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make        Model  Year Vendor Vendor Code      Position       MPN  \
# 0   KAWASAKI  Drifter 440  1978                     MAGNETO SIDE  UB-09202
# 1   KAWASAKI  Drifter 440  1979                     MAGNETO SIDE  UB-09202
# 2   KAWASAKI  Drifter 440  1980                     MAGNETO SIDE  UB-09202
# 3   KAWASAKI  Drifter 440  1981                     MAGNETO SIDE  UB-09202
# 4   KAWASAKI  Drifter 440  1982                     MAGNETO SIDE  UB-09202
# ..       ...          ...   ...    ...         ...           ...       ...
# 75  KAWASAKI  Invader 340  1993                     MAGNETO SIDE  UB-09202
# 76  KAWASAKI  Invader 340  1994                     MAGNETO SIDE  UB-09202
# 77  KAWASAKI  Invader 340  1995                     MAGNETO SIDE  UB-09202
# 78  KAWASAKI  Invader 340  1996                     MAGNETO SIDE  UB-09202
# 79  KAWASAKI  Invader 340  1997                     MAGNETO SIDE  UB-09202
#
#        SKU        Product Type Vendor Notes
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-MAGNETOSIDEKAWASAKI.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-045; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    
'El Tigre 295', 
'El Tigre 340', 
'El Tigre 400', 
'El Tigre 440', 
'EXT 340', 
'EXT 440', 
'Panther 440', 
'VIP 440', 
'Panther 340', 
'Panther 399', 


]

years = list(range(1971, 1976))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#           Make         Model  Year Vendor Vendor Code Position       MPN  \
# 0   Arctic Cat  El Tigre 295  1971                      CENTER  UB-09202
# 1   Arctic Cat  El Tigre 295  1972                      CENTER  UB-09202
# 2   Arctic Cat  El Tigre 295  1973                      CENTER  UB-09202
# 3   Arctic Cat  El Tigre 295  1974                      CENTER  UB-09202
# 4   Arctic Cat  El Tigre 295  1975                      CENTER  UB-09202
# 5   Arctic Cat  El Tigre 340  1971                      CENTER  UB-09202
# 6   Arctic Cat  El Tigre 340  1972                      CENTER  UB-09202
# 7   Arctic Cat  El Tigre 340  1973                      CENTER  UB-09202
# 8   Arctic Cat  El Tigre 340  1974                      CENTER  UB-09202
# 9   Arctic Cat  El Tigre 340  1975                      CENTER  UB-09202
# 10  Arctic Cat  El Tigre 400  1971                      CENTER  UB-09202
# 11  Arctic Cat  El Tigre 400  1972                      CENTER  UB-09202
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERARCTICCAT.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='MAGNETO SIDE',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-045; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    
'El Tigre 295', 
'El Tigre 340', 
'El Tigre 400', 
'El Tigre 440', 
'EXT 340', 
'EXT 440', 
'Panther 440', 
'VIP 440', 
'Panther 340', 
'Panther 399', 
'Puma 340', 
'Puma 340T', 
'Puma 399', 
'Puma 440', 
 


]

years = list(range(1971, 1976))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#           Make         Model  Year Vendor Vendor Code      Position       MPN  \
# 0   Arctic Cat  El Tigre 295  1971                     MAGNETO SIDE  UB-09202
# 1   Arctic Cat  El Tigre 295  1972                     MAGNETO SIDE  UB-09202
# 2   Arctic Cat  El Tigre 295  1973                     MAGNETO SIDE  UB-09202
# 3   Arctic Cat  El Tigre 295  1974                     MAGNETO SIDE  UB-09202
# 4   Arctic Cat  El Tigre 295  1975                     MAGNETO SIDE  UB-09202
# ..         ...           ...   ...    ...         ...           ...       ...
# 65  Arctic Cat      Puma 440  1971                     MAGNETO SIDE  UB-09202
# 66  Arctic Cat      Puma 440  1972                     MAGNETO SIDE  UB-09202
# 67  Arctic Cat      Puma 440  1973                     MAGNETO SIDE  UB-09202
# 68  Arctic Cat      Puma 440  1974                     MAGNETO SIDE  UB-09202
# 69  Arctic Cat      Puma 440  1975                     MAGNETO SIDE  UB-09202
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-MAGNETOSIDEARCTICCAT.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='POLARIS',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 3083805; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    
'Cobra 340', 
'Cobra 440', 
'Colt 250', 
'Colt 250 (244cc)', 
'Colt 295', 
'Colt 340', 
'Colt S/S 250', 
'Colt S/S 295', 
'Colt S/S 340', 
'Cutlass 340', 
'Electra 250', 
'Electra 340', 
'Electra 440', 
'Galaxy 340', 
'Galaxy 440', 
'Gemini 244', 
'Gemini 250', 
'Apollo 340', 
'TX 250', 
'TX 340', 
'TX 440', 
'TX 500', 

 


]

years = list(range(1971, 2001))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make      Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0    POLARIS  Cobra 340  1971                      CENTER  UB-09202  999855
# 1    POLARIS  Cobra 340  1972                      CENTER  UB-09202  999855
# 2    POLARIS  Cobra 340  1973                      CENTER  UB-09202  999855
# 3    POLARIS  Cobra 340  1974                      CENTER  UB-09202  999855
# 4    POLARIS  Cobra 340  1975                      CENTER  UB-09202  999855
# ..       ...        ...   ...    ...         ...      ...       ...     ...
# 655  POLARIS     TX 500  1996                      CENTER  UB-09202  999855
# 656  POLARIS     TX 500  1997                      CENTER  UB-09202  999855
# 657  POLARIS     TX 500  1998                      CENTER  UB-09202  999855
# 658  POLARIS     TX 500  1999                      CENTER  UB-09202  999855
# 659  POLARIS     TX 500  2000                      CENTER  UB-09202  999855
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERPOLARIS.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='YAMAHA',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 405406200, 420832200, 420832207, 420832208, 420832209, 420832481, 420932585; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    
'RX10R Apex ER', 

 


]

years = list(range(2006, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#      Make          Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0  YAMAHA  RX10R Apex ER  2006                              UB-09202  999855
#
#          Product Type                                       Vendor Notes
# 0  CRANKSHAFT BEARING  ID: 30; OD: 62; WIDTH: 16; OEM#: 405406200, 42...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-YAMAHA.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='KAWASAKI',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='CENTER',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 92045-3002; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
    
'Drifter 440', 
'Intruder 440', 
'Invader 440', 
'Invader 340', 





]

years = list(range(1978, 1998))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make        Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0   KAWASAKI  Drifter 440  1978                      CENTER  UB-09202  999855
# 1   KAWASAKI  Drifter 440  1979                      CENTER  UB-09202  999855
# 2   KAWASAKI  Drifter 440  1980                      CENTER  UB-09202  999855
# 3   KAWASAKI  Drifter 440  1981                      CENTER  UB-09202  999855
# 4   KAWASAKI  Drifter 440  1982                      CENTER  UB-09202  999855
# ..       ...          ...   ...    ...         ...      ...       ...     ...
# 75  KAWASAKI  Invader 340  1993                      CENTER  UB-09202  999855
# 76  KAWASAKI  Invader 340  1994                      CENTER  UB-09202  999855
# 77  KAWASAKI  Invader 340  1995                      CENTER  UB-09202  999855
# 78  KAWASAKI  Invader 340  1996                      CENTER  UB-09202  999855
# 79  KAWASAKI  Invader 340  1997                      CENTER  UB-09202  999855
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-CENTERKAWASAKI.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='YAMAHA',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UB-09202',
    sku='999855',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='"ID: 30; OD: 62; WIDTH: 16; OEM#: 93306-20627-0093306-20622-00
93306-20618-00
93306-20607-00
93306-20601-00; Matched - NOTE : KOYO BEARING."
'
)

list_models = [
    
    
'RX10R Apex ER', 

 


]

years = list(range(2006, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make              Model  Year Vendor Vendor Code Position       MPN  \
# 0     YAMAHA          RX10 Apex  1972                              UB-09213
# 1     YAMAHA          RX10 Apex  1973                              UB-09213
# 2     YAMAHA          RX10 Apex  1974                              UB-09213
# 3     YAMAHA          RX10 Apex  1975                              UB-09213
# 4     YAMAHA          RX10 Apex  1976                              UB-09213
# ...      ...                ...   ...    ...         ...      ...       ...
# 5112  YAMAHA  VX800ST VMAX-4 ST  2010                              UB-09213
# 5113  YAMAHA  VX800ST VMAX-4 ST  2011                              UB-09213
# 5114  YAMAHA  VX800ST VMAX-4 ST  2012                              UB-09213
# 5115  YAMAHA  VX800ST VMAX-4 ST  2013                              UB-09213
# 5116  YAMAHA  VX800ST VMAX-4 ST  2014                              UB-09213
#
#          SKU        Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09202-YAMAHA2.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='SKI-DOO',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UB-09213',
    sku='999857',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 19; OEM#: 420832595, 420832596; Matched - NOTE : FAG BEARING. '
)

list_models = [
    
    
'Grand Touring 500 Sport', 
'Grand Touring 600 Sport', 
'Grand Touring Sport 600 ACE', 
'Grand Touring Sport 600 Carb', 
'GSX 500SS Sport', 
'GSX 600 Sport', 
'GSX 600 Sport SDI', 
'GTX 500SS Sport', 
'MX Z 500 Adrenaline', 
'MX Z 500 R Trail', 
'MX Z 500 TNT', 
'MX Z 500 Trail', 
'MX Z 600 Adrenaline', 
'MX Z 600 Sport', 
'MX Z 600 TNT', 
'MX Z 600 TNT Early Edition', 
'Renegade Sport 600 ACE', 
'Renegade Sport 600 Carb', 
'Summit Sport 600 Carb', 
'Skandic 600 SUV', 
'Skandic 600 WT', 
'Skandic 500 SWT', 
'Skandic 500 WT', 




 


]

years = list(range(2003, 2021))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                    Model  Year Vendor Vendor Code Position  \
# 0    SKI-DOO  Grand Touring 500 Sport  2003
# 1    SKI-DOO  Grand Touring 500 Sport  2004
# 2    SKI-DOO  Grand Touring 500 Sport  2005
# 3    SKI-DOO  Grand Touring 500 Sport  2006
# 4    SKI-DOO  Grand Touring 500 Sport  2007
# ..       ...                      ...   ...    ...         ...      ...
# 409  SKI-DOO           Skandic 500 WT  2016
# 410  SKI-DOO           Skandic 500 WT  2017
# 411  SKI-DOO           Skandic 500 WT  2018
# 412  SKI-DOO           Skandic 500 WT  2019
# 413  SKI-DOO           Skandic 500 WT  2020
#
#           MPN     SKU        Product Type  \
# 0    UB-09213  999857  CRANKSHAFT BEARING
# 1    UB-09213  999857  CRANKSHAFT BEARING
# 2    UB-09213  999857  CRANKSHAFT BEARING
# 3    UB-09213  999857  CRANKSHAFT BEARING
# 4    UB-09213  999857  CRANKSHAFT BEARING
# ..        ...     ...                 ...
# 409  UB-09213  999857  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09213.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='POLARIS',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UB-09214',
    sku='999858',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 32; OD: 65; WIDTH: 17; OEM#: 3085204, 3085205, 62/32GPC4; Matched - NOTE : NTN BEARING.  '
)

list_models = [
    
    
'440 XC', 
'440 XC SP', 
'440 XCR', 
'440 XCR SP', 
'500', 
'500 Carb', 
'500 Carb RMK', 
'500 Carb SKS', 
'500 Classic', 
'500 Classic Touring', 
'500 EFI', 
'500 EFI RMK', 
'500 EFI SKS', 
'500 RMK', 
'500 SKS', 
'Classic', 
'Classic Touring', 
'Wide Track LX', 
'Wide Trak LX', 





 


]

years = list(range(1996, 2016))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                    Model  Year Vendor Vendor Code Position  \
# 0    POLARIS  Grand Touring 500 Sport  1996
# 1    POLARIS  Grand Touring 500 Sport  1997
# 2    POLARIS  Grand Touring 500 Sport  1998
# 3    POLARIS  Grand Touring 500 Sport  1999
# 4    POLARIS  Grand Touring 500 Sport  2000
# ..       ...                      ...   ...    ...         ...      ...
# 455  POLARIS           Skandic 500 WT  2011
# 456  POLARIS           Skandic 500 WT  2012
# 457  POLARIS           Skandic 500 WT  2013
# 458  POLARIS           Skandic 500 WT  2014
# 459  POLARIS           Skandic 500 WT  2015
#
#           MPN     SKU        Product Type  \
# 0    UB-09214  999858  CRANKSHAFT BEARING
# 1    UB-09214  999858  CRANKSHAFT BEARING
# 2    UB-09214  999858  CRANKSHAFT BEARING
# 3    UB-09214  999858  CRANKSHAFT BEARING
# 4    UB-09214  999858  CRANKSHAFT BEARING
# ..        ...     ...                 ...
# 455  UB-09214  999858  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09214.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='POLARIS',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09014',
    sku='128619',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72; WIDTH: 20; OEM#: 3090283, 3514363; Matched - NOTE : KOYO BEARING. CENTER BEARING – 2 PER MACHINE'
)

list_models = [
    
   '600 INDY', 
'600 INDY SP', 
'600 INDY SP 129', 
'600 INDY SP 137', 
'600 INDY SP LE', 
'600 INDY SP TD Series LE', 
'600 INDY XC 129', 
'600 INDY XC 137', 
'600 INDY XCR', 
'600 IQ LXT', 
'600 IQ Racer', 
'600 IQ Widetrack', 
'600 IQ Widetrak', 
'600 PRO-RMK 155', 
'600 RMK 144', 
'600 RMK 155', 
'600 Rush', 
'600 Rush PRO-R', 
'600 Rush PRO-S', 
'600 Rush XCR', 
'600 SwitchBack Adventure', 
'600 SwitchBack Assault 144', 
'600 SwitchBack PRO-R', 
'600 SwitchBack PRO-S', 
'600 SwitchBack SP 144', 
'600 SwitchBack XCR', 
'600 Voyageur 144', 
'600 SwitchBack', 
'800 INDY SP', 
'800 INDY SP LE', 
'800 PRO-RMK 155', 
'800 PRO-RMK 155 3in.', 
'800 PRO-RMK 155 LE', 
'800 PRO-RMK 155 Terrain Dominator', 
'800 PRO-RMK 163', 
'800 PRO-RMK 163 3in.', 
'800 PRO-RMK 163 LE', 
'800 PRO-RMK 163 Terrain Dominator', 
'800 PRO-RMK 174', 
'800 PRO-RMK 174 LE', 
'800 PRO-RMK LE', 
'800 RMK 155', 
'800 RMK Assault 155', 
'800 RMK Assault 155 3in.', 
'800 RMK Assault 155 LE', 
'800 Rush PRO-R', 
'800 Rush PRO-R LE', 
'800 Rush PRO-S', 
'800 Rush PRO-S LE', 
'800 Rush PRO-X', 
'800 Rush XCR', 
'800 SKS 146', 
'800 SKS 155', 
'800 SwitchBack Adventure', 
'800 SwitchBack Assault 144', 
'800 SwitchBack Assault 144 TD Series LE', 
'800 SwitchBack Assault LE', 
'800 SwitchBack PRO-R', 
'800 SwitchBack PRO-R LE', 
'800 SwitchBack PRO-S', 
'800 SwitchBack PRO-S LE', 
'800 SwitchBack PRO-X', 
'800 SwitchBack XCR', 
'800 Titan Adventure 155', 
'800 Titan SP 155', 
'800 Titan XC 155', 
 





 


]

years = list(range(2012, 2022))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make             Model  Year Vendor Vendor Code Position       MPN  \
# 0    POLARIS          600 INDY  2012                              UP-09014
# 1    POLARIS          600 INDY  2013                              UP-09014
# 2    POLARIS          600 INDY  2014                              UP-09014
# 3    POLARIS          600 INDY  2015                              UP-09014
# 4    POLARIS          600 INDY  2016                              UP-09014
# ..       ...               ...   ...    ...         ...      ...       ...
# 655  POLARIS  800 Titan XC 155  2017                              UP-09014
# 656  POLARIS  800 Titan XC 155  2018                              UP-09014
# 657  POLARIS  800 Titan XC 155  2019                              UP-09014
# 658  POLARIS  800 Titan XC 155  2020                              UP-09014
# 659  POLARIS  800 Titan XC 155  2021                              UP-09014
#
#         SKU        Product Type  \
# 0    128619  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09014.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='SKI-DOO',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09020',
    sku='128177',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72; WIDTH: 18.75; OEM#: 420832175, 420832176; Not Matched '
)

list_models = [
    
   
'Backcountry E-TEC 600R', 
'Expedition LE E-TEC 600 HO', 
'Expedition LE E-TEC 600R', 
'Expedition SE E-TEC 600 HO', 
'Expedition SE E-TEC 600R', 
'Expedition SWT E-TEC 600R', 
'Expedition Xtreme E-TEC 800R', 
'Freeride E-TEC 800R 137', 
'Freeride E-TEC 800R 146', 
'Freeride E-TEC 800R 154', 
'Grand Touring LE E-TEC 600 HO', 
'Grand Touring Limited E-TEC 600R', 
'GSX LE E-TEC 600 HO', 
'GSX SE E-TEC 600 HO', 
'GSX SE E-TEC 800R', 
'MX Z Blizzard E-TEC 600 HO', 
'MX Z Blizzard E-TEC 600R', 
'MX Z Blizzard E-TEC 800R', 
'MX Z TNT E-TEC 600 HO', 
'MX Z TNT E-TEC 600R', 
'MX Z TNT E-TEC 800R', 
'MX Z X E-TEC 600 HO', 
'MX Z X-RS E-TEC 600R', 
'MX Z X E-TEC 600R', 
'MX Z X E-TEC 800R', 
'MX Z X E-TEC 850', 
'MX Z X-RS E-TEC 600 HO', 
'MX Z X-RS E-TEC 800R', 
'Renegade Adrenaline E-TEC 600 HO', 
'Renegade Adrenaline E-TEC 600R', 
'Renegade Adrenaline E-TEC 800R', 
'Renegade Adrenaline E-TEC 850', 
'Renegade Backcountry E-TEC 600 HO', 
'Renegade Backcountry E-TEC 800R', 
'Renegade Backcountry X E-TEC 600 HO', 
'Renegade Backcountry X E-TEC 800R', 
'Renegade Enduro E-TEC 600 HO', 
'Renegade Enduro E-TEC 600R', 
'Renegade Enduro E-TEC 800R', 
'Renegade X-RS with Comp Package E-TEC 600R', 
'Renegade X E-TEC 600 HO', 
'Renegade X E-TEC 600R', 
'Renegade X E-TEC 800R', 
'Renegade X-RS E-TEC 800R', 
'Skandic LE E-TEC 600R', 
'Skandic SE E-TEC 600R', 
'Skandic SWT E-TEC 600 HO', 
'Skandic SWT E-TEC 600R', 
'Skandic WT E-TEC 600 HO', 
'Skandic WT E-TEC 600R', 
'Summit Burton E-TEC 800R', 
'Summit SP E-TEC 600 HO 146', 
'Summit SP E-TEC 600 HO 154', 
'Summit SP E-TEC 600R 146', 
'Summit SP E-TEC 600R 154', 
'Summit SP E-TEC 800R 146', 
'Summit SP E-TEC 800R 154', 
'Summit SP E-TEC 800R 163', 
'Summit SP E-TEC 800R 174', 
'Summit SP T3 Package E-TEC 800R 154', 
'Summit SP T3 Package E-TEC 800R 163', 
'Summit SP T3 Package E-TEC 800R 174', 
'Summit X E-TEC 800R 146', 
'Summit X E-TEC 800R 154', 
'Summit X E-TEC 800R 163', 
'Summit X E-TEC 800R 174', 
'Summit X T3 Package E-TEC 800R 154', 
'Summit X T3 Package E-TEC 800R 163', 
'Summit X T3 Package E-TEC 800R 174', 
'Tundra Xtreme E-TEC 600 HO', 

 


]

years = list(range(2012, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code Position  \
# 0    SKI-DOO      Backcountry E-TEC 600R  2012
# 1    SKI-DOO      Backcountry E-TEC 600R  2013
# 2    SKI-DOO      Backcountry E-TEC 600R  2014
# 3    SKI-DOO      Backcountry E-TEC 600R  2015
# 4    SKI-DOO      Backcountry E-TEC 600R  2016
# ..       ...                         ...   ...    ...         ...      ...
# 835  SKI-DOO  Tundra Xtreme E-TEC 600 HO  2019
# 836  SKI-DOO  Tundra Xtreme E-TEC 600 HO  2020
# 837  SKI-DOO  Tundra Xtreme E-TEC 600 HO  2021
# 838  SKI-DOO  Tundra Xtreme E-TEC 600 HO  2022
# 839  SKI-DOO  Tundra Xtreme E-TEC 600 HO  2023
#
#           MPN     SKU        Product Type  \
# 0    UP-09020  128177  CRANKSHAFT BEARING
# 1    UP-09020  128177  CRANKSHAFT BEARING
# 2    UP-09020  128177  CRANKSHAFT BEARING
# 3    UP-09020  128177  CRANKSHAFT BEARING
# 4    UP-09020  128177  CRANKSHAFT BEARING
# ..        ...     ...                 ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UB-09020.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='ARCTIC-CAT',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09204',
    sku='129792',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-438; Matched - NOTE : KOYO BEARING. '
)

list_models = [
    
   
'Cheetah 340', 
'Cheetah 440', 
'Pantera 340', 
'Pantera 440', 



 


]

years = list(range(1975, 1976))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make        Model  Year Vendor Vendor Code Position       MPN  \
# 0  ARCTIC-CAT  Cheetah 340  1975                              UP-09204
# 1  ARCTIC-CAT  Cheetah 440  1975                              UP-09204
# 2  ARCTIC-CAT  Pantera 340  1975                              UP-09204
# 3  ARCTIC-CAT  Pantera 440  1975                              UP-09204
#
#       SKU        Product Type  \
# 0  129792  CRANKSHAFT BEARING
# 1  129792  CRANKSHAFT BEARING
# 2  129792  CRANKSHAFT BEARING
# 3  129792  CRANKSHAFT BEARING
#
#                                         Vendor Notes
# 0  ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-438; Mat...
# 1  ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-438; Mat...
# 2  ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-438; Mat...
# 3  ID: 30; OD: 62; WIDTH: 16; OEM#: 3001-438; Mat...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09204-ARCTICCAT.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09204',
    sku='129792',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 3083089, 3083544, 3084602; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    
'340', 
'340 Classic', 
'340 Deluxe', 
'340 Edge', 
'340 Indy', 
'340 LX', 
'340 Touring', 
'340 Transport', 
'400', 
'600', 
'600 SE', 
'Lite', 
'Lite Deluxe', 
'Lite GT', 
'Lite Touring', 
'Starlite', 
'Starlite GT', 
'Longtrak', 
'Longtrak w/ Reverse', 
'SS', 
'Star', 
'Star Trak', 
'Star Twin', 
'Star Twin ES', 
'Trail Boss 250R/ES', 
'Trail', 
'Trail 488', 
]

years = list(range(1985, 2009))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make      Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0    Polaris        340  1985                              UP-09204  129792
# 1    Polaris        340  1986                              UP-09204  129792
# 2    Polaris        340  1987                              UP-09204  129792
# 3    Polaris        340  1988                              UP-09204  129792
# 4    Polaris        340  1989                              UP-09204  129792
# ..       ...        ...   ...    ...         ...      ...       ...     ...
# 643  Polaris  Trail 488  2004                              UP-09204  129792
# 644  Polaris  Trail 488  2005                              UP-09204  129792
# 645  Polaris  Trail 488  2006                              UP-09204  129792
# 646  Polaris  Trail 488  2007                              UP-09204  129792
# 647  Polaris  Trail 488  2008                              UP-09204  129792
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09204-POLARIS.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='SKI-DOO',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09204',
    sku='129792',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 30; OD: 62; WIDTH: 16; OEM#: 405406200, 420832200, 420832207, 420832208, 420832209, 420832481, 420932585; Matched - NOTE : KOYO BEARING.'
)

list_models = [
    

'Nordic 399', 
'Nordic 399E', 
'Nordic 440', 
'Nordic 440E', 
'Nordic 640E', 
'Nordic 640ER', 
'Nordik', 
'Nordik 50', 
'Nordik 60', 
'Olympique 300', 
'Olympique 300S', 
'Olympique 300T', 
'Olympique 335', 
'Olympique 335E', 
'Olympique 340', 
'Olympique 340E', 
'Olympique 399', 
'Olympique 399E', 
'Olympique 400', 
'Olympique 400E', 
'Olympique 440', 
'Olympique Plus', 
'Elan 250', 
'Elan 250 Deluxe', 
'Elan 250E', 
'Elan 250T', 
'Elan SS', 
'Valmont 640ER', 
'Alpine', 
'Alpine 399ER', 
'Alpine 399R', 
'Alpine 440ER', 
'Alpine 440R', 
'Alpine 508', 
'Alpine 640ER', 
'Alpine II', 
'Formula III', 
'Formula III 600', 
'Formula III 600 LT', 
'Formula III 600 R', 
'Formula III 700', 
'Formula III 700 R', 
'Formula III 800', 
'Formula III LT', 
'Formula Z', 
'Formula Z 500', 
'Formula Z 583', 
'Formula Z 600', 
'Formula Z 670', 
'Formula Z 700', 
'Formula SLS', 
'Formula SS', 
'MX Z 440 Fan', 
'MX Z 440 LC', 
'MX Z 440 LC X', 
'Summit 670 X', 
'Summit 670', 
 
]

years = list(range(1971, 2000))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make       Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0     SKI-DOO  Nordic 399  1971                              UP-09204  129792
# 1     SKI-DOO  Nordic 399  1972                              UP-09204  129792
# 2     SKI-DOO  Nordic 399  1973                              UP-09204  129792
# 3     SKI-DOO  Nordic 399  1974                              UP-09204  129792
# 4     SKI-DOO  Nordic 399  1975                              UP-09204  129792
# ...       ...         ...   ...    ...         ...      ...       ...     ...
# 1648  SKI-DOO  Summit 670  1995                              UP-09204  129792
# 1649  SKI-DOO  Summit 670  1996                              UP-09204  129792
# 1650  SKI-DOO  Summit 670  1997                              UP-09204  129792
# 1651  SKI-DOO  Summit 670  1998                              UP-09204  129792
# 1652  SKI-DOO  Summit 670  1999                              UP-09204  129792
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09204-SKIDOO-BOMBARDIER.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='SKI-DOO',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09021',
    sku='128179',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72; WIDTH: 17; OEM#: 420832575, 420832576; Matched - NOTE : KOYO BEARING. '
)

list_models = [
    

'MX Z 440 LC X', 
'MX Z 440 X', 
'Legend 500 Fan', 
'Legend 500 Sport', 
'Expedition LE E-TEC 600 HO', 
'Expedition SE E-TEC 600 HO', 
'Grand Touring LE E-TEC 600 HO', 
'GSX LE E-TEC 600 HO', 
'GSX SE E-TEC 600 HO', 
'MX Z Blizzard E-TEC 600 HO', 
'MX Z TNT E-TEC 600 HO', 
'MX Z X E-TEC 600 HO', 
'MX Z X-RS E-TEC 600 HO', 
'MX Z X-RS Iron Dog E-TEC 600 HO', 
'Renegade Adrenaline E-TEC 600 HO', 
'Renegade Backcountry E-TEC 600 HO', 
'Renegade Backcountry X E-TEC 600 HO', 
'Renegade Enduro E-TEC 600 HO', 
'Renegade X E-TEC 600 HO', 
'Skandic SWT E-TEC 600 HO', 
'Skandic WT E-TEC 600 HO', 
'Summit Everest E-TEC 600 HO', 
'Summit SP E-TEC 600 HO 146', 
'Summit SP E-TEC 600 HO 154', 
'Summit X E-TEC 600 HO', 
'Backcountry Adrenaline E-TEC 600R', 
'Backcountry E-TEC 600R', 
'Expedition LE E-TEC 600R', 
'Expedition SE E-TEC 600R', 
'Expedition SWT E-TEC 600R', 
'Grand Touring Limited E-TEC 600R', 
'MX Z Adrenaline E-TEC 600R', 
'MX Z Adrenaline E-TEC 600R 137', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 600R', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 600R 137', 
'MX Z Blizzard E-TEC 600R', 
'MX Z TNT E-TEC 600R', 
'MX Z X-RS E-TEC 600R', 
'MX Z X-RS E-TEC 600R 137', 
'MX Z X E-TEC 600R', 
'MX Z X-RS w/ Competition Pkg E-TEC 600R', 
'MX Z X E-TEC 600R 137', 
'Renegade Adrenaline E-TEC 600R', 
'Renegade Adrenaline w/ Enduro Pkg E-TEC 600R', 
'Renegade Enduro E-TEC 600R', 
'Renegade X-RS with Comp Package E-TEC 600R', 
'Renegade X E-TEC 600R', 
'Skandic LE E-TEC 600R', 
'Skandic SE E-TEC 600R', 
'Skandic SWT E-TEC 600R', 
'Skandic WT E-TEC 600R', 
'Summit Adrenaline E-TEC 600R 146', 
'Summit Adrenaline E-TEC 600R 154', 
'Summit Adrenaline w/ Edge Package E-TEC 600R 146', 
'Summit Adrenaline w/ Edge Package E-TEC 600R 154', 
'Summit SP E-TEC 600R 146', 
'Summit SP E-TEC 600R 154', 
'MX Z 700', 
'MX Z 700 Adrenaline', 
'MX Z 700 R Sport', 
'MX Z 700 R X', 
'MX Z 700 Renegade', 
'MX Z 700 Sport', 
'MX Z 700 Trail', 
'MX Z 700 X', 
'Summit 700', 
'Summit 700 Adrenaline', 
'Summit 700 Highmark', 
'Summit 700 R Sport', 
'Summit 700 Sport', 
'Summit 700 X', 
'Outlander 800 HO EFI 4x4', 
'Outlander 800 HO EFI 4x4 XT', 
'Outlander Max 800 HO EFI 4x4', 
'Outlander Max 800 HO EFI 4x4 XT', 
'Legend 800 SE SDI', 
'Expedition Xtreme E-TEC 800R', 
'Freeride E-TEC 800R 137', 
'Freeride E-TEC 800R 146', 
'Freeride E-TEC 800R 154', 
'GSX SE E-TEC 800R', 
'MX Z Blizzard E-TEC 800R', 
'MX Z TNT E-TEC 800R', 
'MX Z X E-TEC 800R', 
'MX Z X-RS E-TEC 800R', 
'Renegade Adrenaline E-TEC 800R', 
'Renegade Backcountry E-TEC 800R', 
'Renegade Backcountry X E-TEC 800R', 
'Renegade Enduro E-TEC 800R', 
'Renegade X E-TEC 800R', 
'Renegade X-RS E-TEC 800R', 
'Summit Burton E-TEC 800R', 
'Summit Everest E-TEC 800R', 
'Summit Freeride E-TEC 800R', 
'Summit SP E-TEC 800R 146', 
'Summit SP E-TEC 800R 154', 
'Summit SP E-TEC 800R 163', 
'Summit SP E-TEC 800R 174', 
'Summit SP T3 Package E-TEC 800R 154', 
'Summit SP T3 Package E-TEC 800R 163', 
'Summit SP T3 Package E-TEC 800R 174', 
'Summit X E-TEC 800R 146', 
'Summit X E-TEC 800R 154', 
'Summit X E-TEC 800R 163', 
'Summit X E-TEC 800R 174', 
'Summit X T3 Package E-TEC 800R 154', 
'Summit X T3 Package E-TEC 800R 163', 
'Summit X T3 Package E-TEC 800R 174', 
'MX Z TNT 800R Power TEC', 
'Backcountry Adrenaline E-TEC 850', 
'Backcountry E-TEC 850', 
'Backcountry X E-TEC 850', 
'Backcountry X-RS E-TEC 850 146', 
'Backcountry X-RS E-TEC 850 154', 
'Expedition SE E-TEC 850', 
'Expedition Xtreme E-TEC 850', 
'Freeride E-TEC 850 137', 
'Freeride E-TEC 850 146', 
'Freeride E-TEC 850 154', 
'Freeride E-TEC 850 165', 
'Freeride E-TEC 850 Turbo 146', 
'Freeride E-TEC 850 Turbo 154', 
'Freeride E-TEC 850 Turbo 165', 
'Freeride E-TEC 850 Turbo R 146', 
'Freeride E-TEC 850 Turbo R 154', 
'Freeride E-TEC 850 Turbo R 165', 
'Freeride S-38 E-TEC 850 154', 
'MX Z Adrenaline E-TEC 850', 
'MX Z Adrenaline E-TEC 850 137', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 850', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 850 137', 
'MX Z Blizzard E-TEC 850', 
'MX Z TNT E-TEC 850', 
'MX Z X-RS E-TEC 850', 
'MX Z X-RS E-TEC 850 137', 
'MX Z X-RS w/ Competition Pkg E-TEC 850 Turbo R', 
'MX Z X E-TEC 850', 
'MX Z X E-TEC 850 137', 
'Renegade Adrenaline E-TEC 850', 
'Renegade Adrenaline w/ Enduro Pkg E-TEC 850', 
'Renegade Backcountry E-TEC 850', 
'Renegade Backcountry X E-TEC 850', 
'Renegade Enduro E-TEC 850', 
'Renegade X-RS E-TEC 850', 
'Renegade X E-TEC 850', 
'Summit Adrenaline E-TEC 850 146', 
'Summit Adrenaline E-TEC 850 154', 
'Summit Adrenaline w/ Edge Package E-TEC 850 146', 
'Summit Adrenaline w/ Edge Package E-TEC 850 154', 
'Summit Adrenaline w/ Edge Package E-TEC 850 165', 
'Summit Edge E-TEC 850 154', 
'Summit Edge E-TEC 850 165', 
'Summit Edge E-TEC 850 175', 
'Summit SP E-TEC 850 146', 
'Summit SP E-TEC 850 154', 
'Summit SP E-TEC 850 165', 
'Summit SP E-TEC 850 175', 
'Summit X E-TEC 850 154', 
'Summit X E-TEC 850 165', 
'Summit X E-TEC 850 175', 
'Summit X E-TEC 850 Turbo 154', 
'Summit X E-TEC 850 Turbo 165', 
'Summit X E-TEC 850 Turbo R 154', 
'Summit X E-TEC 850 Turbo R 165', 
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5', 
'Summit X with Expert Package E-TEC 850 154', 
'Summit X with Expert Package E-TEC 850 154 2.5', 
'Summit X with Expert Package E-TEC 850 165', 
'Summit X with Expert Package E-TEC 850 175', 
'Summit X with Expert Package E-TEC 850 Turbo 154', 
'Summit X with Expert Package E-TEC 850 Turbo 165', 
'Summit X with Expert Package E-TEC 850 Turbo 175', 
'Summit X with Expert Package E-TEC 850 Turbo R 154', 
'Summit X with Expert Package E-TEC 850 Turbo R 165', 
'Summit X with Expert Package E-TEC 850 Turbo R 175', 
 
]

years = list(range(1999, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make                                              Model  Year Vendor  \
# 0     SKI-DOO                                      MX Z 440 LC X  1999
# 1     SKI-DOO                                      MX Z 440 LC X  2000
# 2     SKI-DOO                                      MX Z 440 LC X  2001
# 3     SKI-DOO                                      MX Z 440 LC X  2002
# 4     SKI-DOO                                      MX Z 440 LC X  2003
# ...       ...                                                ...   ...    ...
# 4370  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...  2019
# 4371  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...  2020
# 4372  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...  2021
# 4373  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...  2022
# 4374  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...  2023
#
#      Vendor Code Position       MPN     SKU        Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09021 skidoo bombardier.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='SKI-DOO',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09022',
    sku='128180',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 40; OD: 80; WIDTH: 23; OEM#: 420832700, 420832702; Matched - NOTE : KOYO BEARING. '
)

list_models = [
    


'Expedition LE E-TEC 600 HO', 
'Expedition SE E-TEC 600 HO', 
'Grand Touring LE E-TEC 600 HO', 
'GSX LE E-TEC 600 HO', 
'GSX SE E-TEC 600 HO', 
'MX Z Blizzard E-TEC 600 HO', 
'MX Z TNT E-TEC 600 HO', 
'MX Z X E-TEC 600 HO', 
'MX Z X-RS E-TEC 600 HO', 
'MX Z X-RS Iron Dog E-TEC 600 HO', 
'Renegade Adrenaline E-TEC 600 HO', 
'Renegade Backcountry E-TEC 600 HO', 
'Renegade Backcountry X E-TEC 600 HO', 
'Renegade Enduro E-TEC 600 HO', 
'Renegade X E-TEC 600 HO', 
'Skandic SWT E-TEC 600 HO', 
'Skandic WT E-TEC 600 HO', 
'Summit Everest E-TEC 600 HO', 
'Summit SP E-TEC 600 HO 146', 
'Summit SP E-TEC 600 HO 154', 
'Summit X E-TEC 600 HO', 
'Backcountry Adrenaline E-TEC 600R', 
'Backcountry E-TEC 600R', 
'Expedition LE E-TEC 600R', 
'Expedition SE E-TEC 600R', 
'Expedition SWT E-TEC 600R', 
'Grand Touring Limited E-TEC 600R', 
'MX Z Adrenaline E-TEC 600R', 
'MX Z Adrenaline E-TEC 600R 137', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 600R', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 600R 137', 
'MX Z Blizzard E-TEC 600R', 
'MX Z TNT E-TEC 600R', 
'MX Z X-RS E-TEC 600R', 
'MX Z X-RS E-TEC 600R 137', 
'MX Z X E-TEC 600R', 
'MX Z X-RS w/ Competition Pkg E-TEC 600R', 
'MX Z X E-TEC 600R 137', 
'Renegade Adrenaline E-TEC 600R', 
'Renegade Adrenaline w/ Enduro Pkg E-TEC 600R', 
'Renegade Enduro E-TEC 600R', 
'Renegade X-RS with Comp Package E-TEC 600R', 
'Renegade X E-TEC 600R', 
'Skandic LE E-TEC 600R', 
'Skandic SE E-TEC 600R', 
'Skandic SWT E-TEC 600R', 
'Skandic WT E-TEC 600R', 
'Summit Adrenaline E-TEC 600R 146', 
'Summit Adrenaline E-TEC 600R 154', 
'Summit Adrenaline w/ Edge Package E-TEC 600R 146', 
'Summit Adrenaline w/ Edge Package E-TEC 600R 154', 
'Summit SP E-TEC 600R 146', 
'Summit SP E-TEC 600R 154', 
'MX Z 700', 
'MX Z 700 Adrenaline', 
'MX Z 700 R Sport', 
'MX Z 700 R X', 
'MX Z 700 Renegade', 
'MX Z 700 Sport', 
'MX Z 700 Trail', 
'MX Z 700 X', 
'Summit 700', 
'Summit 700 Adrenaline', 
'Summit 700 Highmark', 
'Summit 700 R Sport', 
'Summit 700 Sport', 
'Summit 700 X', 
'Outlander 800 HO EFI 4x4', 
'Outlander 800 HO EFI 4x4 XT', 
'Outlander Max 800 HO EFI 4x4', 
'Outlander Max 800 HO EFI 4x4 XT', 
'Legend 800 SE SDI', 
'Expedition Xtreme E-TEC 800R', 
'Freeride E-TEC 800R 137', 
'Freeride E-TEC 800R 146', 
'Freeride E-TEC 800R 154', 
'GSX SE E-TEC 800R', 
'MX Z Blizzard E-TEC 800R', 
'MX Z TNT E-TEC 800R', 
'MX Z X E-TEC 800R', 
'MX Z X-RS E-TEC 800R', 
'Renegade Adrenaline E-TEC 800R', 
'Renegade Backcountry E-TEC 800R', 
'Renegade Backcountry X E-TEC 800R', 
'Renegade Enduro E-TEC 800R', 
'Renegade X E-TEC 800R', 
'Renegade X-RS E-TEC 800R', 
'Summit Burton E-TEC 800R', 
'Summit Everest E-TEC 800R', 
'Summit Freeride E-TEC 800R', 
'Summit SP E-TEC 800R 146', 
'Summit SP E-TEC 800R 154', 
'Summit SP E-TEC 800R 163', 
'Summit SP E-TEC 800R 174', 
'Summit SP T3 Package E-TEC 800R 154', 
'Summit SP T3 Package E-TEC 800R 163', 
'Summit SP T3 Package E-TEC 800R 174', 
'Summit X E-TEC 800R 146', 
'Summit X E-TEC 800R 154', 
'Summit X E-TEC 800R 163', 
'Summit X E-TEC 800R 174', 
'Summit X T3 Package E-TEC 800R 154', 
'Summit X T3 Package E-TEC 800R 163', 
'Summit X T3 Package E-TEC 800R 174', 
'MX Z TNT 800R Power TEC', 
 
]

years = list(range(2000, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#          Make                       Model  Year Vendor Vendor Code Position  \
# 0     SKI-DOO  Expedition LE E-TEC 600 HO  2000
# 1     SKI-DOO  Expedition LE E-TEC 600 HO  2001
# 2     SKI-DOO  Expedition LE E-TEC 600 HO  2002
# 3     SKI-DOO  Expedition LE E-TEC 600 HO  2003
# 4     SKI-DOO  Expedition LE E-TEC 600 HO  2004
# ...       ...                         ...   ...    ...         ...      ...
# 2515  SKI-DOO     MX Z TNT 800R Power TEC  2019
# 2516  SKI-DOO     MX Z TNT 800R Power TEC  2020
# 2517  SKI-DOO     MX Z TNT 800R Power TEC  2021
# 2518  SKI-DOO     MX Z TNT 800R Power TEC  2022
# 2519  SKI-DOO     MX Z TNT 800R Power TEC  2023
#
#            MPN     SKU        Product Type  \
# 0     UP-09022  128180  CRANKSHAFT BEARING
# 1     UP-09022  128180  CRANKSHAFT BEARING
# 2     UP-09022  128180  CRANKSHAFT BEARING
# 3     UP-09022  128180  CRANKSHAFT BEARING
# 4     UP-09022  128180  CRANKSHAFT BEARING
# ...        ...     ...                 ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09022skidoo.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='POLARIS',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09024',
    sku='129195',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72; WIDTH: 17; OEM#: 3514361, 3585501, 3585503; Matched - NOTE : KOYO BEARING. '
)

list_models = [
    


'440 IQ', 
'440 Pro X', 
'440 Pro X Fan', 
'440 Pro XR', 
'440 XC', 
'440 XC SP', 
'440 XCR', 
'440 XCR SP', 
'500 Classic', 
'500 Classic Touring', 
'500 XC', 
'500 XC SP', 
'600 Classic', 
'600 Classic Touring', 
'600 Dragon SwitchBack', 
'600 HO CFI SwitchBack', 
'600 HO CFI Touring', 
'600 HO Fusion', 
'600 HO IQ', 
'600 HO IQ CFI', 
'600 HO IQ LX CFI', 
'600 HO IQ Touring', 
'600 PRO X', 
'600 RMK', 
'600 RMK 144', 
'600 RMK 155', 
'600 RR', 
'600 Touring', 
'600 XC', 
'600 XC Deluxe', 
'600 XC SP', 
'700 PRO X', 
'700 PRO X2', 
'800 PRO X', 
'800 PRO X2', 
'700 Classic', 
'700 Classic Touring', 
'700 RMK 144', 
'700 RMK 151', 
'700 RMK 155', 
'700 RMK 159', 
'700 SKS', 
'700 XC', 
'700 XC Deluxe', 
'700 XC SP', 
'800 Classic', 
'800 Classic Touring', 
'800 LE', 
'800 PRO XR', 
'800 RMK', 
'800 RMK 144', 
'800 RMK 155', 
'800 RMK SP 144', 
'800 RMK SP 151', 
'800 XC', 
'800 XC SP', 
'700 Fusion', 
'900 Fusion', 
'900 RMK', 
'900 SwitchBack', 
'700 RMK', 
'Frontier Classic', 


 
]

years = list(range(1997, 2010))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make             Model  Year Vendor Vendor Code Position       MPN  \
# 0    POLARIS            440 IQ  1997                              UP-09024
# 1    POLARIS            440 IQ  1998                              UP-09024
# 2    POLARIS            440 IQ  1999                              UP-09024
# 3    POLARIS            440 IQ  2000                              UP-09024
# 4    POLARIS            440 IQ  2001                              UP-09024
# ..       ...               ...   ...    ...         ...      ...       ...
# 801  POLARIS  Frontier Classic  2005                              UP-09024
# 802  POLARIS  Frontier Classic  2006                              UP-09024
# 803  POLARIS  Frontier Classic  2007                              UP-09024
# 804  POLARIS  Frontier Classic  2008                              UP-09024
# 805  POLARIS  Frontier Classic  2009                              UP-09024
#
#         SKU        Product Type  \
# 0    129195  CRANKSHAFT BEARING
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09024POLARIS.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='POLARIS',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='UP-09025',
    sku='128620',
    pro_type='CRANKSHAFT BEARING',
    vendornotes='ID: 35; OD: 72; WIDTH: 17; OEM#: 3513520, 3514318; Matched - NOTE : KOYO BEARING. CENTER BEARING – 1 PER MACHINE '
)

list_models = [
    
'600 PRO X', 
'600 PRO X2', 
'600 XC', 
'600 XC Deluxe', 
'600 XC SP', 
'700 PRO X', 
'700 PRO X2', 
'800 PRO X', 
'800 PRO X2', 
'700 Classic', 
'700 Classic Touring', 
'700 RMK 144', 
'700 RMK 151', 
'700 SKS', 
'700 XC', 
'700 XC Deluxe', 
'700 XC SP', 
'800 Classic', 
'800 Classic Touring', 
'800 LE', 
'800 PRO XR', 
'800 RMK', 
'800 RMK 144', 
'800 RMK 155', 
'800 RMK SP 144', 
'800 RMK SP 151', 
'800 XC', 
'800 XC SP', 
'700 Fusion', 
'900 Fusion', 
'Frontier Classic', 
'Sportsman Forest 800 6x6', 
'Frontier Touring', 
'MSX 140', 



 
]

years = list(range(1996, 2016))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make      Model  Year Vendor Vendor Code Position       MPN     SKU  \
# 0    POLARIS  600 PRO X  1996                              UP-09025  128620
# 1    POLARIS  600 PRO X  1997                              UP-09025  128620
# 2    POLARIS  600 PRO X  1998                              UP-09025  128620
# 3    POLARIS  600 PRO X  1999                              UP-09025  128620
# 4    POLARIS  600 PRO X  2000                              UP-09025  128620
# ..       ...        ...   ...    ...         ...      ...       ...     ...
# 675  POLARIS    MSX 140  2011                              UP-09025  128620
# 676  POLARIS    MSX 140  2012                              UP-09025  128620
# 677  POLARIS    MSX 140  2013                              UP-09025  128620
# 678  POLARIS    MSX 140  2014                              UP-09025  128620
# 679  POLARIS    MSX 140  2015                              UP-09025  128620
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(06)SECTION 09 - CRANKSHAFT BEARING ( 06-28-23 )\Merged Crank\UP-09025POLARIS.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-710303E',
    sku='127971',
    pro_type='Exhaust Valve Gasket',
    vendornotes=' OEM#: 420430032; DESC: GASKET; QTY: 2- OEM#: 420950730; DESC: SEAL; QTY: 2- OEM#: 420431380; DESC: SEAL; QTY: 2- OEM#: 420931765; DESC: O-RING; QTY: 2'
)

list_models = [
    
'Expedition LE E-TEC 600 HO', 
'Expedition SE E-TEC 600 HO', 
'Grand Touring LE E-TEC 600 HO', 
'GSX LE E-TEC 600 HO', 
'GSX SE E-TEC 600 HO', 
'MX Z Blizzard E-TEC 600 HO', 
'MX Z TNT E-TEC 600 HO', 
'MX Z X E-TEC 600 HO', 
'MX Z X-RS E-TEC 600 HO', 
'MX Z X-RS Iron Dog E-TEC 600 HO', 
'Renegade Adrenaline E-TEC 600 HO', 
'Renegade Backcountry E-TEC 600 HO', 
'Renegade Backcountry X E-TEC 600 HO', 
'Renegade Enduro E-TEC 600 HO', 
'Renegade X E-TEC 600 HO', 
'Skandic SWT E-TEC 600 HO', 
'Skandic WT E-TEC 600 HO', 
'Summit Everest E-TEC 600 HO', 
'Summit SP E-TEC 600 HO 146', 
'Summit SP E-TEC 600 HO 154', 
'Summit X E-TEC 600 HO', 





 
]

years = list(range(2010, 2021))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                       Model  Year Vendor Vendor Code Position  \
# 0    Ski-Doo  Expedition LE E-TEC 600 HO  2010
# 1    Ski-Doo  Expedition LE E-TEC 600 HO  2011
# 2    Ski-Doo  Expedition LE E-TEC 600 HO  2012
# 3    Ski-Doo  Expedition LE E-TEC 600 HO  2013
# 4    Ski-Doo  Expedition LE E-TEC 600 HO  2014
# ..       ...                         ...   ...    ...         ...      ...
# 226  Ski-Doo       Summit X E-TEC 600 HO  2016
# 227  Ski-Doo       Summit X E-TEC 600 HO  2017
# 228  Ski-Doo       Summit X E-TEC 600 HO  2018
# 229  Ski-Doo       Summit X E-TEC 600 HO  2019
# 230  Ski-Doo       Summit X E-TEC 600 HO  2020
#
#             MPN     SKU          Product Type  \
# 0    09-710303E  127971  Exhaust Valve Gasket
# 1    09-710303E  127971  Exhaust Valve Gasket
# 2    09-710303E  127971  Exhaust Valve Gasket
# 3    09-710303E  127971  Exhaust Valve Gasket
# 4    09-710303E  127971  Exhaust Valve Gasket
# ..          ...     ...                   ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-710303E.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719103',
    sku='127821',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 3006-329; DESC: GASKET; QTY: 2 -  OEM#: 3006-436 ; DESC: GASKET; QTY: 2 -  OEM#: 3006-322; DESC: SEAL; QTY: 2 -  OEM#: 3005-226 ; DESC: O-RING; QTY: 2'
)

list_models = [
   'F5 EFI', 
'F5 EFI LXR', 
'F5 Firecat', 
'F5 Firecat Sno Pro', 
'Crossfire 600 EFI', 
'Crossfire 600 EFI Sno Pro', 
'Crossfire 700 EFI', 
'Crossfire 700 EFI Early Build', 
'Crossfire 700 EFI Sno Pro', 
'Crossfire 800 EFI', 
'Crossfire 800 EFI Limited', 
'Crossfire 800 EFI Sno Pro', 
'Crossfire 800 EFI Sno Pro LE', 
'Crossfire 1000 EFI', 
'Crossfire 1000 EFI Sno Pro', 
'Crossfire 1000 Sno Pro LE', 
'F6 Firecat', 
'F6 Firecat EFI', 
'F6 Firecat EFI Early Build', 
'F6 Firecat EFI EXT', 
'F6 Firecat EFI R', 
'F6 Firecat EFI Sno Pro', 
'F6 Firecat Sno Pro', 
'F7 Firecat', 
'F7 Firecat EFI', 
'F7 Firecat EFI EXT', 
'F7 Firecat EFI R', 
'F7 Firecat EFI Sno Pro', 
'F7 Firecat EFI Tony Stewart', 
'F7 Firecat Sno Pro', 
'F1000 EFI', 
'F1000 EFI LXR', 
'F1000 EFI Sno Pro', 
'M1000 EFI 153', 
'M1000 EFI 153 Sno Pro', 
'M1000 EFI 162', 
'M1000 EFI 162 Sno Pro', 
'M1000 EFI 162 Sno Pro LE', 
'Mountain Cat 600 EFI', 
'Mountain Cat 600 EFI 136', 
'Mountain Cat 600 EFI 144', 
'M6 EFI 141', 
'M6 EFI 153', 
'M7 153', 
'M7 EFI 141', 
'M7 EFI 153', 
'M7 EFI 162', 
'M7 EFI LE', 
'M7 EFI LE 153', 
'M7 EFI LE 162', 
'M8 153', 
'M8 153 Limited', 
'M8 153 Sno Pro LE', 
'M8 162', 
'M8 EFI 141', 
'M8 EFI 153', 
'M8 EFI 153 Sno Pro', 
'M8 EFI 153 Sno Pro LE', 
'M8 EFI 162', 
'M8 EFI 162 Sno Pro', 
'M8 HCR 153', 
'M8 Sno Pro 153', 
'M8 Sno Pro 162', 
'Sabercat 600', 
'Sabercat 600 EFI', 
'Sabercat 600 EFI EXT', 
'Sabercat 600 EFI LX', 
'Sabercat 600 LX', 
'Sabercat 700 EFI', 
'Sabercat 700 EFI EXT', 
'Sabercat 700 EFI LX', 

   




   


]

years = list(range(2003, 2013))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#            Make                Model  Year Vendor Vendor Code Position  \
# 0    Arctic Cat               F5 EFI  2003
# 1    Arctic Cat               F5 EFI  2004
# 2    Arctic Cat               F5 EFI  2005
# 3    Arctic Cat               F5 EFI  2006
# 4    Arctic Cat               F5 EFI  2007
# ..          ...                  ...   ...    ...         ...      ...
# 705  Arctic Cat  Sabercat 700 EFI LX  2008
# 706  Arctic Cat  Sabercat 700 EFI LX  2009
# 707  Arctic Cat  Sabercat 700 EFI LX  2010
# 708  Arctic Cat  Sabercat 700 EFI LX  2011
# 709  Arctic Cat  Sabercat 700 EFI LX  2012
#
#            MPN     SKU           Product Type  \
# 0    09-719103  127821  Exhaust Valve Gaskets
# 1    09-719103  127821  Exhaust Valve Gaskets
# 2    09-719103  127821  Exhaust Valve Gaskets
# 3    09-719103  127821  Exhaust Valve Gaskets
# 4    09-719103  127821  Exhaust Valve Gaskets
# ..         ...     ...                    ...
# 705  09-719103  127821  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719103.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719104',
    sku='62-09025',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 5812700; DESC: O-RING; QTY: 2'
)

list_models = [
'700 Classic', 
'700 Fusion', 
'700 HO Touring', 
'700 RMK', 
'700 RMK 144', 
'700 RMK 151', 
'700 RMK 159', 
'900 Fusion', 
'900 RMK', 
'900 SwitchBack', 


   




   


]

years = list(range(2005, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make           Model  Year Vendor Vendor Code Position        MPN  \
# 0   Polaris     700 Classic  2005                              09-719104
# 1   Polaris     700 Classic  2006                              09-719104
# 2   Polaris      700 Fusion  2005                              09-719104
# 3   Polaris      700 Fusion  2006                              09-719104
# 4   Polaris  700 HO Touring  2005                              09-719104
# 5   Polaris  700 HO Touring  2006                              09-719104
# 6   Polaris         700 RMK  2005                              09-719104
# 7   Polaris         700 RMK  2006                              09-719104
# 8   Polaris     700 RMK 144  2005                              09-719104
# 9   Polaris     700 RMK 144  2006                              09-719104
# 10  Polaris     700 RMK 151  2005                              09-719104
# 11  Polaris     700 RMK 151  2006                              09-719104
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719104.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719105',
    sku='127822',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 3086122; DESC: GASKET; QTY: 3'
)

list_models = [
'700 Classic', 
'700 Fusion', 
'700 HO Touring', 
'700 RMK', 
'700 RMK 144', 
'700 RMK 151', 
'700 RMK 159', 
'900 Fusion', 
'900 RMK', 
'900 SwitchBack', 


   




   


]

years = list(range(1999, 2004))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make           Model  Year Vendor Vendor Code Position        MPN  \
# 0   Polaris     700 Classic  1999                              09-719105
# 1   Polaris     700 Classic  2000                              09-719105
# 2   Polaris     700 Classic  2001                              09-719105
# 3   Polaris     700 Classic  2002                              09-719105
# 4   Polaris     700 Classic  2003                              09-719105
# 5   Polaris      700 Fusion  1999                              09-719105
# 6   Polaris      700 Fusion  2000                              09-719105
# 7   Polaris      700 Fusion  2001                              09-719105
# 8   Polaris      700 Fusion  2002                              09-719105
# 9   Polaris      700 Fusion  2003                              09-719105
# 10  Polaris  700 HO Touring  1999                              09-719105
# 11  Polaris  700 HO Touring  2000                              09-719105
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719105.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719106',
    sku='62-09026',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='  OEM#: 5811807; DESC: GASKET; QTY: 2;  OEM#: 5433375; DESC: GASKET; QTY: 2'
)

list_models = [
'440 Pro X', 
'440 Pro X Fan', 
'500 XC SP', 
'600 PRO X', 
'600 Touring', 
'600 XC SP', 

]

years = list(range(2000, 2006))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make          Model  Year Vendor Vendor Code Position        MPN  \
# 0   Polaris      440 Pro X  2000                              09-719106
# 1   Polaris      440 Pro X  2001                              09-719106
# 2   Polaris      440 Pro X  2002                              09-719106
# 3   Polaris      440 Pro X  2003                              09-719106
# 4   Polaris      440 Pro X  2004                              09-719106
# 5   Polaris      440 Pro X  2005                              09-719106
# 6   Polaris  440 Pro X Fan  2000                              09-719106
# 7   Polaris  440 Pro X Fan  2001                              09-719106
# 8   Polaris  440 Pro X Fan  2002                              09-719106
# 9   Polaris  440 Pro X Fan  2003                              09-719106
# 10  Polaris  440 Pro X Fan  2004                              09-719106
# 11  Polaris  440 Pro X Fan  2005                              09-719106
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719106.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719107',
    sku='62-09027',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 5813934; DESC: GASKET; QTY: 2 -  OEM#: 5812350; DESC: GASKET; QTY: 2'
)

list_models = [
'500 XC SP', 
'600 Classic', 
'600 Classic Touring', 
'600 PRO X', 
'600 RMK', 
'600 XC SP', 
'600 HO IQ', 
'600 HO IQ CFI', 
'600 HO IQ LX CFI', 
'600 INDY', 
'600 INDY SP', 
'600 INDY SP 129', 
'600 INDY SP 137', 
'600 INDY SP LE', 
'600 INDY SP TD Series LE', 
'600 INDY Voyager', 
'600 INDY Voyageur', 
'600 INDY XCR', 
'600 IQ', 
'600 IQ LXT', 
'600 IQ Racer', 
'600 PRO-RMK 155', 
'600 Rush PRO-R', 
'600 Rush PRO-S', 
'600 Rush XCR', 
'600 SwitchBack Adventure', 
'600 SwitchBack Assault 144', 
'600 SwitchBack PRO-R', 
'600 SwitchBack PRO-S', 
'600 SwitchBack XCR', 
'600 Touring', 
'600 Voyageur 144', 
'600 XC', 
'Wide Track IQ 600', 


]

years = list(range(2002, 2023))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make              Model  Year Vendor Vendor Code Position        MPN  \
# 0    Polaris          500 XC SP  2002                              09-719107
# 1    Polaris          500 XC SP  2003                              09-719107
# 2    Polaris          500 XC SP  2004                              09-719107
# 3    Polaris          500 XC SP  2005                              09-719107
# 4    Polaris          500 XC SP  2006                              09-719107
# ..       ...                ...   ...    ...         ...      ...        ...
# 709  Polaris  Wide Track IQ 600  2018                              09-719107
# 710  Polaris  Wide Track IQ 600  2019                              09-719107
# 711  Polaris  Wide Track IQ 600  2020                              09-719107
# 712  Polaris  Wide Track IQ 600  2021                              09-719107
# 713  Polaris  Wide Track IQ 600  2022                              09-719107
#
#           SKU           Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719107.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719111',
    sku='127825',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420230256; DESC: GASKET; QTY: 2-OEM#: 420430110; DESC: O-RING; QTY: 2'
)

list_models = [
'Formula 583', 
'Formula Deluxe 583', 
'Formula Z 583', 
'Grand Touring 583', 
'MX Z 583', 
'Summit 583', 
'Formula Deluxe 670', 
'Formula Z 670', 
'MX Z 670', 
'Summit 670', 
'Summit 670 X', 

]

years = list(range(1997, 2000))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make               Model  Year Vendor Vendor Code Position        MPN  \
# 0   Ski-Doo         Formula 583  1997                              09-719111
# 1   Ski-Doo         Formula 583  1998                              09-719111
# 2   Ski-Doo         Formula 583  1999                              09-719111
# 3   Ski-Doo  Formula Deluxe 583  1997                              09-719111
# 4   Ski-Doo  Formula Deluxe 583  1998                              09-719111
# 5   Ski-Doo  Formula Deluxe 583  1999                              09-719111
# 6   Ski-Doo       Formula Z 583  1997                              09-719111
# 7   Ski-Doo       Formula Z 583  1998                              09-719111
# 8   Ski-Doo       Formula Z 583  1999                              09-719111
# 9   Ski-Doo   Grand Touring 583  1997                              09-719111
# 10  Ski-Doo   Grand Touring 583  1998                              09-719111
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719111.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719112',
    sku='127826',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420250239; DESC: GASKET; QTY: 3-OEM#: 420430110; DESC: O-RING; QTY: 3'
)

list_models = [
'Formula III 600', 
'Formula III 600 LT', 
'Formula III 600 R', 
'Formula III 700', 
'Formula III 700 R', 
'Grand Touring 700', 
'Mach 1', 
'Mach 1R', 
'Formula III 800', 
'Mach Z', 
'Mach Z LT', 
'Mach Z LT R', 


]

years = list(range(1997, 2000))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make               Model  Year Vendor Vendor Code Position        MPN  \
# 0   Ski-Doo     Formula III 600  1997                              09-719112
# 1   Ski-Doo     Formula III 600  1998                              09-719112
# 2   Ski-Doo     Formula III 600  1999                              09-719112
# 3   Ski-Doo  Formula III 600 LT  1997                              09-719112
# 4   Ski-Doo  Formula III 600 LT  1998                              09-719112
# 5   Ski-Doo  Formula III 600 LT  1999                              09-719112
# 6   Ski-Doo   Formula III 600 R  1997                              09-719112
# 7   Ski-Doo   Formula III 600 R  1998                              09-719112
# 8   Ski-Doo   Formula III 600 R  1999                              09-719112
# 9   Ski-Doo     Formula III 700  1997                              09-719112
# 10  Ski-Doo     Formula III 700  1998                              09-719112
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719112.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719113',
    sku='127823',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 420250239; DESC: GASKET; QTY: 2- OEM#: 420430110; DESC: O-RING; QTY: 2'
)

list_models = [
'Formula 500', 
'Formula 500 LC', 
'Formula Z 700', 
'Grand Touring 600', 
'Grand Touring 600 GS', 
'Grand Touring 600 SE', 
'Grand Touring 600 Sport', 
'MX Z 440 Fan', 
'MX Z 440 LC', 
'MX Z 440 LC X', 
'MX Z 440 X', 
'MX Z 500', 
'MX Z 500 Adrenaline', 
'MX Z 500 Fan', 
'MX Z 500 R Sport', 
'MX Z 500 Sport', 
'MX Z 500 Trail', 
'MX Z 600', 
'MX Z 600 Adrenaline', 
'MX Z 600 R Sport', 
'MX Z 600 R X', 
'MX Z 600 Renegade', 
'MX Z 600 Sport', 
'MX Z 600 Trail', 
'MX Z 600 X', 
'MX Z 700', 
'MX Z 700 Adrenaline', 
'MX Z 700 R Sport', 
'MX Z 700 R X', 
'MX Z 700 Renegade', 
'MX Z 700 Sport', 
'MX Z 700 Trail', 
'MX Z 700 X', 
'Skandic 500', 
'Skandic 500 Sport', 
'Skandic 500 SWT', 
'Skandic 500 WT', 
'Summit 500', 
'Summit 500 Fan', 
'Touring 500 Fan', 
'Touring 500 LC', 
'Skandic 600 SUV', 
'Skandic 600 WT', 
'Summit 600', 
'Summit 600 Adrenaline', 
'Summit 600 R Sport', 
'Summit 600 Sport', 



]

years = list(range(1995, 2004))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make             Model  Year Vendor Vendor Code Position        MPN  \
# 0    Ski-Doo       Formula 500  1995                              09-719113
# 1    Ski-Doo       Formula 500  1996                              09-719113
# 2    Ski-Doo       Formula 500  1997                              09-719113
# 3    Ski-Doo       Formula 500  1998                              09-719113
# 4    Ski-Doo       Formula 500  1999                              09-719113
# ..       ...               ...   ...    ...         ...      ...        ...
# 418  Ski-Doo  Summit 600 Sport  1999                              09-719113
# 419  Ski-Doo  Summit 600 Sport  2000                              09-719113
# 420  Ski-Doo  Summit 600 Sport  2001                              09-719113
# 421  Ski-Doo  Summit 600 Sport  2002                              09-719113
# 422  Ski-Doo  Summit 600 Sport  2003                              09-719113
#
#         SKU           Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719113.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719114',
    sku='62-09028',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 420250239; DESC: GASKET; QTY: 2- OEM#: 420430110; DESC: O-RING; QTY: 2- OEM#: 420950730; DESC: SEAL; QTY: 2'
)

list_models = [
'GSX 500SS Sport', 
'Formula 500 LC', 
'Formula Deluxe 500', 
'Formula Deluxe 500 Fan', 
'Formula Deluxe 500 LC', 
'Formula Deluxe 600', 
'Formula Deluxe 600 GSE', 
'Grand Touring 500', 
'Grand Touring 500 Sport', 
'MX Z 500', 
'MX Z 500 Adrenaline', 
'MX Z 500 Fan', 
'MX Z 500 R Sport', 
'MX Z 500 R Trail', 
'MX Z 500 Renegade', 
'MX Z 500 Sport', 
'MX Z 500 TNT', 
'MX Z 500 Trail', 
'MX Z 500 X', 
'MX Z 600', 
'MX Z 600 50th Anniversary', 
'MX Z 600 Adrenaline', 
'MX Z 600 Blizzard', 
'MX Z 600 R Sport', 
'MX Z 600 R X', 
'MX Z 600 Renegade', 
'MX Z 600 Renegade X', 
'MX Z 600 Sport', 
'MX Z 600 TNT', 
'MX Z 600 TNT Early Edition', 
'MX Z 600 Trail', 
'MX Z 600 X', 
'MX Z 600 X-RS', 
'MX Z 600RS', 
'Skandic 600 SUV', 
'Skandic 600 WT', 
'Skandic WT 600', 
'Summit 600', 
'Summit 600 Adrenaline', 
'Summit 600 Everest', 
'Summit 600 Everest 146', 
'Summit 600 R Sport', 
'Summit 600 Sport', 
'Summit 600 X', 
'Summit 600 X 154', 


]

years = list(range(2001, 2011))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make             Model  Year Vendor Vendor Code Position        MPN  \
# 0    Ski-Doo   GSX 500SS Sport  1995                              09-719114
# 1    Ski-Doo   GSX 500SS Sport  1996                              09-719114
# 2    Ski-Doo   GSX 500SS Sport  1997                              09-719114
# 3    Ski-Doo   GSX 500SS Sport  1998                              09-719114
# 4    Ski-Doo   GSX 500SS Sport  1999                              09-719114
# ..       ...               ...   ...    ...         ...      ...        ...
# 400  Ski-Doo  Summit 600 X 154  1999                              09-719114
# 401  Ski-Doo  Summit 600 X 154  2000                              09-719114
# 402  Ski-Doo  Summit 600 X 154  2001                              09-719114
# 403  Ski-Doo  Summit 600 X 154  2002                              09-719114
# 404  Ski-Doo  Summit 600 X 154  2003                              09-719114
#
#           SKU           Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719114.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719115',
    sku='62-09029',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 420931542; DESC: GASKET; QTY: 2- OEM#: 420430110; DESC: O-RING; QTY: 2- OEM#: 420430110; DESC: O-RING; QTY: 2'
)

list_models = [
'Expedition 600', 
'Expedition 600 SE', 
'Expedition 600 TUV REV-XU', 
'Expedition 600 TUV Yeti II', 
'Grand Touring 800 SE', 
'Legend 800 SE', 
'Legend 800 SE SDI', 
'Legend Touring V-800', 
'Legend Trail V-800', 
'MX Z 800', 
'MX Z 800 Adrenaline', 
'MX Z 800 Blizzard', 
'MX Z 800 R', 
'MX Z 800 R Adrenaline', 
'MX Z 800 R Sport', 
'MX Z 800 R X', 
'MX Z 800 Renegade', 
'MX Z 800 Renegade X', 
'MX Z 800 Sport', 
'MX Z 800 Trail', 
'MX Z 800 X', 
'MX Z 800 X-RS', 
'MX Z 800R Renegade', 
'MX Z 800R Renegade X', 
'MX Z X-RS 800R', 
'Summit 800', 
'Summit 800 Adrenaline 144', 
'Summit 800 Adrenaline 151', 
'Summit 800 Everest 146', 
'Summit 800 Everest 154', 
'Summit 800 Everest 163', 
'Summit 800 Foothill', 
'Summit 800 Highmark', 
'Summit 800 Highmark X', 
'Summit 800 Highmark Xtreme', 
'Summit 800 Hill Climb', 
'Summit 800 R 50th Anniversary', 
'Summit 800 R Everest', 
'Summit 800 R Highmark', 
'Summit 800 R Highmark X', 
'Summit 800 R Sport', 
'Summit 800 R X', 
'Summit 800 Sport', 
'Summit 800 X', 
'Summit 800 X 144', 
'Summit 800 X 146', 
'Summit 800 X 151', 
'Summit 800 X 154', 
'Summit 800 X 159', 
'Summit 800 X 163', 
'Summit 800 XRS 151', 
'Summit 800 XRS 159', 
'MX Z 600', 
'MX Z 600 50th Anniversary', 
'MX Z 600 Adrenaline', 
'MX Z 600 Blizzard', 
'MX Z 600 R Sport', 
'MX Z 600 R X', 
'MX Z 600 Renegade', 
'MX Z 600 Renegade X', 
'MX Z 600 Sport', 
'MX Z 600 TNT', 
'MX Z 600 TNT Early Edition', 
'MX Z 600 Trail', 
'MX Z 600 X', 
'MX Z 600 X-RS', 
'MX Z 600RS', 

]

years = list(range(2001, 2011))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make           Model  Year Vendor Vendor Code Position        MPN  \
# 0    Ski-Doo  Expedition 600  2001                              09-719115
# 1    Ski-Doo  Expedition 600  2002                              09-719115
# 2    Ski-Doo  Expedition 600  2003                              09-719115
# 3    Ski-Doo  Expedition 600  2004                              09-719115
# 4    Ski-Doo  Expedition 600  2005                              09-719115
# ..       ...             ...   ...    ...         ...      ...        ...
# 665  Ski-Doo      MX Z 600RS  2006                              09-719115
# 666  Ski-Doo      MX Z 600RS  2007                              09-719115
# 667  Ski-Doo      MX Z 600RS  2008                              09-719115
# 668  Ski-Doo      MX Z 600RS  2009                              09-719115
# 669  Ski-Doo      MX Z 600RS  2010                              09-719115
#
#           SKU           Product Type  \
# 0    62-09029  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719115.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Yamaha',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719118',
    sku='127828',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 8DF-11354-03; DESC: GASKET; QTY: 3-OEM#: 8DF-11397-10; DESC: GASKET; QTY: 3-OEM#: 93109-15074; DESC: SEAL; QTY: 3-OEM#: 93210-09165; DESC: O-RING; QTY: 3-OEM#: 93210-06632 ; DESC: O-RING; QTY: 3'
)

list_models = [
'MSRX700 Mountain SRX 700', 
'SRX600', 
'SRX600S', 
'SRX700', 
'SRX700S', 
'SXV700 SX Viper', 
'SXV700 SX Viper S', 
'SXV700ER SX Viper ER', 
'SXV70MH SX Viper Mountain', 

]

years = list(range(1998, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#       Make             Model  Year Vendor Vendor Code Position        MPN  \
# 0  Ski-Doo            Mach Z  2001                              09-719116
# 1  Ski-Doo            Mach Z  2002                              09-719116
# 2  Ski-Doo            Mach Z  2003                              09-719116
# 3  Ski-Doo  Mach Z Tech Plus  2001                              09-719116
# 4  Ski-Doo  Mach Z Tech Plus  2002                              09-719116
# 5  Ski-Doo  Mach Z Tech Plus  2003                              09-719116
#
#       SKU           Product Type  \
# 0  127827  Exhaust Valve Gaskets
# 1  127827  Exhaust Valve Gaskets
# 2  127827  Exhaust Valve Gaskets
# 3  127827  Exhaust Valve Gaskets
# 4  127827  Exhaust Valve Gaskets
# 5  127827  Exhaust Valve Gaskets
#
#                                         Vendor Notes
# 0   OEM#: 420250239; DESC: GASKET; QTY: 3- OEM#: ...
# 1   OEM#: 420250239; DESC: GASKET; QTY: 3- OEM#: ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719116.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Yamaha',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719118',
    sku='127828',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 8DF-11354-03; DESC: GASKET; QTY: 3-OEM#: 8DF-11397-10; DESC: GASKET; QTY: 3-OEM#: 93109-15074; DESC: SEAL; QTY: 3-OEM#: 93210-09165; DESC: O-RING; QTY: 3-OEM#: 93210-06632 ; DESC: O-RING; QTY: 3'
)

list_models = [
'MSRX700 Mountain SRX 700', 
'SRX600', 
'SRX600S', 
'SRX700', 
'SRX700S', 
'SXV700 SX Viper', 
'SXV700 SX Viper S', 
'SXV700ER SX Viper ER', 
'SXV70MH SX Viper Mountain', 

]

years = list(range(1998, 2007))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#       Make                      Model  Year Vendor Vendor Code Position  \
# 0   Yamaha   MSRX700 Mountain SRX 700  1998
# 1   Yamaha   MSRX700 Mountain SRX 700  1999
# 2   Yamaha   MSRX700 Mountain SRX 700  2000
# 3   Yamaha   MSRX700 Mountain SRX 700  2001
# 4   Yamaha   MSRX700 Mountain SRX 700  2002
# ..     ...                        ...   ...    ...         ...      ...
# 76  Yamaha  SXV70MH SX Viper Mountain  2002
# 77  Yamaha  SXV70MH SX Viper Mountain  2003
# 78  Yamaha  SXV70MH SX Viper Mountain  2004
# 79  Yamaha  SXV70MH SX Viper Mountain  2005
# 80  Yamaha  SXV70MH SX Viper Mountain  2006
#
#           MPN     SKU           Product Type  \
# 0   09-719118  127828  Exhaust Valve Gaskets
# 1   09-719118  127828  Exhaust Valve Gaskets
# 2   09-719118  127828  Exhaust Valve Gaskets
# 3   09-719118  127828  Exhaust Valve Gaskets
# 4   09-719118  127828  Exhaust Valve Gaskets
# ..        ...     ...                    ...
# 76  09-719118  127828  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719118.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719119',
    sku='62-09030',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 5813934; DESC: GASKET; QTY: 2 -  OEM#: 5812350; DESC: GASKET; QTY: 2'
)

list_models = [
'600 HO CFI SwitchBack', 
'600 HO CFI Touring', 
'600 HO Fusion', 
'600 HO IQ', 
'600 HO IQ CFI', 
'600 HO IQ LX CFI', 
'600 HO IQ Touring', 
'600 IQ', 
'600 IQ LX', 
'600 IQ LXT', 
'600 IQ Shift', 
'600 IQ Shift 136', 
'600 IQ Touring', 
'600 IQ Widetrack', 
'600 RMK', 
'600 RMK 144', 
'600 RMK 155', 
'600 RR', 
'600 SwitchBack', 
'600 Dragon SwitchBack', 
'600 Rush PRO-R', 
'Wide Track IQ 600', 
'600 Shift 136', 
'600 Rush', 
'600 Rush LX', 
'700 Dragon', 
'700 Dragon IQ', 
'700 Dragon RMK 155', 
'700 Dragon RMK 163', 
'700 Dragon SwitchBack', 
'700 IQ', 
'700 SwitchBack', 
'700 RMK 144', 
'700 RMK 151', 
'700 RMK 155', 
'700 RMK 159', 
'800 Assault RMK 146', 
'800 Dragon RMK 155', 
'800 Dragon RMK 163', 
'800 PRO-RMK 155', 
'800 PRO-RMK 163', 
'800 RMK 144', 
'800 RMK 155', 
'800 RMK Assault 155', 
'800 Dragon IQ', 
'800 IQ', 
'550 IQ Shift', 
'IQ Shift', 


]

years = list(range(2006, 2012))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                  Model  Year Vendor Vendor Code Position  \
# 0    Polaris  600 HO CFI SwitchBack  2006
# 1    Polaris  600 HO CFI SwitchBack  2007
# 2    Polaris  600 HO CFI SwitchBack  2008
# 3    Polaris  600 HO CFI SwitchBack  2009
# 4    Polaris  600 HO CFI SwitchBack  2010
# ..       ...                    ...   ...    ...         ...      ...
# 283  Polaris               IQ Shift  2007
# 284  Polaris               IQ Shift  2008
# 285  Polaris               IQ Shift  2009
# 286  Polaris               IQ Shift  2010
# 287  Polaris               IQ Shift  2011
#
#            MPN       SKU           Product Type  \
# 0    09-719119  62-09030  Exhaust Valve Gaskets
# 1    09-719119  62-09030  Exhaust Valve Gaskets
# 2    09-719119  62-09030  Exhaust Valve Gaskets
# 3    09-719119  62-09030  Exhaust Valve Gaskets
# 4    09-719119  62-09030  Exhaust Valve Gaskets
# ..         ...       ...                    ...
# 283  09-719119  62-09030  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719119.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719203',
    sku='121628',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420931542; DESC: GASKET; QTY: 2-OEM#: 420430220; DESC: O-RING; QTY: 2-OEM#: 420430110; DESC: O-RING; QTY: 4'
)

list_models = [
'MX Z X E-TEC 600 HO', 
'MX Z X-RS 600', 
'MX Z X-RS E-TEC 600 HO', 
'MX Z X-RS Iron Dog E-TEC 600 HO', 



]

years = list(range(2006, 2018))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make                            Model  Year Vendor Vendor Code  \
# 0   Polaris              MX Z X E-TEC 600 HO  2006
# 1   Polaris              MX Z X E-TEC 600 HO  2007
# 2   Polaris              MX Z X E-TEC 600 HO  2008
# 3   Polaris              MX Z X E-TEC 600 HO  2009
# 4   Polaris              MX Z X E-TEC 600 HO  2010
# 5   Polaris              MX Z X E-TEC 600 HO  2011
# 6   Polaris              MX Z X E-TEC 600 HO  2012
# 7   Polaris              MX Z X E-TEC 600 HO  2013
# 8   Polaris              MX Z X E-TEC 600 HO  2014
# 9   Polaris              MX Z X E-TEC 600 HO  2015
# 10  Polaris              MX Z X E-TEC 600 HO  2016
# 11  Polaris              MX Z X E-TEC 600 HO  2017
# 12  Polaris                    MX Z X-RS 600  2006
# 13  Polaris                    MX Z X-RS 600  2007
# 14  Polaris                    MX Z X-RS 600  2008
# 15  Polaris                    MX Z X-RS 600  2009
# 16  Polaris                    MX Z X-RS 600  2010
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719203.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-719204',
    sku='121629',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 420430032; DESC: GASKET; QTY: 2- OEM#: 420931765; DESC: O-RING; QTY: 2- OEM#: 420431380; DESC: GASKET RING; QTY: 2'
)

list_models = [
'Expedition Xtreme E-TEC 800R', 
'Freeride E-TEC 800R 137', 
'Freeride E-TEC 800R 146', 
'Freeride E-TEC 800R 154', 
'GSX SE E-TEC 800R', 
'MX Z 800R Renegade', 
'MX Z 800R Renegade X', 
'MX Z Blizzard E-TEC 800R', 
'MX Z TNT 800R Power TEC', 
'MX Z TNT E-TEC 800R', 
'MX Z X E-TEC 800R', 
'MX Z X-RS 800R', 
'MX Z X-RS E-TEC 800R', 
'Renegade Adrenaline 800R Power TEK', 
'Renegade Adrenaline E-TEC 800R', 
'Renegade Backcountry 800R Power TEK', 
'Renegade Backcountry E-TEC 800R', 
'Renegade Backcountry X E-TEC 800R', 
'Renegade Enduro E-TEC 800R', 
'Renegade SP 800R Power TEK', 
'Renegade X E-TEC 800R', 
'Renegade X-RS E-TEC 800R', 
'Summit Burton E-TEC 800R', 
'Summit Everest 800R Power TEK 146', 
'Summit Everest 800R Power TEK 154', 
'Summit Everest 800R Power TEK 163', 
'Summit Everest E-TEC 800R', 
'Summit Freeride E-TEC 800R', 
'Summit SP E-TEC 800R 146', 
'Summit SP E-TEC 800R 154', 
'Summit SP E-TEC 800R 163', 
'Summit SP E-TEC 800R 174', 
'Summit SP T3 Package E-TEC 800R 154', 
'Summit SP T3 Package E-TEC 800R 163', 
'Summit SP T3 Package E-TEC 800R 174', 
'Summit Sport Power TEK 800R', 
'Summit X E-TEC 800R 146', 
'Summit X E-TEC 800R 154', 
'Summit X E-TEC 800R 163', 
'Summit X E-TEC 800R 174', 
'Summit X T3 Package E-TEC 800R 154', 
'Summit X T3 Package E-TEC 800R 163', 
'Summit X T3 Package E-TEC 800R 174', 




]

years = list(range(2007, 2018))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                               Model  Year Vendor Vendor Code  \
# 0    Ski-Doo        Expedition Xtreme E-TEC 800R  2007
# 1    Ski-Doo        Expedition Xtreme E-TEC 800R  2008
# 2    Ski-Doo        Expedition Xtreme E-TEC 800R  2009
# 3    Ski-Doo        Expedition Xtreme E-TEC 800R  2010
# 4    Ski-Doo        Expedition Xtreme E-TEC 800R  2011
# ..       ...                                 ...   ...    ...         ...
# 468  Ski-Doo  Summit X T3 Package E-TEC 800R 174  2013
# 469  Ski-Doo  Summit X T3 Package E-TEC 800R 174  2014
# 470  Ski-Doo  Summit X T3 Package E-TEC 800R 174  2015
# 471  Ski-Doo  Summit X T3 Package E-TEC 800R 174  2016
# 472  Ski-Doo  Summit X T3 Package E-TEC 800R 174  2017
#
#     Position        MPN     SKU           Product Type  \
# 0             09-719204  121629  Exhaust Valve Gaskets
# 1             09-719204  121629  Exhaust Valve Gaskets
# 2             09-719204  121629  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\09-719204.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='AU-09017E',
    sku='120865',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420254361; DESC: Exhaust Valve'
)

list_models = [
'Expedition 800 TUV Yeti II', 
'Expedition Sport V-800', 
'Expedition TUV V-800', 
'Legend Touring V-800', 
'Skandic V-800 SWT', 
'Skandic V-800 Tundra', 
'Skandic V-800 Tundra LT', 





]

years = list(range(2006, 2012))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make                       Model  Year Vendor Vendor Code Position  \
# 0   Ski-Doo  Expedition 800 TUV Yeti II  2006
# 1   Ski-Doo  Expedition 800 TUV Yeti II  2007
# 2   Ski-Doo  Expedition 800 TUV Yeti II  2008
# 3   Ski-Doo  Expedition 800 TUV Yeti II  2009
# 4   Ski-Doo  Expedition 800 TUV Yeti II  2010
# 5   Ski-Doo  Expedition 800 TUV Yeti II  2011
# 6   Ski-Doo      Expedition Sport V-800  2006
# 7   Ski-Doo      Expedition Sport V-800  2007
# 8   Ski-Doo      Expedition Sport V-800  2008
# 9   Ski-Doo      Expedition Sport V-800  2009
# 10  Ski-Doo      Expedition Sport V-800  2010
# 11  Ski-Doo      Expedition Sport V-800  2011
# 12  Ski-Doo        Expedition TUV V-800  2006
# 13  Ski-Doo        Expedition TUV V-800  2007
# 14  Ski-Doo        Expedition TUV V-800  2008
# 15  Ski-Doo        Expedition TUV V-800  2009
# 16  Ski-Doo        Expedition TUV V-800  2010
# 17  Ski-Doo        Expedition TUV V-800  2011
# 18  Ski-Doo        Legend Touring V-800  2006
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\AU-09017E.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='AU-09017I',
    sku='120865',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420254361; DESC: Exhaust Valve'
)

list_models = [
'Expedition 800 TUV Yeti II', 
'Expedition Sport V-800', 
'Expedition TUV V-800', 
'Legend Touring V-800', 
'Skandic V-800 SWT', 
'Skandic V-800 Tundra', 
'Skandic V-800 Tundra LT', 





]

years = list(range(2006, 2012))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make                       Model  Year Vendor Vendor Code Position  \
# 0   Ski-Doo  Expedition 800 TUV Yeti II  2006
# 1   Ski-Doo  Expedition 800 TUV Yeti II  2007
# 2   Ski-Doo  Expedition 800 TUV Yeti II  2008
# 3   Ski-Doo  Expedition 800 TUV Yeti II  2009
# 4   Ski-Doo  Expedition 800 TUV Yeti II  2010
# 5   Ski-Doo  Expedition 800 TUV Yeti II  2011
# 6   Ski-Doo      Expedition Sport V-800  2006
# 7   Ski-Doo      Expedition Sport V-800  2007
# 8   Ski-Doo      Expedition Sport V-800  2008
# 9   Ski-Doo      Expedition Sport V-800  2009
# 10  Ski-Doo      Expedition Sport V-800  2010
# 11  Ski-Doo      Expedition Sport V-800  2011
# 12  Ski-Doo        Expedition TUV V-800  2006
# 13  Ski-Doo        Expedition TUV V-800  2007
# 14  Ski-Doo        Expedition TUV V-800  2008
# 15  Ski-Doo        Expedition TUV V-800  2009
# 16  Ski-Doo        Expedition TUV V-800  2010
# 17  Ski-Doo        Expedition TUV V-800  2011
# 18  Ski-Doo        Legend Touring V-800  2006
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\AU-09017I.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Yamaha',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='AU-09224E',
    sku='128362',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 8GL-12121-10; DESC: EXHAUST VALVE, OEM TYPE; QTY: 4.46 X 26.01 X 87.9MM, GROOVE DEPTH:3.54MM, ”ALSO FITS WC/UTV, PLEASE INQUIRE FOR DETAIL INFORMATION"'
)

list_models = [
'FX10 FX Nytro', 
'FX10M FX Nytro MTX 153', 
'FX10M FX Nytro MTX 162', 
'FX10M FX Nytro MTX SE 153', 
'FX10M FX Nytro MTX SE 162', 
'FX10MT FX Nytro MTX', 
'FX10MTR FX Nytro MX', 
'FX10MTRA FX Nytro MTX 40th Anniv', 
'FX10RT FX Nytro RTX Non-Reverse', 
'FX10RTR FX Nytro RTX', 
'FX10RTRA FX Nytro RTX 40th Anniv', 
'FX10RTRS FX Nytro RTX SE', 
'FX10XT FX Nytro XTX', 
'FX10XT FX Nytro XTX 1.75', 
'RS10 RS Vector', 
'RS90 RS Vector', 
'RS90GTA RS Vector 40th Anniv', 
'RS90L RS Vector LE', 
'RS90LT RS Vector LTX', 
'RS90LTGT RS Vector LT GT', 
'RS90LTGT RS Vector LTX GT', 
'RS90XT RS Vector XTX', 
'RS90XT75 RS Vector XTX 1.75', 
'RS90XTL RS Vector XTX 1.75 LE', 
'RS10 RS Venture TF', 
'RST1NTF RS Venture TF', 
'RST1NTF RS Venture TF BAT', 
'RST90 RS Venture', 
'RST90GT RS Venture GT', 
'RST90TF RS Venture TF', 
'RST90TFL RS Venture TF LE', 
'RST90TFY RS Venture TF BAT', 
'SW10BL Sidewinder BTX 153 LE 50th', 
'SW10BL Sidewinder BTX LE', 
'SW10BL53 Sidewinder BTX 153 LE', 
'SW10BS Sidewinder BTX 153 1.75 SE', 
'SW10BS Sidewinder BTX SE', 
'SW10LD Sidewinder LTX DX', 
'SW10LG Sidewinder LTX GT', 
'SW10LG Sidewinder LTX GT EPS', 
'SW10LL Sidewinder LTX LE', 
'SW10LL Sidewinder LTX LE 50th', 
'SW10LL Sidewinder LTX LE EPS', 
'SW10LS Sidewinder LTX SE', 
'SW10M53 Sidewinder MTX 153', 
'SW10M62 Sidewinder MTX 162', 
'SW10ML53 Sidewinder MTX 153 LE', 
'SW10ML62 Sidewinder MTX 162 LE', 
'SW10ML62 Sidewinder MTX 162 LE 50th', 
'SW10MS53 Sidewinder MTX 153 SE', 
'SW10MS62 Sidewinder MTX 162 SE', 
'SW10RL Sidewinder RTX LE', 
'SW10RL Sidewinder RTX LE 50th', 
'SW10RS Sidewinder RTX SE', 
'SW10SD37 Sidewinder STX 137 DX', 
'SW10SD46 Sidewinder STX 146 DX', 
'SW10SG Sidewinder STX GT', 
'SW10SG Sidewinder STX GT EPS', 
'SW10XL Sidewinder XTX 1.75 LE 50th', 
'SW10XL37 Sidewinder XTX 137 LE', 
'SW10XL41 Sidewinder XTX 141 LE', 
'SW10XL46 Sidewinder XTX 146 LE', 
'SW10XS37 Sidewinder XTX 137 SE', 
'SW10XS41 Sidewinder XTX 141 SE', 
'SW10XS46 Sidewinder XTX 146 SE', 
'SW1NSR Sidewinder SRX LE', 
'SW1NSR Sidewinder SRX LE EPS', 
'SR10 SR Venture DX', 
'SR10 SR Viper', 
'SR10BL SR Viper BTX LE', 
'SR10L SR Viper LTX', 
'SR10LD SR Viper LTX DX', 
'SR10LG SR Viper LTX GT', 
'SR10LL SR Viper LTX LE', 
'SR10LL SR Viper LTX LE 50th', 
'SR10LS SR Viper LTX SE', 
'SR10M41S SR Viper MTX 141 SE', 
'SR10M53 SR Viper MTX 153', 
'SR10M53L SR Viper MTX 153 LE', 
'SR10M53S SR Viper MTX 153 SE', 
'SR10M62 SR Viper MTX 162', 
'SR10M62L SR Viper MTX 162 LE', 
'SR10M62S SR Viper MTX 162 SE', 
'SR10R SR Viper RTX', 
'SR10RD SR Viper RTX DX', 
'SR10RL SR Viper RTX LE', 
'SR10RS SR Viper RTX SE', 
'SR10S37D SR Viper STX 137 DX', 
'SR10S46D SR Viper STX 146 DX', 
'SR10SD SR Viper STX DX', 
'SR10XL SR Viper XTX LE', 
'SR10XS SR Viper XTX SE', 
'VK10F VK Professional II', 
'VK10F VK Professional II EPS', 

]

years = list(range(2008, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                         Model  Year Vendor Vendor Code Position  \
# 0     Yamaha                 FX10 FX Nytro  2008
# 1     Yamaha                 FX10 FX Nytro  2009
# 2     Yamaha                 FX10 FX Nytro  2010
# 3     Yamaha                 FX10 FX Nytro  2011
# 4     Yamaha                 FX10 FX Nytro  2012
# ...      ...                           ...   ...    ...         ...      ...
# 1499  Yamaha  VK10F VK Professional II EPS  2019
# 1500  Yamaha  VK10F VK Professional II EPS  2020
# 1501  Yamaha  VK10F VK Professional II EPS  2021
# 1502  Yamaha  VK10F VK Professional II EPS  2022
# 1503  Yamaha  VK10F VK Professional II EPS  2023
#
#             MPN     SKU           Product Type  \
# 0     AU-09224E  128362  Exhaust Valve Gaskets
# 1     AU-09224E  128362  Exhaust Valve Gaskets
# 2     AU-09224E  128362  Exhaust Valve Gaskets
# 3     AU-09224E  128362  Exhaust Valve Gaskets
# 4     AU-09224E  128362  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\AU-09224E.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Yamaha',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='AU-09224I',
    sku='128363',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='MPN: AU-09017E; OEM#: 8GL-12111-00-00, 8GL-12111-01-00, 8GL-12111-10-00; DESC: INTAKE VALVE, ”ALSO FITS WC/UTV, PLEASE INQUIRE FOR DETAIL INFORMATION”'
)

list_models = [
'FX10 FX Nytro', 
'FX10M FX Nytro MTX 153', 
'FX10M FX Nytro MTX 162', 
'FX10M FX Nytro MTX SE 153', 
'FX10M FX Nytro MTX SE 162', 
'FX10MT FX Nytro MTX', 
'FX10MTR FX Nytro MX', 
'FX10MTRA FX Nytro MTX 40th Anniv', 
'FX10RT FX Nytro RTX Non-Reverse', 
'FX10RTR FX Nytro RTX', 
'FX10RTRA FX Nytro RTX 40th Anniv', 
'FX10RTRS FX Nytro RTX SE', 
'FX10XT FX Nytro XTX', 
'FX10XT FX Nytro XTX 1.75', 
'RS10 RS Vector', 
'RS90 RS Vector', 
'RS90GTA RS Vector 40th Anniv', 
'RS90L RS Vector LE', 
'RS90LT RS Vector LTX', 
'RS90LTGT RS Vector LT GT', 
'RS90LTGT RS Vector LTX GT', 
'RS90XT RS Vector XTX', 
'RS90XT75 RS Vector XTX 1.75', 
'RS90XTL RS Vector XTX 1.75 LE', 
'RS10 RS Venture TF', 
'RST1NTF RS Venture TF', 
'RST1NTF RS Venture TF BAT', 
'RST90 RS Venture', 
'RST90GT RS Venture GT', 
'RST90TF RS Venture TF', 
'RST90TFL RS Venture TF LE', 
'RST90TFY RS Venture TF BAT', 
'SW10BL Sidewinder BTX 153 LE 50th', 
'SW10BL Sidewinder BTX LE', 
'SW10BL53 Sidewinder BTX 153 LE', 
'SW10BS Sidewinder BTX 153 1.75 SE', 
'SW10BS Sidewinder BTX SE', 
'SW10LD Sidewinder LTX DX', 
'SW10LG Sidewinder LTX GT', 
'SW10LG Sidewinder LTX GT EPS', 
'SW10LL Sidewinder LTX LE', 
'SW10LL Sidewinder LTX LE 50th', 
'SW10LL Sidewinder LTX LE EPS', 
'SW10LS Sidewinder LTX SE', 
'SW10M53 Sidewinder MTX 153', 
'SW10M62 Sidewinder MTX 162', 
'SW10ML53 Sidewinder MTX 153 LE', 
'SW10ML62 Sidewinder MTX 162 LE', 
'SW10ML62 Sidewinder MTX 162 LE 50th', 
'SW10MS53 Sidewinder MTX 153 SE', 
'SW10MS62 Sidewinder MTX 162 SE', 
'SW10RL Sidewinder RTX LE', 
'SW10RL Sidewinder RTX LE 50th', 
'SW10RS Sidewinder RTX SE', 
'SW10SD37 Sidewinder STX 137 DX', 
'SW10SD46 Sidewinder STX 146 DX', 
'SW10SG Sidewinder STX GT', 
'SW10SG Sidewinder STX GT EPS', 
'SW10XL Sidewinder XTX 1.75 LE 50th', 
'SW10XL37 Sidewinder XTX 137 LE', 
'SW10XL41 Sidewinder XTX 141 LE', 
'SW10XL46 Sidewinder XTX 146 LE', 
'SW10XS37 Sidewinder XTX 137 SE', 
'SW10XS41 Sidewinder XTX 141 SE', 
'SW10XS46 Sidewinder XTX 146 SE', 
'SW1NSR Sidewinder SRX LE', 
'SW1NSR Sidewinder SRX LE EPS', 
'SR10 SR Venture DX', 
'SR10 SR Viper', 
'SR10BL SR Viper BTX LE', 
'SR10L SR Viper LTX', 
'SR10LD SR Viper LTX DX', 
'SR10LG SR Viper LTX GT', 
'SR10LL SR Viper LTX LE', 
'SR10LL SR Viper LTX LE 50th', 
'SR10LS SR Viper LTX SE', 
'SR10M41S SR Viper MTX 141 SE', 
'SR10M53 SR Viper MTX 153', 
'SR10M53L SR Viper MTX 153 LE', 
'SR10M53S SR Viper MTX 153 SE', 
'SR10M62 SR Viper MTX 162', 
'SR10M62L SR Viper MTX 162 LE', 
'SR10M62S SR Viper MTX 162 SE', 
'SR10R SR Viper RTX', 
'SR10RD SR Viper RTX DX', 
'SR10RL SR Viper RTX LE', 
'SR10RS SR Viper RTX SE', 
'SR10S37D SR Viper STX 137 DX', 
'SR10S46D SR Viper STX 146 DX', 
'SR10SD SR Viper STX DX', 
'SR10XL SR Viper XTX LE', 
'SR10XS SR Viper XTX SE', 
'VK10F VK Professional II', 
'VK10F VK Professional II EPS', 

]

years = list(range(2008, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                         Model  Year Vendor Vendor Code Position  \
# 0     Yamaha                 FX10 FX Nytro  2008
# 1     Yamaha                 FX10 FX Nytro  2009
# 2     Yamaha                 FX10 FX Nytro  2010
# 3     Yamaha                 FX10 FX Nytro  2011
# 4     Yamaha                 FX10 FX Nytro  2012
# ...      ...                           ...   ...    ...         ...      ...
# 1499  Yamaha  VK10F VK Professional II EPS  2019
# 1500  Yamaha  VK10F VK Professional II EPS  2020
# 1501  Yamaha  VK10F VK Professional II EPS  2021
# 1502  Yamaha  VK10F VK Professional II EPS  2022
# 1503  Yamaha  VK10F VK Professional II EPS  2023
#
#             MPN     SKU           Product Type  \
# 0     AU-09224I  128363  Exhaust Valve Gaskets
# 1     AU-09224I  128363  Exhaust Valve Gaskets
# 2     AU-09224I  128363  Exhaust Valve Gaskets
# 3     AU-09224I  128363  Exhaust Valve Gaskets
# 4     AU-09224I  128363  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\AU-09224I.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09506E-2',
    sku='129155',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 5414680; DESC: GASKET; QTY: 2'
)

list_models = [
'800 INDY Adventure 137', 
'800 INDY XC 129', 
'800 INDY XC 137', 
'800 INDY XCR', 
'800 RMK Assault 155', 
'800 RMK Assault 155 3in.', 
'800 RMK Assault 155 LE', 
'800 RMK KHAOS 155', 
'800 RMK KHAOS 155 3in.', 
'800 Rush PRO-S', 
'800 Rush PRO-S LE', 
'800 Rush PRO-X', 
'800 Rush XCR', 
'800 SKS 146', 
'800 SKS 155', 
'800 SwitchBack Adventure', 
'800 SwitchBack Assault 144', 
'800 SwitchBack Assault 144 TD Series LE', 
'800 SwitchBack Assault LE', 
'800 SwitchBack PRO-S', 
'800 SwitchBack PRO-S LE', 
'800 SwitchBack PRO-X', 
'800 SwitchBack XCR', 


]

years = list(range(2017, 2021))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make                   Model  Year Vendor Vendor Code Position  \
# 0   Polaris  800 INDY Adventure 137  2017
# 1   Polaris  800 INDY Adventure 137  2018
# 2   Polaris  800 INDY Adventure 137  2019
# 3   Polaris  800 INDY Adventure 137  2020
# 4   Polaris         800 INDY XC 129  2017
# ..      ...                     ...   ...    ...         ...      ...
# 87  Polaris    800 SwitchBack PRO-X  2020
# 88  Polaris      800 SwitchBack XCR  2017
# 89  Polaris      800 SwitchBack XCR  2018
# 90  Polaris      800 SwitchBack XCR  2019
# 91  Polaris      800 SwitchBack XCR  2020
#
#             MPN     SKU           Product Type  \
# 0   SM-09506E-2  129155  Exhaust Valve Gaskets
# 1   SM-09506E-2  129155  Exhaust Valve Gaskets
# 2   SM-09506E-2  129155  Exhaust Valve Gaskets
# 3   SM-09506E-2  129155  Exhaust Valve Gaskets
# 4   SM-09506E-2  129155  Exhaust Valve Gaskets
# ..          ...     ...                    ...
# 87  SM-09506E-2  129155  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09506E-2a.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09506E-2',
    sku='129155',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 420250239; DESC: GASKET; QTY: 2- OEM#: 420430110; DESC: O-RING; QTY: 2'
)

list_models = [
'800 Titan Adventure 155', 
'800 Titan SP 155', 
'800 Titan XC 155', 



]

years = list(range(2018, 2025))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#        Make                    Model  Year Vendor Vendor Code Position  \
# 0   Polaris  800 Titan Adventure 155  2018
# 1   Polaris  800 Titan Adventure 155  2019
# 2   Polaris  800 Titan Adventure 155  2020
# 3   Polaris  800 Titan Adventure 155  2021
# 4   Polaris  800 Titan Adventure 155  2022
# 5   Polaris  800 Titan Adventure 155  2023
# 6   Polaris  800 Titan Adventure 155  2024
# 7   Polaris         800 Titan SP 155  2018
# 8   Polaris         800 Titan SP 155  2019
# 9   Polaris         800 Titan SP 155  2020
# 10  Polaris         800 Titan SP 155  2021
# 11  Polaris         800 Titan SP 155  2022
# 12  Polaris         800 Titan SP 155  2023
# 13  Polaris         800 Titan SP 155  2024
# 14  Polaris         800 Titan XC 155  2018
# 15  Polaris         800 Titan XC 155  2019
# 16  Polaris         800 Titan XC 155  2020
# 17  Polaris         800 Titan XC 155  2021
# 18  Polaris         800 Titan XC 155  2022
# 19  Polaris         800 Titan XC 155  2023
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09506E-2b.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Arctic-Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09526E',
    sku='127208',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 0930-022, 8ND-E1354-00-00; DESC: GASKET; QTY: 2- OEM#: 0930-010, 8ND-E1397-00-00; DESC: GASKET; QTY: 2- OEM#: 0930-001, 0930-059, 8ND-RAY12-00-00; DESC: SEAL; QTY: 2- OEM#: 0930-008, 8ND-RAF03-00-00; DESC: O-RING; QTY: 2'
)

list_models = [
'Blast LT 4000', 
'Blast M 4000', 
'Blast M 4000 Special Edition', 
'Blast M LTD 4000', 
'Blast ZR 4000', 
'M 6000 141', 
'M 6000 153', 
'M 6000 ES 153', 
'M 6000 Limited 153', 
'M 6000 SE 141', 
'M 6000 SE 153', 
'M 6000 SE ES 141', 
'M 6000 SE ES 153', 
'M 6000 Sno Pro 141', 
'M 6000 Sno Pro 153', 
'M 6000 Sno Pro ES 153', 
'M 8000 153', 
'M 8000 Alpha One 154', 
'M 8000 Alpha One 165', 
'M 8000 David McClure SE', 
'M 8000 Hardcore 153', 
'M 8000 Hardcore 162', 
'M 8000 Hardcore Alpha One 146', 
'M 8000 Hardcore Alpha One 154', 
'M 8000 Hardcore Alpha One 154 2.6in.', 
'M 8000 Hardcore Alpha One 165', 
'M 8000 Hardcore Alpha One ES 146', 
'M 8000 Hardcore Alpha One ES 154', 
'M 8000 Hardcore Alpha One ES 154 2.6in.', 
'M 8000 Hardcore Alpha One ES 165', 
'M 8000 HCR 153', 
'M 8000 Limited 153', 
'M 8000 Limited 162', 
'M 8000 Limited ES 153', 
'M 8000 Limited ES 162', 
'M 8000 Mountain Cat 153', 
'M 8000 Mountain Cat 162', 
'M 8000 Mountain Cat Alpha One 146', 
'M 8000 Mountain Cat Alpha One 154', 
'M 8000 Mountain Cat Alpha One 154 2.6in.', 
'M 8000 Mountain Cat Alpha One 165', 
'M 8000 Mountain Cat Alpha One ATAC 146', 
'M 8000 Mountain Cat Alpha One ATAC 154', 
'M 8000 Mountain Cat Alpha One ATAC 154 2.6in.', 
'M 8000 Mountain Cat Alpha One ATAC 165', 
'M 8000 Mountain Cat Alpha One ATAC ES 146', 
'M 8000 Mountain Cat Alpha One ATAC ES 154', 
'M 8000 Mountain Cat Alpha One ATAC ES 154 2.6in.', 
'M 8000 Mountain Cat Alpha One ATAC ES 165', 
'M 8000 Mountain Cat Alpha One ES 146', 
'M 8000 Mountain Cat Alpha One ES 154', 
'M 8000 Mountain Cat Alpha One ES 154 2.6in.', 
'M 8000 Mountain Cat Alpha One ES 165', 
'M 8000 Mountain Cat ES 153', 
'M 8000 Mountain Cat ES 162', 
'M 8000 Rob Kincaid SE', 
'M 8000 SE 141', 
'M 8000 SE 153', 
'M 8000 SE ES 153', 
'M 8000 SE ES 162', 
'M 8000 Sno Pro 141', 
'M 8000 Sno Pro 153', 
'M 8000 Sno Pro 153 Early Build', 
'M 8000 Sno Pro 162', 
'M 8000 Sno Pro 162 Early Build', 
'M 8000 Sno Pro ES 141', 
'M 8000 Sno Pro ES 153', 
'M 8000 Sno Pro ES 162', 
'Norseman 6000 ES', 
'Norseman X 6000', 
'Norseman X 8000', 
'Pantera 6000 ES', 
'Riot 8000', 
'Riot 8000 1.35in.', 
'Riot 8000 1.6in.', 
'Riot 8000 ATAC', 
'Riot 8000 ATAC 1.6in.', 
'XF 6000 Cross Country', 
'XF 6000 Cross Country Limited ES', 
'XF 6000 Crosstour', 
'XF 6000 Crosstour ES', 
'XF 6000 Crosstrek', 
'XF 6000 Crosstrek ES', 
'XF 6000 High Country', 
'XF 6000 High Country ES', 
'XF 6000 High Country Limited ES', 
'XF 6000 Limited', 
'XF 6000 LXR', 
'XF 6000 Sno Pro', 
'XF 8000 Cross Country', 
'XF 8000 Cross Country Limited', 
'XF 8000 Cross Country Limited ES', 
'XF 8000 Crosstour', 
'XF 8000 Crosstrek', 
'XF 8000 Crosstrek ES', 
'XF 8000 High Country', 
'XF 8000 High Country Limited', 
'XF 8000 High Country Limited ES 141', 
'XF 8000 High Country Limited ES 153', 
'XF 8000 Limited', 
'XF 8000 LXR', 
'XF 8000 Sno Pro', 
'ZR 6000', 
'ZR 6000 El Tigre', 
'ZR 6000 El Tigre ES 129', 
'ZR 6000 El Tigre ES 137', 
'ZR 6000 ES 129', 
'ZR 6000 ES 137', 
'ZR 6000 Limited 129', 
'ZR 6000 Limited 137', 
'ZR 6000 Limited ES 129', 
'ZR 6000 Limited ES 129 iACT', 
'ZR 6000 Limited ES 137', 
'ZR 6000 Limited ES 137 iACT', 
'ZR 6000 Limited ES ATAC 137', 
'ZR 6000 LXR 129', 
'ZR 6000 LXR 137', 
'ZR 6000 LXR ES 129', 
'ZR 6000 LXR ES 137', 
'ZR 6000 R-XC', 
'ZR 6000 R-XC ES', 
'ZR 6000 R XC', 
'ZR 6000 R XC 129', 
'ZR 6000 RR', 
'ZR 6000 RR ES 129', 
'ZR 6000 RR ES 137', 
'ZR 6000 RS', 
'ZR 6000 Sno Pro 129', 
'ZR 6000 Sno Pro 137', 
'ZR 6000 Sno Pro ES 129', 
'ZR 6000 Sno Pro ES 137', 
'ZR 6000 Tucker Hibbert RR', 
'ZR 8000', 
'ZR 8000 ATAC', 
'ZR 8000 El Tigre', 
'ZR 8000 El Tigre ES 129', 
'ZR 8000 El Tigre ES 137', 
'ZR 8000 ES 129', 
'ZR 8000 ES 137', 
'ZR 8000 Limited 129', 
'ZR 8000 Limited 137', 
'ZR 8000 Limited ES 129', 
'ZR 8000 Limited ES 129 iACT', 
'ZR 8000 Limited ES 137', 
'ZR 8000 Limited ES 137 iACT', 
'ZR 8000 Limited ES ATAC 137', 
'ZR 8000 LXR 129', 
'ZR 8000 LXR 137', 
'ZR 8000 LXR ES 129', 
'ZR 8000 LXR ES 137', 
'ZR 8000 RR', 
'ZR 8000 RR ES 129', 
'ZR 8000 RR ES 137', 
'ZR 8000 Sno Pro 129', 
'ZR 8000 Sno Pro 137', 
'ZR 8000 Sno Pro ES 129', 
'ZR 8000 Sno Pro ES 129 Early Build', 
'ZR 8000 Sno Pro ES 137', 
'ZR 8000 Sno Pro ES 137 Early Build', 




]

years = list(range(2015, 2025))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#             Make                               Model  Year Vendor Vendor Code  \
# 0     Arctic-Cat                       Blast LT 4000  2015
# 1     Arctic-Cat                       Blast LT 4000  2016
# 2     Arctic-Cat                       Blast LT 4000  2017
# 3     Arctic-Cat                       Blast LT 4000  2018
# 4     Arctic-Cat                       Blast LT 4000  2019
# ...          ...                                 ...   ...    ...         ...
# 1585  Arctic-Cat  ZR 8000 Sno Pro ES 137 Early Build  2020
# 1586  Arctic-Cat  ZR 8000 Sno Pro ES 137 Early Build  2021
# 1587  Arctic-Cat  ZR 8000 Sno Pro ES 137 Early Build  2022
# 1588  Arctic-Cat  ZR 8000 Sno Pro ES 137 Early Build  2023
# 1589  Arctic-Cat  ZR 8000 Sno Pro ES 137 Early Build  2024
#
#      Position        MPN     SKU           Product Type  \
# 0              SM-09526E  127208  Exhaust Valve Gaskets
# 1              SM-09526E  127208  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09526E.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Yamaha',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09526E',
    sku='127208',
    pro_type='Exhaust Valve Gaskets',
    vendornotes=' OEM#: 0930-022, 8ND-E1354-00-00; DESC: GASKET; QTY: 2- OEM#: 0930-010, 8ND-E1397-00-00; DESC: GASKET; QTY: 2- OEM#: 0930-001, 0930-059, 8ND-RAY12-00-00; DESC: SEAL; QTY: 2- OEM#: 0930-008, 8ND-RAF03-00-00; DESC: O-RING; QTY: 2'
)

list_models = [

'TR6 Transporter 600', 
'MM8 Mountain Max LE 154', 
'MM8 Mountain Max LE 154 SL', 
'MM8 Mountain Max LE 165', 
'SXV4 SXVenom', 
'SXV4 SXVenom Mountain', 
'TR4 Transporter Lite', 
'TR4T Transporter Lite 2-Up', 




]

years = list(range(2020, 2025))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#       Make                       Model  Year Vendor Vendor Code Position  \
# 0   Yamaha         TR6 Transporter 600  2020
# 1   Yamaha         TR6 Transporter 600  2021
# 2   Yamaha         TR6 Transporter 600  2022
# 3   Yamaha         TR6 Transporter 600  2023
# 4   Yamaha         TR6 Transporter 600  2024
# 5   Yamaha     MM8 Mountain Max LE 154  2020
# 6   Yamaha     MM8 Mountain Max LE 154  2021
# 7   Yamaha     MM8 Mountain Max LE 154  2022
# 8   Yamaha     MM8 Mountain Max LE 154  2023
# 9   Yamaha     MM8 Mountain Max LE 154  2024
# 10  Yamaha  MM8 Mountain Max LE 154 SL  2020
# 11  Yamaha  MM8 Mountain Max LE 154 SL  2021
# 12  Yamaha  MM8 Mountain Max LE 154 SL  2022
# 13  Yamaha  MM8 Mountain Max LE 154 SL  2023
# 14  Yamaha  MM8 Mountain Max LE 154 SL  2024
# 15  Yamaha     MM8 Mountain Max LE 165  2020
# 16  Yamaha     MM8 Mountain Max LE 165  2021
# 17  Yamaha     MM8 Mountain Max LE 165  2022
# 18  Yamaha     MM8 Mountain Max LE 165  2023
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09526Eyamaha.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Ski-Doo',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09537E',
    sku='127981',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 420430036 / 420430035 / 420430037; DESC: GASKET; QTY: 1-OEM#: 420950730 / 420950732; DESC: OIL SEAL; QTY: 2'
)

list_models = [

'Backcountry Adrenaline E-TEC 850', 
'Backcountry E-TEC 850', 
'Backcountry X E-TEC 850', 
'Backcountry X-RS E-TEC 850 146', 
'Backcountry X-RS E-TEC 850 154', 
'Expedition SE E-TEC 850', 
'Expedition Xtreme E-TEC 850', 
'Freeride E-TEC 850 137', 
'Freeride E-TEC 850 146', 
'Freeride E-TEC 850 154', 
'Freeride E-TEC 850 165', 
'Freeride E-TEC 850 Turbo 146', 
'Freeride E-TEC 850 Turbo 154', 
'Freeride E-TEC 850 Turbo 165', 
'Freeride E-TEC 850 Turbo R 146', 
'Freeride E-TEC 850 Turbo R 154', 
'Freeride E-TEC 850 Turbo R 165', 
'Freeride S-38 E-TEC 850 154', 
'MX Z Adrenaline E-TEC 850', 
'MX Z Adrenaline E-TEC 850 137', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 850', 
'MX Z Adrenaline w/ Blizzard Pkg E-TEC 850 137', 
'MX Z Blizzard E-TEC 850', 
'MX Z TNT E-TEC 850', 
'MX Z X-RS E-TEC 850', 
'MX Z X-RS E-TEC 850 137', 
'MX Z X-RS w/ Competition Pkg E-TEC 850 Turbo R', 
'MX Z X E-TEC 850', 
'MX Z X E-TEC 850 137', 
'Renegade Adrenaline E-TEC 850', 
'Renegade Adrenaline w/ Enduro Pkg E-TEC 850', 
'Renegade Backcountry E-TEC 850', 
'Renegade Backcountry X E-TEC 850', 
'Renegade Enduro E-TEC 850', 
'Renegade X-RS E-TEC 850', 
'Renegade X E-TEC 850', 
'Summit Adrenaline E-TEC 850 146', 
'Summit Adrenaline E-TEC 850 154', 
'Summit Adrenaline w/ Edge Package E-TEC 850 146', 
'Summit Adrenaline w/ Edge Package E-TEC 850 154', 
'Summit Adrenaline w/ Edge Package E-TEC 850 165', 
'Summit Edge E-TEC 850 154', 
'Summit Edge E-TEC 850 165', 
'Summit Edge E-TEC 850 175', 
'Summit SP E-TEC 850 146', 
'Summit SP E-TEC 850 154', 
'Summit SP E-TEC 850 165', 
'Summit SP E-TEC 850 175', 
'Summit X E-TEC 850 154', 
'Summit X E-TEC 850 165', 
'Summit X E-TEC 850 175', 
'Summit X E-TEC 850 Turbo 154', 
'Summit X E-TEC 850 Turbo 165', 
'Summit X E-TEC 850 Turbo R 154', 
'Summit X E-TEC 850 Turbo R 165', 
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5', 
'Summit X with Expert Package E-TEC 850 154', 
'Summit X with Expert Package E-TEC 850 154 2.5', 
'Summit X with Expert Package E-TEC 850 165', 
'Summit X with Expert Package E-TEC 850 175', 
'Summit X with Expert Package E-TEC 850 Turbo 154', 
'Summit X with Expert Package E-TEC 850 Turbo 165', 
'Summit X with Expert Package E-TEC 850 Turbo 175', 
'Summit X with Expert Package E-TEC 850 Turbo R 154', 
'Summit X with Expert Package E-TEC 850 Turbo R 165', 
'Summit X with Expert Package E-TEC 850 Turbo R 175', 

]

years = list(range(2017, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                                              Model  Year Vendor  \
# 0    Ski-Doo                   Backcountry Adrenaline E-TEC 850  2017
# 1    Ski-Doo                   Backcountry Adrenaline E-TEC 850  2018
# 2    Ski-Doo                   Backcountry Adrenaline E-TEC 850  2019
# 3    Ski-Doo                   Backcountry Adrenaline E-TEC 850  2020
# 4    Ski-Doo                   Backcountry Adrenaline E-TEC 850  2021
# ..       ...                                                ...   ...    ...
# 457  Ski-Doo  Summit X with Expert Package E-TEC 850 Turbo R...  2019
# 458  Ski-Doo  Summit X with Expert Package E-TEC 850 Turbo R...  2020
# 459  Ski-Doo  Summit X with Expert Package E-TEC 850 Turbo R...  2021
# 460  Ski-Doo  Summit X with Expert Package E-TEC 850 Turbo R...  2022
# 461  Ski-Doo  Summit X with Expert Package E-TEC 850 Turbo R...  2023
#
#     Vendor Code Position        MPN     SKU           Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09537E.csv"
final_df.to_csv(file_path, index = False)

# %%
autodist_template = Autodist_temp(
    make='Polaris',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='SM-09539E',
    sku='128583',
    pro_type='Exhaust Valve Gaskets',
    vendornotes='OEM#: 5416132 DESC: GASKET QTY: 2'
)

list_models = [

'650 INDY Adventure 137', 
'650 INDY Adventure X2 137', 
'650 INDY VR1 129', 
'650 INDY VR1 137', 
'650 INDY XC 129', 
'650 INDY XC 137', 
'650 INDY XC Launch Edition 129', 
'650 INDY XC Launch Edition 137', 
'650 INDY XCR 128', 
'650 INDY XCR 136', 
'650 PRO-RMK 155', 
'650 PRO-RMK Matryx 155', 
'650 RMK KHAOS Matryx Slash 146', 
'650 RMK KHAOS Slash 146', 
'650 SKS 146', 
'650 SwitchBack Assault 146', 
'650 SwitchBack SP 146', 
'650 SwitchBack XC 146', 
'650 Voyageur 146', 
'850 INDY Adventure 137', 
'850 INDY VR1 129', 
'850 INDY VR1 137', 
'850 INDY XC 129', 
'850 INDY XC 137', 
'850 INDY XC Launch Edition 129', 
'850 INDY XC Launch Edition 137', 
'850 INDY XCR', 
'850 INDY XCR 128', 
'850 INDY XCR 136', 
'850 PRO-RMK 155', 
'850 PRO-RMK 155 3in.', 
'850 PRO-RMK 163', 
'850 PRO-RMK 163 3in.', 
'850 PRO-RMK 174', 
'850 PRO-RMK AXYS 155 2.75in.', 
'850 PRO-RMK AXYS 155 3in.', 
'850 PRO-RMK AXYS 163 3in.', 
'850 PRO-RMK AXYS 165 2.75in.', 
'850 PRO-RMK Matryx 155', 
'850 PRO-RMK Matryx Slash 155 2.75in.', 
'850 PRO-RMK Matryx Slash 155 3in.', 
'850 PRO-RMK Matryx Slash 163 3in.', 
'850 PRO-RMK Matryx Slash 165 2.75in.', 
'850 PRO-RMK QD2 155 2.75in.', 
'850 PRO-RMK QD2 155 3in.', 
'850 PRO-RMK QD2 163 3in.', 
'850 PRO-RMK QD2 165 2.75in.', 
'850 PRO-RMK QD2 174 3in.', 
'850 PRO-RMK Slash 155', 
'850 PRO-RMK Slash 163', 
'850 PRO-RMK Slash 165', 
'850 RMK KHAOS 155', 
'850 RMK KHAOS 155 3in.', 
'850 RMK KHAOS 163 2.6in.', 
'850 RMK KHAOS AXYS 155 2.75in.', 
'850 RMK KHAOS AXYS 155 3in.', 
'850 RMK KHAOS AXYS 163 3in.', 
'850 RMK KHAOS AXYS 165 2.75in.', 
'850 RMK KHAOS Matryx 155', 
'850 RMK KHAOS Matryx Slash 146', 
'850 RMK KHAOS Matryx Slash 155', 
'850 RMK KHAOS Matryx Slash 163 3in.', 
'850 RMK KHAOS Matryx Slash 165 2.75in.', 
'850 RMK KHAOS QD2 155 2.75in.', 
'850 RMK KHAOS QD2 155 3in.', 
'850 RMK KHAOS QD2 163 3in.', 
'850 RMK KHAOS QD2 165 2.75in.', 
'850 RMK KHAOS Slash 146', 
'850 RMK KHAOS Slash 155', 
'850 RMK KHAOS Slash 163', 
'850 RMK KHAOS Slash 165', 
'850 Rush PRO-S', 
'850 Rush XCR', 
'850 SKS 146', 
'850 SKS 155', 
'850 SwitchBack Assault 144', 
'850 SwitchBack Assault 146', 
'850 SwitchBack PRO-S', 
'850 SwitchBack XC 146', 
'850 SwitchBack XCR', 
'Patriot 9R PRO-RMK Slash 155', 
'Patriot 9R PRO-RMK Slash 163', 
'Patriot 9R PRO-RMK Slash 165', 
'Patriot 9R RMK KHAOS Slash 146', 
'Patriot 9R RMK KHAOS Slash 155', 
'Patriot 9R RMK KHAOS Slash 163', 
'Patriot 9R RMK KHAOS Slash 165', 
'Patriot Boost INDY VR1 129', 
'Patriot Boost INDY VR1 137', 
'Patriot Boost PRO-RMK Matryx Slash 163 3in.', 
'Patriot Boost PRO-RMK Matryx Slash 165 2.75in.', 
'Patriot Boost PRO-RMK Slash 155', 
'Patriot Boost PRO-RMK Slash 163', 
'Patriot Boost PRO-RMK Slash 165', 
'Patriot Boost RMK KHAOS Matryx Slash 155', 
'Patriot Boost RMK KHAOS Slash 155', 
'Patriot Boost RMK KHAOS Slash 163', 
'Patriot Boost RMK KHAOS Slash 165', 
'Patriot Boost SwitchBack Assault 146', 


]

years = list(range(2017, 2024))

generator = AutodistGenerator(autodist_template, list_models, years)
final_df = generator.generate_autodist()

#print(final_df)  #item[start(index):end(element)]
final_df
# Out:
#         Make                                 Model  Year Vendor Vendor Code  \
# 0    Polaris                650 INDY Adventure 137  2017
# 1    Polaris                650 INDY Adventure 137  2018
# 2    Polaris                650 INDY Adventure 137  2019
# 3    Polaris                650 INDY Adventure 137  2020
# 4    Polaris                650 INDY Adventure 137  2021
# ..       ...                                   ...   ...    ...         ...
# 688  Polaris  Patriot Boost SwitchBack Assault 146  2019
# 689  Polaris  Patriot Boost SwitchBack Assault 146  2020
# 690  Polaris  Patriot Boost SwitchBack Assault 146  2021
# 691  Polaris  Patriot Boost SwitchBack Assault 146  2022
# 692  Polaris  Patriot Boost SwitchBack Assault 146  2023
#
#     Position        MPN     SKU           Product Type  \
# 0             SM-09539E  128583  Exhaust Valve Gaskets
# 1             SM-09539E  128583  Exhaust Valve Gaskets
# 2             SM-09539E  128583  Exhaust Valve Gaskets
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(17)SECTION 09 - EXHAUST VALVE GASKETS ( 06-02-23 ) in progress\Merged Exhaust\SM-09539E.csv"
final_df.to_csv(file_path, index = False)
