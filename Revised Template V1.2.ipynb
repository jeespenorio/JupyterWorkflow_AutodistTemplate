# %%
# Creator: JID Espenorio
# Requestor: Data Analyst - Autodist
# Created: July 9, 2024


import pandas as pd

# Define a class for the Autodistribution template
class Autodist_temp:
    def __init__(self, make, model, year, mpn, sku, position, pro_type, vendor, vendorcode, vendornotes):
        self.make = make
        self.model = model
        self.year = year
        self.mpn = mpn
        self.sku = sku
        self.position = position
        self.pro_type = pro_type
        self.vendor = vendor
        self.vendorcode = vendorcode
        self.vendornotes = vendornotes
        
    def to_dict(self):
        return {
            'Make': self.make,
            'Model': self.model,
            'Vendor': self.vendor,
            'Vendor Code': self.vendorcode,
            'Product Type': self.pro_type,
            'Position': self.position,
            'SKU': self.sku,
            'MPN': self.mpn,
            'Year': self.year,
            'Vendor Notes': self.vendornotes
        }

# %%
# Define a class for generating Autodistribution data
class AutodistGenerator:
    def __init__(self, autodist_template, list_models, years):
        self.autodist_template = autodist_template
        self.list_models = list_models
        self.years = years
    
    def generate_autodist(self):
        data = []
        for model in self.list_models:
            for year in self.years:
                autodist_data = {
                    'Make': self.autodist_template.make,
                    'Model': model,
                    'Year': year,
                    'Vendor': self.autodist_template.vendor,
                    'Vendor Code': self.autodist_template.vendorcode,
                    'Position': self.autodist_template.position,
                    'MPN': self.autodist_template.mpn,
                    'SKU': self.autodist_template.sku,
                    'Product Type': self.autodist_template.pro_type,
                    'Vendor Notes': self.autodist_template.vendornotes,
                }
                data.append(autodist_data)
        return pd.DataFrame(data)

# %%
# Create an instance of Autodist_temp for the template - 1st template
autodist_template = Autodist_temp(
    make='Arctic Cat',
    model='All types of models',
    year=None,
    vendor='',
    vendorcode='',
    position='',
    mpn='09-501-01',
    sku='NB9501',
    pro_type='TOP END BEARING',
    vendornotes='SIZE: 60.00MM;  OEM: 3000-218'
)

# List of specific models for which autodistribution data will be generated
list_models = [
    'Cheetah 340'

]

# Range of years for which autodistribution data will be generated
years = list(range(1972, 1976))

# Create an instance of AutodistGenerator using the template, models, and years
generator = AutodistGenerator(autodist_template, list_models, years)

# Generate autodistribution data and store it in final_df
final_df = generator.generate_autodist()

# Print or display the generated DataFrame
print(final_df)
#final_df
# Out:
#          Make        Model  Year Vendor Vendor Code Position        MPN  \
# 0  Arctic Cat  Cheetah 340  1972                              09-501-01
# 1  Arctic Cat  Cheetah 340  1973                              09-501-01
# 2  Arctic Cat  Cheetah 340  1974                              09-501-01
# 3  Arctic Cat  Cheetah 340  1975                              09-501-01
#
#       SKU     Product Type                   Vendor Notes
# 0  NB9501  TOP END BEARING  SIZE: 60.00MM;  OEM: 3000-218
# 1  NB9501  TOP END BEARING  SIZE: 60.00MM;  OEM: 3000-218
# 2  NB9501  TOP END BEARING  SIZE: 60.00MM;  OEM: 3000-218
# 3  NB9501  TOP END BEARING  SIZE: 60.00MM;  OEM: 3000-218

# %%
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    {'model': 'Cheetah 340', 'notes': 'SIZE: 60.00MM; OEM: 3000-218', 'years': list(range(1972, 1976))},
    {'model': 'Lynx 500', 'notes': 'SIZE: 65.00MM; OEM: 4000-312', 'years': list(range(1980, 1985))},
    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make='Arctic Cat',
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-501-01',
        sku='NB9501',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
print(final_df)
# Out:
#          Make        Model  Year Vendor Vendor Code Position        MPN  \
# 0  Arctic Cat  Cheetah 340  1972                              09-501-01
# 1  Arctic Cat  Cheetah 340  1973                              09-501-01
# 2  Arctic Cat  Cheetah 340  1974                              09-501-01
# 3  Arctic Cat  Cheetah 340  1975                              09-501-01
# 4  Arctic Cat     Lynx 500  1980                              09-501-01
# 5  Arctic Cat     Lynx 500  1981                              09-501-01
# 6  Arctic Cat     Lynx 500  1982                              09-501-01
# 7  Arctic Cat     Lynx 500  1983                              09-501-01
# 8  Arctic Cat     Lynx 500  1984                              09-501-01
#
#       SKU     Product Type                  Vendor Notes
# 0  NB9501  TOP END BEARING  SIZE: 60.00MM; OEM: 3000-218
# 1  NB9501  TOP END BEARING  SIZE: 60.00MM; OEM: 3000-218
# 2  NB9501  TOP END BEARING  SIZE: 60.00MM; OEM: 3000-218
# 3  NB9501  TOP END BEARING  SIZE: 60.00MM; OEM: 3000-218
# 4  NB9501  TOP END BEARING  SIZE: 65.00MM; OEM: 4000-312
# 5  NB9501  TOP END BEARING  SIZE: 65.00MM; OEM: 4000-312
# 6  NB9501  TOP END BEARING  SIZE: 65.00MM; OEM: 4000-312
# 7  NB9501  TOP END BEARING  SIZE: 65.00MM; OEM: 4000-312
# 8  NB9501  TOP END BEARING  SIZE: 65.00MM; OEM: 4000-312

# %%
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    {'make': 'Arctic Cat', 'model': 'Cheetah 340', 'notes': 'SIZE: 60.00MM; OEM: 3000-218', 'years': list(range(1972, 1976))},
    {'make': 'Arctic Cat', 'model': 'Bearcat 340', 'notes': 'SIZE: 60.00MM;  OEM: 3002-761', 'years': list(range(1995, 2001))},
    {'make': 'Polaris', 'model': 'Sport GT', 'notes': 'SIZE: 62.30MM; REF: 2316; OEM: 3085840', 'years': list(range(1989, 1997))},
    {'make': 'Polaris', 'model': 'XLT', 'notes': 'SIZE: 64.00MM; REF: 2347; OEM: 3084449', 'years': list(range(1993, 1995))},
    {'make': 'Polaris', 'model': 'XLT SKS', 'notes': 'SIZE: 64.00MM; REF: 2347; OEM: 3084449', 'years': list(range(1993, 1995))},
    {'make': 'Polaris', 'model': 'XLT SP', 'notes': 'SIZE: 64.00MM; REF: 2347; OEM: 3084449', 'years': list(range(1993, 1995))},
    {'make': 'Polaris', 'model': 'XLT SP Xtra', 'notes': 'SIZE: 64.00MM; REF: 2347; OEM: 3084449', 'years': list(range(1993, 1995))},
    {'make': 'Polaris', 'model': 'XLT SKS', 'notes': 'SIZE: 65.00MM; REF: 2358; OEM: 3085018', 'years': list(range(1995, 2000))},
    {'make': 'Polaris', 'model': 'XLT SP', 'notes': 'SIZE: 65.00MM; REF: 2358; OEM: 3085018', 'years': list(range(1995, 2000))},
    {'make': 'Polaris', 'model': 'XLT SP LT', 'notes': 'SIZE: 65.00MM; REF: 2358; OEM: 3085018', 'years': list(range(1995, 2000))},
    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-501-01',
        sku='NB9501',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#           Make        Model  Year Vendor Vendor Code Position        MPN  \
# 0   Arctic Cat  Cheetah 340  1972                              09-501-01
# 1   Arctic Cat  Cheetah 340  1973                              09-501-01
# 2   Arctic Cat  Cheetah 340  1974                              09-501-01
# 3   Arctic Cat  Cheetah 340  1975                              09-501-01
# 4   Arctic Cat  Bearcat 340  1995                              09-501-01
# 5   Arctic Cat  Bearcat 340  1996                              09-501-01
# 6   Arctic Cat  Bearcat 340  1997                              09-501-01
# 7   Arctic Cat  Bearcat 340  1998                              09-501-01
# 8   Arctic Cat  Bearcat 340  1999                              09-501-01
# 9   Arctic Cat  Bearcat 340  2000                              09-501-01
# 10     Polaris     Sport GT  1989                              09-501-01
# 11     Polaris     Sport GT  1990                              09-501-01
# 12     Polaris     Sport GT  1991                              09-501-01
# 13     Polaris     Sport GT  1992                              09-501-01
# 14     Polaris     Sport GT  1993                              09-501-01
# 15     Polaris     Sport GT  1994                              09-501-01
# 16     Polaris     Sport GT  1995                              09-501-01
# 17     Polaris     Sport GT  1996                              09-501-01
# 18     Polaris          XLT  1993                              09-501-01
# 19     Polaris          XLT  1994                              09-501-01
# 20     Polaris      XLT SKS  1993                              09-501-01
# 21     Polaris      XLT SKS  1994                              09-501-01
# 22     Polaris       XLT SP  1993                              09-501-01
# 23     Polaris       XLT SP  1994                              09-501-01
# 24     Polaris  XLT SP Xtra  1993                              09-501-01
# 25     Polaris  XLT SP Xtra  1994                              09-501-01
# 26     Polaris      XLT SKS  1995                              09-501-01
# 27     Polaris      XLT SKS  1996                              09-501-01
# 28     Polaris      XLT SKS  1997                              09-501-01
# 29     Polaris      XLT SKS  1998                              09-501-01
# 30     Polaris      XLT SKS  1999                              09-501-01
# 31     Polaris       XLT SP  1995                              09-501-01
# 32     Polaris       XLT SP  1996                              09-501-01
# 33     Polaris       XLT SP  1997                              09-501-01
# 34     Polaris       XLT SP  1998                              09-501-01
# 35     Polaris       XLT SP  1999                              09-501-01
# 36     Polaris    XLT SP LT  1995                              09-501-01
# 37     Polaris    XLT SP LT  1996                              09-501-01
# 38     Polaris    XLT SP LT  1997                              09-501-01
# 39     Polaris    XLT SP LT  1998                              09-501-01
# 34  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 35  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 36  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 37  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 38  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 39  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018
# 40  NB9501  TOP END BEARING  SIZE: 65.00MM; REF: 2358; OEM: 3085018

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-501-01.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    {'make': 'Arctic Cat', 'model': 'Bearcat 440', 'notes': 'SIZE: 65.00MM; REF: 2300; OEM: 3002-928', 'years': list(range(1995, 2000))},

    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-502-1',
        sku='NB9502',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#          Make        Model  Year Vendor Vendor Code Position       MPN  \
# 0  Arctic Cat  Bearcat 440  1995                              09-502-1
# 1  Arctic Cat  Bearcat 440  1996                              09-502-1
# 2  Arctic Cat  Bearcat 440  1997                              09-502-1
# 3  Arctic Cat  Bearcat 440  1998                              09-502-1
# 4  Arctic Cat  Bearcat 440  1999                              09-502-1
#
#       SKU     Product Type                             Vendor Notes
# 0  NB9502  TOP END BEARING  SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 1  NB9502  TOP END BEARING  SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 2  NB9502  TOP END BEARING  SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 3  NB9502  TOP END BEARING  SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 4  NB9502  TOP END BEARING  SIZE: 65.00MM; REF: 2300; OEM: 3002-928

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-502-1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    {'make': 'Arctic Cat', 'model': 'zr 440', 'notes': 'SIZE: 65.00MM; REF: 2300; OEM: 3002-928', 'years': list(range(1995, 2000))},
    {'make': 'Arctic Cat', 'model': 'ZR 440 Sno Pro', 'notes': 'SIZE: 65.00MM; REF: 2300; OEM: 3002-928', 'years': list(range(1995, 1998))},
    {'make': 'Arctic Cat', 'model': 'Cheetah 500 F/C', 'notes': 'SIZE: 70.00MM;  ', 'years': list(range(1986, 1991))},
    {'make': 'Arctic Cat', 'model': 'Cougar', 'notes': 'SIZE: 70.00MM;  ', 'years': list(range(1986, 1991))},
    {'make': 'Arctic Cat', 'model': 'EXT 600', 'notes': 'SIZE: 66.50MM;  ', 'years': list(range(1997, 1999))},
    {'make': 'Arctic Cat', 'model': 'EXT 600 Tour', 'notes': 'SIZE: 66.50MM;  ', 'years': list(range(1997, 1999))},
    {'make': 'Arctic Cat', 'model': 'EXT 600 Triple', 'notes': 'SIZE: 66.50MM;  ', 'years': list(range(1997, 1999))},
    {'make': 'Polaris', 'model': '400', 'notes': 'SIZE: 65.00MM ; ', 'years': list(range(1984, 1992))},
    {'make': 'Polaris', 'model': '400', 'notes': 'SIZE: 67.75MM; REF: 2346; OEM: 3084245', 'years': list(range(1988, 1990))},
    {'make': 'Polaris', 'model': '400 SKS', 'notes': 'SIZE: 67.75MM; REF: 2346; OEM: 3084245', 'years': list(range(1988, 1990))},
    {'make': 'Polaris', 'model': 'XC 400', 'notes': 'SIZE: 67.75MM; REF: 2346; OEM: 3084245', 'years': list(range(1988, 1990))},
    {'make': 'Polaris', 'model': '440 SKS', 'notes': 'SIZE: 67.60MM; REF: 2343; OEM: 3084327', 'years': list(range(1995, 1999))},
    {'make': 'Polaris', 'model': '500', 'notes': 'SIZE: 72.00MM; REF: 2345; OEM: 3083841', 'years': list(range(1998, 1999))},
    {'make': 'Polaris', 'model': '500', 'notes': 'SIZE: 72.00MM;  OEM: 3085458', 'years': list(range(1998, 1999))},
    {'make': 'Polaris', 'model': '500 Carb RMK', 'notes': 'SIZE: 72.00MM;  OEM: 3085458', 'years': list(range(1998, 1999))},
    {'make': 'Polaris', 'model': '500 RMK', 'notes': 'SIZE: 72.00MM;  OEM: 3085458', 'years': list(range(1998, 1999))},
    {'make': 'Polaris', 'model': '550 Classic', 'notes': 'SIZE: 73.00MM; REF: 2417; OEM: 3087024', 'years': list(range(2003, 2004))},
    {'make': 'Polaris', 'model': '550 Pro X Fan', 'notes': 'SIZE: 73.00MM; REF: 2417; OEM: 3087024', 'years': list(range(2004, 2005))},
    # xcr 600 sp
    {'make': 'Polaris', 'model': '600 XCR', 'notes': 'SIZE: 62.50MM; REF: 2365; OEM: 3085297', 'years': list(range(1996, 1999))},
    {'make': 'Polaris', 'model': '600 XCR SE', 'notes': 'SIZE: 62.50MM; REF: 2365; OEM: 3085297', 'years': list(range(1996, 1999))},
    {'make': 'Polaris', 'model': '600 XCR SP', 'notes': 'SIZE: 62.50MM; REF: 2365; OEM: 3085297', 'years': list(range(1996, 1999))},
    # 680 ULTRA
    {'make': 'Polaris', 'model': 'Ultra', 'notes': 'SIZE: 66.50MM; REF: 2366; OEM: 3085262', 'years': list(range(1996, 1999))},
    {'make': 'Polaris', 'model': 'Ultra SP', 'notes': 'SIZE: 66.50MM; REF: 2366; OEM: 3085262', 'years': list(range(1996, 1999))},
    {'make': 'Polaris', 'model': 'Ultra SPX', 'notes': 'SIZE: 66.50MM; REF: 2366; OEM: 3085262', 'years': list(range(1996, 1999))},
    {'make': 'Polaris', 'model': 'Ultra SPX SE', 'notes': 'SIZE: 66.50MM; REF: 2366; OEM: 3085262', 'years': list(range(1996, 1999))},
    #XCR 800, XPS SERIES
    {'make': 'Polaris', 'model': '800 XCR', 'notes': 'SIZE: 72.00MM; REF: 2404; OEM: 3086142', 'years': list(range(1999, 2004))},
    # Ski- Doo
    {'make': 'Ski-Doo', 'model': 'Formula Deluxe 500', 'notes': 'SIZE: 69.50MM; REF: 2436; OEM: 420888445', 'years': list(range(2001, 2002))},
    {'make': 'Ski-Doo', 'model': 'Formula Deluxe 500 LC', 'notes': 'SIZE: 69.50MM; REF: 2436; OEM: 420888445', 'years': list(range(2001, 2002))},
    {'make': 'Ski-Doo', 'model': 'Formula Deluxe 500 Fan', 'notes': 'SIZE: 69.50MM; REF: 2436; OEM: 420888445', 'years': list(range(2001, 2002))},
    # Formula III 600
    {'make': 'Ski-Doo', 'model': 'Formula III', 'notes': 'SIZE: 64.50MM; REF: 2377;', 'years': list(range(1995, 2000))},
    {'make': 'Ski-Doo', 'model': 'Formula III 600', 'notes': 'SIZE: 64.50MM; REF: 2377;', 'years': list(range(1995, 2000))},
    {'make': 'Ski-Doo', 'model': 'Formula III 600 LT', 'notes': 'SIZE: 64.50MM; REF: 2377;', 'years': list(range(1995, 2000))},
    {'make': 'Ski-Doo', 'model': 'Formula III 600 R', 'notes': 'SIZE: 64.50MM; REF: 2377;', 'years': list(range(1995, 2000))},
    # Formula III 700
    {'make': 'Ski-Doo', 'model': 'Formula III', 'notes': 'SIZE: 69.75MM; REF: 2382; OEM: 420887521', 'years': list(range(1998, 2001))},        
    {'make': 'Ski-Doo', 'model': 'Formula III 700', 'notes': 'SIZE: 69.75MM; REF: 2382; OEM: 420887521', 'years': list(range(1998, 2001))},        
    {'make': 'Ski-Doo', 'model': 'Formula III 700 R', 'notes': 'SIZE: 69.75MM; REF: 2382; OEM: 420887521', 'years': list(range(1998, 2001))},        
    # Formula III 800
    {'make': 'Ski-Doo', 'model': 'Formula III', 'notes': 'SIZE: 70.50MM; REF: 2434; OEM: 420887643', 'years': list(range(1999, 2001))},        
    {'make': 'Ski-Doo', 'model': 'Formula III 800', 'notes': 'SIZE: 70.50MM; REF: 2434; OEM: 420887643', 'years': list(range(1999, 2001))},

    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-503-1',
        sku='NB9503',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#            Make              Model  Year Vendor Vendor Code Position  \
# 0    Arctic Cat             zr 440  1995
# 1    Arctic Cat             zr 440  1996
# 2    Arctic Cat             zr 440  1997
# 3    Arctic Cat             zr 440  1998
# 4    Arctic Cat             zr 440  1999
# ..          ...                ...   ...    ...         ...      ...
# 105     Ski-Doo  Formula III 700 R  2000
# 106     Ski-Doo        Formula III  1999
# 107     Ski-Doo        Formula III  2000
# 108     Ski-Doo    Formula III 800  1999
# 109     Ski-Doo    Formula III 800  2000
#
#           MPN     SKU     Product Type  \
# 0    09-503-1  NB9503  TOP END BEARING
# 1    09-503-1  NB9503  TOP END BEARING
# 2    09-503-1  NB9503  TOP END BEARING
# 3    09-503-1  NB9503  TOP END BEARING
# 4    09-503-1  NB9503  TOP END BEARING
# ..        ...     ...              ...
# 105  09-503-1  NB9503  TOP END BEARING
# 106  09-503-1  NB9503  TOP END BEARING
# 107  09-503-1  NB9503  TOP END BEARING
# 108  09-503-1  NB9503  TOP END BEARING
# 109  09-503-1  NB9503  TOP END BEARING
#
#                                  Vendor Notes
# 0     SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 1     SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 2     SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 3     SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# 4     SIZE: 65.00MM; REF: 2300; OEM: 3002-928
# ..                                        ...
# 105  SIZE: 69.75MM; REF: 2382; OEM: 420887521
# 106  SIZE: 70.50MM; REF: 2434; OEM: 420887643
# 107  SIZE: 70.50MM; REF: 2434; OEM: 420887643
# 108  SIZE: 70.50MM; REF: 2434; OEM: 420887643
# 109  SIZE: 70.50MM; REF: 2434; OEM: 420887643
#
# [110 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-503-1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #Everest 340
    {'make': 'Ski-Doo', 'model': 'Everest 340', 'notes': 'SIZE: 59.50MM; ', 'years': list(range(1973, 1980))},
    {'make': 'Ski-Doo', 'model': 'Everest 340E', 'notes': 'SIZE: 59.50MM; ', 'years': list(range(1973, 1980))},
    #TNT
    {'make': 'Ski-Doo', 'model': 'TNT 340', 'notes': 'SIZE: 59.50MM; ', 'years': list(range(1973, 1980))},
    #Blizzard
    {'make': 'Ski-Doo', 'model': 'Blizzard 6500 Plus', 'notes': 'SIZE: 59.50MM; ', 'years': list(range(1973, 1980))},
   

    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-505-01',
        sku='NB9505',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#        Make               Model  Year Vendor Vendor Code Position        MPN  \
# 0   Ski-Doo         Everest 340  1973                              09-505-01
# 1   Ski-Doo         Everest 340  1974                              09-505-01
# 2   Ski-Doo         Everest 340  1975                              09-505-01
# 3   Ski-Doo         Everest 340  1976                              09-505-01
# 4   Ski-Doo         Everest 340  1977                              09-505-01
# 5   Ski-Doo         Everest 340  1978                              09-505-01
# 6   Ski-Doo         Everest 340  1979                              09-505-01
# 7   Ski-Doo        Everest 340E  1973                              09-505-01
# 8   Ski-Doo        Everest 340E  1974                              09-505-01
# 9   Ski-Doo        Everest 340E  1975                              09-505-01
# 10  Ski-Doo        Everest 340E  1976                              09-505-01
# 11  Ski-Doo        Everest 340E  1977                              09-505-01
# 12  Ski-Doo        Everest 340E  1978                              09-505-01
# 13  Ski-Doo        Everest 340E  1979                              09-505-01
# 14  Ski-Doo             TNT 340  1973                              09-505-01
# 15  Ski-Doo             TNT 340  1974                              09-505-01
# 16  Ski-Doo             TNT 340  1975                              09-505-01
# 17  Ski-Doo             TNT 340  1976                              09-505-01
# 18  Ski-Doo             TNT 340  1977                              09-505-01
# 19  Ski-Doo             TNT 340  1978                              09-505-01
# 20  Ski-Doo             TNT 340  1979                              09-505-01
# 21  Ski-Doo  Blizzard 6500 Plus  1973                              09-505-01
# 22  Ski-Doo  Blizzard 6500 Plus  1974                              09-505-01
# 23  Ski-Doo  Blizzard 6500 Plus  1975                              09-505-01
# 24  Ski-Doo  Blizzard 6500 Plus  1976                              09-505-01
# 25  Ski-Doo  Blizzard 6500 Plus  1977                              09-505-01
# 26  Ski-Doo  Blizzard 6500 Plus  1978                              09-505-01
# 27  Ski-Doo  Blizzard 6500 Plus  1979                              09-505-01
#
#        SKU     Product Type     Vendor Notes
# 0   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 1   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 2   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 3   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 4   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 5   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 6   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 7   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 8   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 9   NB9505  TOP END BEARING  SIZE: 59.50MM;
# 10  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 11  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 12  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 13  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 14  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 15  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 16  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 17  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 18  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 19  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 20  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 21  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 22  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 23  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 24  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 25  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 26  NB9505  TOP END BEARING  SIZE: 59.50MM;
# 27  NB9505  TOP END BEARING  SIZE: 59.50MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #GP338
    {'make': 'Yamaha', 'model': 'GP338', 'notes': 'SIZE: 60.00MM;  ', 'years': list(range(1973, 1979))},
    #GPx338
    {'make': 'Yamaha', 'model': 'GPx338', 'notes': 'SIZE: 60.00MM;  ', 'years': list(range(1973, 1979))},
    #EX340
   {'make': 'Yamaha', 'model': 'EX340', 'notes': 'SIZE: 60.00MM;  ', 'years': list(range(1973, 1979))},

    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-505-01',
        sku='NB9505',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#       Make   Model  Year Vendor Vendor Code Position        MPN     SKU  \
# 0   Yamaha   GP338  1973                              09-505-01  NB9505
# 1   Yamaha   GP338  1974                              09-505-01  NB9505
# 2   Yamaha   GP338  1975                              09-505-01  NB9505
# 3   Yamaha   GP338  1976                              09-505-01  NB9505
# 4   Yamaha   GP338  1977                              09-505-01  NB9505
# 5   Yamaha   GP338  1978                              09-505-01  NB9505
# 6   Yamaha  GPx338  1973                              09-505-01  NB9505
# 7   Yamaha  GPx338  1974                              09-505-01  NB9505
# 8   Yamaha  GPx338  1975                              09-505-01  NB9505
# 9   Yamaha  GPx338  1976                              09-505-01  NB9505
# 10  Yamaha  GPx338  1977                              09-505-01  NB9505
# 11  Yamaha  GPx338  1978                              09-505-01  NB9505
# 12  Yamaha   EX340  1973                              09-505-01  NB9505
# 13  Yamaha   EX340  1974                              09-505-01  NB9505
# 14  Yamaha   EX340  1975                              09-505-01  NB9505
# 15  Yamaha   EX340  1976                              09-505-01  NB9505
# 16  Yamaha   EX340  1977                              09-505-01  NB9505
# 17  Yamaha   EX340  1978                              09-505-01  NB9505
#
#        Product Type      Vendor Notes
# 0   TOP END BEARING  SIZE: 60.00MM;
# 1   TOP END BEARING  SIZE: 60.00MM;
# 2   TOP END BEARING  SIZE: 60.00MM;
# 3   TOP END BEARING  SIZE: 60.00MM;
# 4   TOP END BEARING  SIZE: 60.00MM;
# 5   TOP END BEARING  SIZE: 60.00MM;
# 6   TOP END BEARING  SIZE: 60.00MM;
# 7   TOP END BEARING  SIZE: 60.00MM;
# 8   TOP END BEARING  SIZE: 60.00MM;
# 9   TOP END BEARING  SIZE: 60.00MM;
# 10  TOP END BEARING  SIZE: 60.00MM;
# 11  TOP END BEARING  SIZE: 60.00MM;
# 12  TOP END BEARING  SIZE: 60.00MM;
# 13  TOP END BEARING  SIZE: 60.00MM;
# 14  TOP END BEARING  SIZE: 60.00MM;
# 15  TOP END BEARING  SIZE: 60.00MM;
# 16  TOP END BEARING  SIZE: 60.00MM;
# 17  TOP END BEARING  SIZE: 60.00MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch2.csv"
final_df.to_csv(file_path, index = False)

# %%
#BATCH 3_Testing Waters
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #GP338
    {'make': 'Ski-Doo', 'model': 'Citation 4500', 'notes': 'SIZE: 62.00MM;  ', 'years': list(range(1979, 2003))},
    {'make': 'Ski-Doo', 'model': ['Formula Deluxe 380 Fan', 'test2'], 'notes': 'SIZE: 62.00MM;  ', 'years': list(range(1979, 2003))},

    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    # Create an instance of Autodist_temp for the current model
    autodist_template = create_autodist_template(
        make=info['make'],
        model=info['model'],
        year=None,  # 'year' is not used in the template directly
        vendor='',
        vendorcode='',
        position='',
        mpn='09-505-01',
        sku='NB9505',
        pro_type='TOP END BEARING',
        vendornotes=info['notes']
    )
    
    # Create an instance of AutodistGenerator using the template, models, and years
    generator = AutodistGenerator(autodist_template, [info['model']], info['years'])
    
    # Generate autodistribution data
    df = generator.generate_autodist()
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
#print(final_df)
final_df
# Out:
#        Make                            Model  Year Vendor Vendor Code  \
# 0   Ski-Doo                    Citation 4500  1979
# 1   Ski-Doo                    Citation 4500  1980
# 2   Ski-Doo                    Citation 4500  1981
# 3   Ski-Doo                    Citation 4500  1982
# 4   Ski-Doo                    Citation 4500  1983
# 5   Ski-Doo                    Citation 4500  1984
# 6   Ski-Doo                    Citation 4500  1985
# 7   Ski-Doo                    Citation 4500  1986
# 8   Ski-Doo                    Citation 4500  1987
# 9   Ski-Doo                    Citation 4500  1988
# 10  Ski-Doo                    Citation 4500  1989
# 11  Ski-Doo                    Citation 4500  1990
# 12  Ski-Doo                    Citation 4500  1991
# 13  Ski-Doo                    Citation 4500  1992
# 14  Ski-Doo                    Citation 4500  1993
# 15  Ski-Doo                    Citation 4500  1994
# 16  Ski-Doo                    Citation 4500  1995
# 17  Ski-Doo                    Citation 4500  1996
# 18  Ski-Doo                    Citation 4500  1997
# 19  Ski-Doo                    Citation 4500  1998
# 20  Ski-Doo                    Citation 4500  1999
# 21  Ski-Doo                    Citation 4500  2000
# 22  Ski-Doo                    Citation 4500  2001
# 23  Ski-Doo                    Citation 4500  2002
# 24  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1979
# 25  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1980
# 26  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1981
# 27  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1982
# 28  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1983
# 29  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1984
# 30  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1985
# 31  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1986
# 32  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1987
# 33  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1988
# 34  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1989
# 35  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1990
# 36  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1991
# 37  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1992
# 38  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1993
# 39  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1994
# 40  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1995
# 41  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1996
# 42  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1997
# 43  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1998
# 44  Ski-Doo  [Formula Deluxe 380 Fan, test2]  1999
# 45  Ski-Doo  [Formula Deluxe 380 Fan, test2]  2000
# 46  Ski-Doo  [Formula Deluxe 380 Fan, test2]  2001
# 47  Ski-Doo  [Formula Deluxe 380 Fan, test2]  2002
#
#    Position        MPN     SKU     Product Type      Vendor Notes
# 0            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 1            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 2            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 3            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 4            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 5            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 6            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 7            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 8            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 9            09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 10           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 11           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 12           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 13           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 14           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 15           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 16           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 17           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 18           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 19           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 20           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 21           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 22           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 23           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 24           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 25           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 26           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 27           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 28           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 29           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 30           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 31           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 32           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 33           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 34           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 35           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 36           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 37           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 38           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 39           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 40           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 41           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 42           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 43           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 44           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 45           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 46           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 47           09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;

# %%
#Final Batch 3
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Ski-Doo', 'models': ['Citation 4500'], 'notes': 'SIZE: 62.00MM;', 'years': list(range(1979, 2003))},
    #By Multiple Models
    {'make': 'Ski-Doo', 'models': [ 'Formula Deluxe 380 Fan', 
                                    'Formula Deluxe 500', 
                                    'Formula Deluxe 500 Fan', 
                                    'Formula Deluxe 500 LC', 
                                    'Formula Deluxe 583', 
                                    'Formula Deluxe 600', 
                                    'Formula Deluxe 600 GSE', 
                                    'Formula Deluxe 670', 
                                    'Formula Deluxe 700', 
                                    'Formula Deluxe 700 GS', 
                                    'Formula Deluxe 700 GSE', 

                                  ], 'notes': 'SIZE: 62.00MM;', 'years': list(range(1979, 2003))},
    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#         Make                   Model  Year Vendor Vendor Code Position  \
# 0    Ski-Doo           Citation 4500  1979
# 1    Ski-Doo           Citation 4500  1980
# 2    Ski-Doo           Citation 4500  1981
# 3    Ski-Doo           Citation 4500  1982
# 4    Ski-Doo           Citation 4500  1983
# ..       ...                     ...   ...    ...         ...      ...
# 283  Ski-Doo  Formula Deluxe 700 GSE  1998
# 284  Ski-Doo  Formula Deluxe 700 GSE  1999
# 285  Ski-Doo  Formula Deluxe 700 GSE  2000
# 286  Ski-Doo  Formula Deluxe 700 GSE  2001
# 287  Ski-Doo  Formula Deluxe 700 GSE  2002
#
#            MPN     SKU     Product Type    Vendor Notes
# 0    09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 1    09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 2    09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 3    09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 4    09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# ..         ...     ...              ...             ...
# 283  09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 284  09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 285  09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 286  09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
# 287  09-505-01  NB9505  TOP END BEARING  SIZE: 62.00MM;
#
# [288 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch3.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 4
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Ski-Doo', 'models': ['RV 340'], 'notes': 'SIZE: 63.00MM;', 'years': list(range(1976, 1981))},
    #By Multiple Models
  #  {'make': 'Ski-Doo', 'models': [ 'Formula Deluxe 380 Fan', 
   #                                 'Formula Deluxe 500', 
    #                                'Formula Deluxe 500 Fan', 
     #                               'Formula Deluxe 500 LC', 
      #                              'Formula Deluxe 583', 
       #                            'Formula Deluxe 600 GSE', 
        #                            'Formula Deluxe 670', 
         #                           'Formula Deluxe 700', 
          #                          'Formula Deluxe 700 GS', 
           #                         'Formula Deluxe 700 GSE', 

            #                      ], 'notes': 'SIZE: 62.00MM;', 'years': list(range(1979, 2003))},
    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#       Make   Model  Year Vendor Vendor Code Position        MPN     SKU  \
# 0  Ski-Doo  RV 340  1976                              09-505-01  NB9505
# 1  Ski-Doo  RV 340  1977                              09-505-01  NB9505
# 2  Ski-Doo  RV 340  1978                              09-505-01  NB9505
# 3  Ski-Doo  RV 340  1979                              09-505-01  NB9505
# 4  Ski-Doo  RV 340  1980                              09-505-01  NB9505
#
#       Product Type    Vendor Notes
# 0  TOP END BEARING  SIZE: 63.00MM;
# 1  TOP END BEARING  SIZE: 63.00MM;
# 2  TOP END BEARING  SIZE: 63.00MM;
# 3  TOP END BEARING  SIZE: 63.00MM;
# 4  TOP END BEARING  SIZE: 63.00MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch4.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 5
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
   # {'make': 'Ski-Doo', 'models': ['RV 340'], 'notes': 'SIZE: 63.00MM;', 'years': list(range(1976, 1981))},
    #By Multiple Models
    {'make': 'Ski-Doo', 'models': [ 'Alpine 399ER', 
                                    'Alpine 399R', 
                                    'Nordic 399', 
                                    'Nordic 399E', 
                                    'Valmont 399ER', 
                                    'Valmont 399R', 
                                  ], 'notes': 'SIZE: 64.50MM; ', 'years': list(range(1970, 1972))},
    # Add more models as needed
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#        Make          Model  Year Vendor Vendor Code Position        MPN  \
# 0   Ski-Doo   Alpine 399ER  1970                              09-505-01
# 1   Ski-Doo   Alpine 399ER  1971                              09-505-01
# 2   Ski-Doo    Alpine 399R  1970                              09-505-01
# 3   Ski-Doo    Alpine 399R  1971                              09-505-01
# 4   Ski-Doo     Nordic 399  1970                              09-505-01
# 5   Ski-Doo     Nordic 399  1971                              09-505-01
# 6   Ski-Doo    Nordic 399E  1970                              09-505-01
# 7   Ski-Doo    Nordic 399E  1971                              09-505-01
# 8   Ski-Doo  Valmont 399ER  1970                              09-505-01
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
  #{'make': 'Lynx', 'models': ['SS440'], 'notes': 'SIZE: 66.00MM; REF: 2309; OEM: 8K4-11631-01-96', 'years': list(range(1980, 1986))},
    #By Multiple Models
    {'make': 'Yamaha', 'models': ['GP292'





                                  ], 'notes': 'SIZE: 73.00MM; ', 'years': list(range(1972, 1974))},
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#      Make  Model  Year Vendor Vendor Code Position        MPN     SKU  \
# 0  Yamaha  GP292  1972                              09-505-01  NB9505
# 1  Yamaha  GP292  1973                              09-505-01  NB9505
#
#       Product Type     Vendor Notes
# 0  TOP END BEARING  SIZE: 73.00MM;
# 1  TOP END BEARING  SIZE: 73.00MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch19.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 20
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
  #{'make': 'Lynx', 'models': ['SS440'], 'notes': 'SIZE: 66.00MM; REF: 2309; OEM: 8K4-11631-01-96', 'years': list(range(1980, 1986))},
    #By Multiple Models
    {'make': 'Yamaha', 'models': ['MX Z 583'





                                  ], 'notes': 'SIZE: 76.00MM ; REF: 2376; OEM: 420995835 ', 'years': list(range(1998, 1999))},
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#      Make     Model  Year Vendor Vendor Code Position        MPN     SKU  \
# 0  Yamaha  MX Z 583  1998                              09-505-01  NB9505
#
#       Product Type                                Vendor Notes
# 0  TOP END BEARING  SIZE: 76.00MM ; REF: 2376; OEM: 420995835

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch20.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 21
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
  #{'make': 'Lynx', 'models': ['SS440'], 'notes': 'SIZE: 66.00MM; REF: 2309; OEM: 8K4-11631-01-96', 'years': list(range(1980, 1986))},
    #By Multiple Models
    {'make': 'Ski-Doo', 'models': ['Olympique 300', 
                                    'Olympique 300S', 
                                    'Olympique 300T', 
                                    'Alpine 640', 
                                    'Alpine 640ER', 






                                  ], 'notes': 'SIZE: 76.00MM; ', 'years': list(range(1969, 1983))},
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#        Make          Model  Year Vendor Vendor Code Position        MPN  \
# 0   Ski-Doo  Olympique 300  1969                              09-505-01
# 1   Ski-Doo  Olympique 300  1970                              09-505-01
# 2   Ski-Doo  Olympique 300  1971                              09-505-01
# 3   Ski-Doo  Olympique 300  1972                              09-505-01
# 4   Ski-Doo  Olympique 300  1973                              09-505-01
# ..      ...            ...   ...    ...         ...      ...        ...
# 65  Ski-Doo   Alpine 640ER  1978                              09-505-01
# 66  Ski-Doo   Alpine 640ER  1979                              09-505-01
# 67  Ski-Doo   Alpine 640ER  1980                              09-505-01
# 68  Ski-Doo   Alpine 640ER  1981                              09-505-01
# 69  Ski-Doo   Alpine 640ER  1982                              09-505-01
#
#        SKU     Product Type     Vendor Notes
# 0   NB9505  TOP END BEARING  SIZE: 76.00MM;
# 1   NB9505  TOP END BEARING  SIZE: 76.00MM;
# 2   NB9505  TOP END BEARING  SIZE: 76.00MM;
# 3   NB9505  TOP END BEARING  SIZE: 76.00MM;
# 4   NB9505  TOP END BEARING  SIZE: 76.00MM;
# ..     ...              ...              ...
# 65  NB9505  TOP END BEARING  SIZE: 76.00MM;
# 66  NB9505  TOP END BEARING  SIZE: 76.00MM;
# 67  NB9505  TOP END BEARING  SIZE: 76.00MM;
# 68  NB9505  TOP END BEARING  SIZE: 76.00MM;
# 69  NB9505  TOP END BEARING  SIZE: 76.00MM;
#
# [70 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch21.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 22
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
  #{'make': 'Lynx', 'models': ['SS440'], 'notes': 'SIZE: 66.00MM; REF: 2309; OEM: 8K4-11631-01-96', 'years': list(range(1980, 1986))},
    #By Multiple Models
    {'make': 'Ski-Doo', 'models': ['Olympique 335',
                                    'Olympique 335E'







                                  ], 'notes': 'SIZE: 78.00MM; ', 'years': list(range(1969, 1973))},
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-505-01',
            sku='NB9505',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#       Make           Model  Year Vendor Vendor Code Position        MPN  \
# 0  Ski-Doo   Olympique 335  1969                              09-505-01
# 1  Ski-Doo   Olympique 335  1970                              09-505-01
# 2  Ski-Doo   Olympique 335  1971                              09-505-01
# 3  Ski-Doo   Olympique 335  1972                              09-505-01
# 4  Ski-Doo  Olympique 335E  1969                              09-505-01
# 5  Ski-Doo  Olympique 335E  1970                              09-505-01
# 6  Ski-Doo  Olympique 335E  1971                              09-505-01
# 7  Ski-Doo  Olympique 335E  1972                              09-505-01
#
#       SKU     Product Type     Vendor Notes
# 0  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 1  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 2  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 3  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 4  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 5  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 6  NB9505  TOP END BEARING  SIZE: 78.00MM;
# 7  NB9505  TOP END BEARING  SIZE: 78.00MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-505-01batch22.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 1
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
  #{'make': 'Lynx', 'models': ['SS440'], 'notes': 'SIZE: 66.00MM; REF: 2309; OEM: 8K4-11631-01-96', 'years': list(range(1980, 1986))},
    #By Multiple Models
    {'make': 'Yamaha', 'models': ['VX500SX VMAX 500 SX',
                                  'SX500/R'









                                  ], 'notes': 'SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00', 'years': list(range(1999, 2002))},
]

# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-521-1',
            sku='NB9521',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#      Make                Model  Year Vendor Vendor Code Position       MPN  \
# 0  Yamaha  VX500SX VMAX 500 SX  1999                              09-521-1
# 1  Yamaha  VX500SX VMAX 500 SX  2000                              09-521-1
# 2  Yamaha  VX500SX VMAX 500 SX  2001                              09-521-1
# 3  Yamaha              SX500/R  1999                              09-521-1
# 4  Yamaha              SX500/R  2000                              09-521-1
# 5  Yamaha              SX500/R  2001                              09-521-1
#
#       SKU     Product Type                                  Vendor Notes
# 0  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00
# 1  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00
# 2  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00
# 3  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00
# 4  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00
# 5  NB9521  TOP END BEARING  SIZE: 68.00MM ; REF: 2356; OEM: 8CJ-11631-00

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-521-1batch1.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 1
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Yamaha', 'models': ['EC540'], 'notes': 'SIZE: 73.00MM; REF: 2305; OEM: 8R6-11631-00-95', 'years': list(range(1979, 1985))},
    {'make': 'Yamaha', 'models': ['VMX540 VMax'], 'notes': 'SIZE: 73.00MM; REF: 2304; OEM: 8UR-11631-00-94', 'years': list(range(1983, 1992))},
    {'make': 'Yamaha', 'models': ['MM600 Mountain Max 600'], 'notes': 'SIZE: 73.00MM; REF: 2304; OEM: 8UR-11631-00-94', 'years': list(range(1998, 2000))},
    #By Multiple Models
    {'make': 'Yamaha', 'models': ['SRX440'
                                  ], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
      {'make': 'Yamaha', 'models': ['EX570 Exciter', 
                                    'EX570 Exciter II', 
                                    'EX570E Exciter Deluxe', 
                                    'EX570E Exciter II LE', 
                                    'EX570E Exciter LE', 

                                  ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Arctic Cat', 'models': ['Bearcat 550'], 'notes': 'SIZE: 73.40MM; REF: 2338; OEM: 3004-062', 'years': list(range(2000, 2003))},
    {'make': 'Arctic Cat', 'models': ['EXT 580 Z'], 'notes': 'SIZE: 75.40MM; REF: 2348; OEM: 3005-187', 'years': list(range(1993, 1995))},
    
    {'make': 'Arctic Cat', 'models': ['Powder Special 2K', 
                                    'Powder Special 500 EFI', 
                                    'Powder Special 500 EFI LE', 
                                    'Powder Special 600', 
                                    'Powder Special 600 EFI', 
                                    'Powder Special 600 EFI LE', 
                                    'Powder Special 600 LE', 
                                    'Powder Special 700', 
                                    'Powder Special 700 LE', 
                                   ], 'notes': 'SIZE: 78.00MM ; ', 'years': list(range(1998, 2001))},
    
    {'make': 'Arctic Cat', 'models': ['ZRT 800'], 'notes': 'SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738', 'years': list(range(1995, 2002))},
    {'make': 'Arctic Cat', 'models': [
                                    ' Wildcat EFI  ', 
                                    ' Wildcat EFI Mountain Cat  ', 
                                    ' Wildcat Mountain Cat  ', 
 
                                   ], 'notes': 'SIZE: 81.00MM ; ', 'years': list(range(1991, 1997))},
]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-523-1',
            sku='NB9523',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#           Make                        Model  Year Vendor Vendor Code Position  \
# 0   Arctic Cat                  Bearcat 550  2000
# 1   Arctic Cat                  Bearcat 550  2001
# 2   Arctic Cat                  Bearcat 550  2002
# 3   Arctic Cat                    EXT 580 Z  1993
# 4   Arctic Cat                    EXT 580 Z  1994
# 5   Arctic Cat            Powder Special 2K  1998
# 6   Arctic Cat            Powder Special 2K  1999
# 7   Arctic Cat            Powder Special 2K  2000
# 8   Arctic Cat       Powder Special 500 EFI  1998
# 9   Arctic Cat       Powder Special 500 EFI  1999
# 10  Arctic Cat       Powder Special 500 EFI  2000
# 11  Arctic Cat    Powder Special 500 EFI LE  1998
# 12  Arctic Cat    Powder Special 500 EFI LE  1999
# 13  Arctic Cat    Powder Special 500 EFI LE  2000
# 14  Arctic Cat           Powder Special 600  1998
# 15  Arctic Cat           Powder Special 600  1999
# 16  Arctic Cat           Powder Special 600  2000
# 17  Arctic Cat       Powder Special 600 EFI  1998
# 18  Arctic Cat       Powder Special 600 EFI  1999
# 19  Arctic Cat       Powder Special 600 EFI  2000
# 20  Arctic Cat    Powder Special 600 EFI LE  1998
# 21  Arctic Cat    Powder Special 600 EFI LE  1999
# 22  Arctic Cat    Powder Special 600 EFI LE  2000
# 23  Arctic Cat        Powder Special 600 LE  1998
# 24  Arctic Cat        Powder Special 600 LE  1999
# 25  Arctic Cat        Powder Special 600 LE  2000
# 26  Arctic Cat           Powder Special 700  1998
# 27  Arctic Cat           Powder Special 700  1999
# 28  Arctic Cat           Powder Special 700  2000
# 29  Arctic Cat        Powder Special 700 LE  1998
# 30  Arctic Cat        Powder Special 700 LE  1999
# 35  09-523-1  NB9523  TOP END BEARING
# 36  09-523-1  NB9523  TOP END BEARING
# 37  09-523-1  NB9523  TOP END BEARING
# 38  09-523-1  NB9523  TOP END BEARING
# 39  09-523-1  NB9523  TOP END BEARING
# 40  09-523-1  NB9523  TOP END BEARING
# 41  09-523-1  NB9523  TOP END BEARING
# 42  09-523-1  NB9523  TOP END BEARING
# 43  09-523-1  NB9523  TOP END BEARING
# 44  09-523-1  NB9523  TOP END BEARING
# 45  09-523-1  NB9523  TOP END BEARING
# 46  09-523-1  NB9523  TOP END BEARING
# 47  09-523-1  NB9523  TOP END BEARING
# 48  09-523-1  NB9523  TOP END BEARING
# 49  09-523-1  NB9523  TOP END BEARING
# 50  09-523-1  NB9523  TOP END BEARING
# 51  09-523-1  NB9523  TOP END BEARING
# 52  09-523-1  NB9523  TOP END BEARING
# 53  09-523-1  NB9523  TOP END BEARING
# 54  09-523-1  NB9523  TOP END BEARING
# 55  09-523-1  NB9523  TOP END BEARING
# 56  09-523-1  NB9523  TOP END BEARING
#
#                                     Vendor Notes
# 0        SIZE: 73.40MM; REF: 2338; OEM: 3004-062
# 1        SIZE: 73.40MM; REF: 2338; OEM: 3004-062
# 2        SIZE: 73.40MM; REF: 2338; OEM: 3004-062
# 3        SIZE: 75.40MM; REF: 2348; OEM: 3005-187
# 4        SIZE: 75.40MM; REF: 2348; OEM: 3005-187
# 5                               SIZE: 78.00MM ;
# 6                               SIZE: 78.00MM ;
# 7                               SIZE: 78.00MM ;
# 8                               SIZE: 78.00MM ;
# 9                               SIZE: 78.00MM ;
# 10                              SIZE: 78.00MM ;
# 11                              SIZE: 78.00MM ;
# 12                              SIZE: 78.00MM ;
# 13                              SIZE: 78.00MM ;
# 14                              SIZE: 78.00MM ;
# 15                              SIZE: 78.00MM ;
# 16                              SIZE: 78.00MM ;
# 17                              SIZE: 78.00MM ;
# 18                              SIZE: 78.00MM ;
# 19                              SIZE: 78.00MM ;
# 20                              SIZE: 78.00MM ;
# 21                              SIZE: 78.00MM ;
# 22                              SIZE: 78.00MM ;
# 23                              SIZE: 78.00MM ;
# 24                              SIZE: 78.00MM ;
# 25                              SIZE: 78.00MM ;
# 26                              SIZE: 78.00MM ;
# 27                              SIZE: 78.00MM ;
# 28                              SIZE: 78.00MM ;
# 29                              SIZE: 78.00MM ;
# 30                              SIZE: 78.00MM ;
# 31                              SIZE: 78.00MM ;
# 32  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 33  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 34  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 35  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 36  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 37  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 38  SIZE:SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 39                              SIZE: 81.00MM ;
# 40                              SIZE: 81.00MM ;
# 41                              SIZE: 81.00MM ;
# 42                              SIZE: 81.00MM ;
# 43                              SIZE: 81.00MM ;
# 44                              SIZE: 81.00MM ;
# 45                              SIZE: 81.00MM ;
# 46                              SIZE: 81.00MM ;
# 47                              SIZE: 81.00MM ;
# 48                              SIZE: 81.00MM ;
# 49                              SIZE: 81.00MM ;
# 50                              SIZE: 81.00MM ;
# 51                              SIZE: 81.00MM ;
# 52                              SIZE: 81.00MM ;
# 53                              SIZE: 81.00MM ;
# 54                              SIZE: 81.00MM ;
# 55                              SIZE: 81.00MM ;
# 56                              SIZE: 81.00MM ;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-523-1.csv"
final_df.to_csv(file_path, index = False)

# %%
#Batch 1
import pandas as pd  # Ensure pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Ski-Doo', 'models': ['Formula Deluxe 670'], 'notes': 'SIZE: 78.00MM; REF: 2379; OEM: 420887610', 'years': list(range(1999, 2000))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-524-1',
            sku='NB9524',
            pro_type='TOP END BEARING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#       Make               Model  Year Vendor Vendor Code Position       MPN  \
# 0  Ski-Doo  Formula Deluxe 670  1999                              09-524-1
#
#       SKU     Product Type                              Vendor Notes
# 0  NB9524  TOP END BEARING  SIZE: 78.00MM; REF: 2379; OEM: 420887610

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-524-1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #By Individual Model
    {'make': 'Ski-Doo', 'models': ['Formula Deluxe 670'], 'notes': 'SIZE: 66.50MM; ', 'years': list(range(1997, 1999))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-601R',
            sku='9601RS',
            pro_type='PISTON RING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#       Make               Model  Year Vendor Vendor Code Position      MPN  \
# 0  Ski-Doo  Formula Deluxe 670  1997                              09-601R
# 1  Ski-Doo  Formula Deluxe 670  1998                              09-601R
#
#       SKU Product Type     Vendor Notes
# 0  9601RS  PISTON RING  SIZE: 66.50MM;
# 1  9601RS  PISTON RING  SIZE: 66.50MM;

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-601R.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['ZRT 800',
                                      'ZRT 800 LE'], 'notes': 'SIZE: 72.00MM; REF: 2361; OEM: 3004-738 ', 'years': list(range(1995, 2002))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-602N',
            sku='9602PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#           Make       Model  Year Vendor Vendor Code Position      MPN     SKU  \
# 0   Arctic Cat     ZRT 800  1995                              09-602N  9602PS
# 1   Arctic Cat     ZRT 800  1996                              09-602N  9602PS
# 2   Arctic Cat     ZRT 800  1997                              09-602N  9602PS
# 3   Arctic Cat     ZRT 800  1998                              09-602N  9602PS
# 4   Arctic Cat     ZRT 800  1999                              09-602N  9602PS
# 5   Arctic Cat     ZRT 800  2000                              09-602N  9602PS
# 6   Arctic Cat     ZRT 800  2001                              09-602N  9602PS
# 7   Arctic Cat  ZRT 800 LE  1995                              09-602N  9602PS
# 8   Arctic Cat  ZRT 800 LE  1996                              09-602N  9602PS
# 9   Arctic Cat  ZRT 800 LE  1997                              09-602N  9602PS
# 10  Arctic Cat  ZRT 800 LE  1998                              09-602N  9602PS
# 11  Arctic Cat  ZRT 800 LE  1999                              09-602N  9602PS
# 12  Arctic Cat  ZRT 800 LE  2000                              09-602N  9602PS
# 13  Arctic Cat  ZRT 800 LE  2001                              09-602N  9602PS
#
#    Product Type                              Vendor Notes
# 0    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 1    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 2    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 3    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 4    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 5    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 6    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 7    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 8    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 9    PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 10   PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 11   PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 12   PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 13   PISTON KIT  SIZE: 72.00MM; REF: 2361; OEM: 3004-738

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-602N.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['ZRT 800',
                                      'ZRT 800 LE'], 'notes': 'SIZE: 72.00MM; REF: 2361; OEM: 3004-738 ', 'years': list(range(1995, 2002))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-602R',
            sku='9602RS',
            pro_type='PISTON RING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#           Make       Model  Year Vendor Vendor Code Position      MPN     SKU  \
# 0   Arctic Cat     ZRT 800  1995                              09-602R  9602RS
# 1   Arctic Cat     ZRT 800  1996                              09-602R  9602RS
# 2   Arctic Cat     ZRT 800  1997                              09-602R  9602RS
# 3   Arctic Cat     ZRT 800  1998                              09-602R  9602RS
# 4   Arctic Cat     ZRT 800  1999                              09-602R  9602RS
# 5   Arctic Cat     ZRT 800  2000                              09-602R  9602RS
# 6   Arctic Cat     ZRT 800  2001                              09-602R  9602RS
# 7   Arctic Cat  ZRT 800 LE  1995                              09-602R  9602RS
# 8   Arctic Cat  ZRT 800 LE  1996                              09-602R  9602RS
# 9   Arctic Cat  ZRT 800 LE  1997                              09-602R  9602RS
# 10  Arctic Cat  ZRT 800 LE  1998                              09-602R  9602RS
# 11  Arctic Cat  ZRT 800 LE  1999                              09-602R  9602RS
# 12  Arctic Cat  ZRT 800 LE  2000                              09-602R  9602RS
# 13  Arctic Cat  ZRT 800 LE  2001                              09-602R  9602RS
#
#    Product Type                              Vendor Notes
# 0   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 1   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 2   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 3   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 4   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 5   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 6   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 7   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 8   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 9   PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 10  PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 11  PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 12  PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738
# 13  PISTON RING  SIZE: 72.00MM; REF: 2361; OEM: 3004-738

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-602R.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Panther 370',
                                      'Z 370',
                                      'Z 370 ES',
                                     ], 'notes': 'SIZE: 60.00MM;  OEM: 3005-913', 'years': list(range(2001, 2002))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-603',
            sku='9603PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make        Model  Year Vendor Vendor Code Position     MPN     SKU  \
# 0  Arctic Cat  Panther 370  2001                              09-603  9603PS
# 1  Arctic Cat        Z 370  2001                              09-603  9603PS
# 2  Arctic Cat     Z 370 ES  2001                              09-603  9603PS
#
#   Product Type                   Vendor Notes
# 0   PISTON KIT  SIZE: 60.00MM;  OEM: 3005-913
# 1   PISTON KIT  SIZE: 60.00MM;  OEM: 3005-913
# 2   PISTON KIT  SIZE: 60.00MM;  OEM: 3005-913

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-603.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 500 EFI',
                                      'Mountain Cat 500',
                                     ], 'notes': 'SIZE: 71.00MM;  OEM: 3005-815', 'years': list(range(2001, 2003))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-605',
            sku='9605PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                 Model  Year Vendor Vendor Code Position     MPN  \
# 0  Arctic Cat  Mountain Cat 500 EFI  2001                              09-605
# 1  Arctic Cat  Mountain Cat 500 EFI  2002                              09-605
# 2  Arctic Cat      Mountain Cat 500  2001                              09-605
# 3  Arctic Cat      Mountain Cat 500  2002                              09-605
#
#       SKU Product Type                   Vendor Notes
# 0  9605PS   PISTON KIT  SIZE: 71.00MM;  OEM: 3005-815
# 1  9605PS   PISTON KIT  SIZE: 71.00MM;  OEM: 3005-815
# 2  9605PS   PISTON KIT  SIZE: 71.00MM;  OEM: 3005-815
# 3  9605PS   PISTON KIT  SIZE: 71.00MM;  OEM: 3005-815

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-605.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 600 EFI',
                                      'Mountain Cat 600 EFI LE',
                                      'Mountain Cat 600 VEV'
                                     ], 'notes': 'SIZE: 78.00MM; REF: 2427; OEM: 3005-748', 'years': list(range(2001, 2002))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-609',
            sku='9609PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                    Model  Year Vendor Vendor Code Position  \
# 0  Arctic Cat     Mountain Cat 600 EFI  2001
# 1  Arctic Cat  Mountain Cat 600 EFI LE  2001
# 2  Arctic Cat     Mountain Cat 600 VEV  2001
#
#       MPN     SKU Product Type                             Vendor Notes
# 0  09-609  9609PS   PISTON KIT  SIZE: 78.00MM; REF: 2427; OEM: 3005-748
# 1  09-609  9609PS   PISTON KIT  SIZE: 78.00MM; REF: 2427; OEM: 3005-748
# 2  09-609  9609PS   PISTON KIT  SIZE: 78.00MM; REF: 2427; OEM: 3005-748

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-609.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 600 EFI',
                                      'Mountain Cat 600 EFI LE',
                                      'Mountain Cat 600 VEV'
                                     ], 'notes': 'SIZE: 78.00MM; REF: 2427; OEM: 3005-748', 'years': list(range(2001, 2002))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-609R',
            sku='9609RS',
            pro_type='PISTON RING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                    Model  Year Vendor Vendor Code Position  \
# 0  Arctic Cat     Mountain Cat 600 EFI  2001
# 1  Arctic Cat  Mountain Cat 600 EFI LE  2001
# 2  Arctic Cat     Mountain Cat 600 VEV  2001
#
#        MPN     SKU Product Type                             Vendor Notes
# 0  09-609R  9609RS  PISTON RING  SIZE: 78.00MM; REF: 2427; OEM: 3005-748
# 1  09-609R  9609RS  PISTON RING  SIZE: 78.00MM; REF: 2427; OEM: 3005-748
# 2  09-609R  9609RS  PISTON RING  SIZE: 78.00MM; REF: 2427; OEM: 3005-748

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-609R.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 800 EFI 151',
                                      'Mountain Cat 800 EFI 159',
                                    
                                     ], 'notes': 'SIZE: 81.00MM; REF: 2431; OEM: 3006-029', 'years': list(range(2004, 2005))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-611',
            sku='9611PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                     Model  Year Vendor Vendor Code Position  \
# 0  Arctic Cat  Mountain Cat 800 EFI 151  2004
# 1  Arctic Cat  Mountain Cat 800 EFI 159  2004
#
#       MPN     SKU Product Type                             Vendor Notes
# 0  09-611  9611PS   PISTON KIT  SIZE: 81.00MM; REF: 2431; OEM: 3006-029
# 1  09-611  9611PS   PISTON KIT  SIZE: 81.00MM; REF: 2431; OEM: 3006-029

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-611.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 800 EFI 151',
                                      'Mountain Cat 800 EFI 159',
                                    
                                     ], 'notes': 'SIZE: 81.00MM; REF: 2431; OEM: 3006-029', 'years': list(range(2004, 2005))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-611R',
            sku='9611RS',
            pro_type='PISTON RING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                     Model  Year Vendor Vendor Code Position  \
# 0  Arctic Cat  Mountain Cat 800 EFI 151  2004
# 1  Arctic Cat  Mountain Cat 800 EFI 159  2004
#
#        MPN     SKU Product Type                             Vendor Notes
# 0  09-611R  9611RS  PISTON RING  SIZE: 81.00MM; REF: 2431; OEM: 3006-029
# 1  09-611R  9611RS  PISTON RING  SIZE: 81.00MM; REF: 2431; OEM: 3006-029

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-611R.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 1000',
                                                                         
                                     ], 'notes': 'SIZE: 81.00MM; REF: 2394; OEM: 3005-220', 'years': list(range(1998, 2003))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-612',
            sku='9612PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make              Model  Year Vendor Vendor Code Position     MPN  \
# 0  Arctic Cat  Mountain Cat 1000  1998                              09-612
# 1  Arctic Cat  Mountain Cat 1000  1999                              09-612
# 2  Arctic Cat  Mountain Cat 1000  2000                              09-612
# 3  Arctic Cat  Mountain Cat 1000  2001                              09-612
# 4  Arctic Cat  Mountain Cat 1000  2002                              09-612
#
#       SKU Product Type                             Vendor Notes
# 0  9612PS   PISTON KIT  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 1  9612PS   PISTON KIT  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 2  9612PS   PISTON KIT  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 3  9612PS   PISTON KIT  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 4  9612PS   PISTON KIT  SIZE: 81.00MM; REF: 2394; OEM: 3005-220

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-612.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Mountain Cat 1000',
                                                                         
                                     ], 'notes': 'SIZE: 81.00MM; REF: 2394; OEM: 3005-220', 'years': list(range(1998, 2003))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-612R',
            sku='9612RS',
            pro_type='PISTON RING',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make              Model  Year Vendor Vendor Code Position      MPN  \
# 0  Arctic Cat  Mountain Cat 1000  1998                              09-612R
# 1  Arctic Cat  Mountain Cat 1000  1999                              09-612R
# 2  Arctic Cat  Mountain Cat 1000  2000                              09-612R
# 3  Arctic Cat  Mountain Cat 1000  2001                              09-612R
# 4  Arctic Cat  Mountain Cat 1000  2002                              09-612R
#
#       SKU Product Type                             Vendor Notes
# 0  9612RS  PISTON RING  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 1  9612RS  PISTON RING  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 2  9612RS  PISTON RING  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 3  9612RS  PISTON RING  SIZE: 81.00MM; REF: 2394; OEM: 3005-220
# 4  9612RS  PISTON RING  SIZE: 81.00MM; REF: 2394; OEM: 3005-220

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-612R.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Powder Special 500 EFI',
                                      'Powder Special 500 EFI LE'
                                                                         
                                     ], 'notes': 'SIZE: 71.00MM; REF: 2393; OEM: 3005-250', 'years': list(range(1999, 2001))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-679',
            sku='9679PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
# Out:
#          Make                      Model  Year Vendor Vendor Code Position  \
# 0  Arctic Cat     Powder Special 500 EFI  1999
# 1  Arctic Cat     Powder Special 500 EFI  2000
# 2  Arctic Cat  Powder Special 500 EFI LE  1999
# 3  Arctic Cat  Powder Special 500 EFI LE  2000
#
#       MPN     SKU Product Type                             Vendor Notes
# 0  09-679  9679PS   PISTON KIT  SIZE: 71.00MM; REF: 2393; OEM: 3005-250
# 1  09-679  9679PS   PISTON KIT  SIZE: 71.00MM; REF: 2393; OEM: 3005-250
# 2  09-679  9679PS   PISTON KIT  SIZE: 71.00MM; REF: 2393; OEM: 3005-250
# 3  09-679  9679PS   PISTON KIT  SIZE: 71.00MM; REF: 2393; OEM: 3005-250

# %%
file_path = r"C:\Users\User\Desktop\nachmann\(01)SECTION 09 - PISTONS ( 07-03-23 ) (1) (1)\Merge\09-679.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd  # Ensuring that pandas is imported

# Define a function to create autodistribution templates for each model
def create_autodist_template(make, model, year, vendor, vendorcode, position, mpn, sku, pro_type, vendornotes):
    return Autodist_temp(
        make=make,
        model=model,
        year=year,
        vendor=vendor,
        vendorcode=vendorcode,
        position=position,
        mpn=mpn,
        sku=sku,
        pro_type=pro_type,
        vendornotes=vendornotes
    )

# List of specific models with their notes and years
model_info = [
    #D
    {'make': 'Arctic Cat', 'models': ['Powder Special 500 EFI',
                                      'Powder Special 500 EFI LE'
                                                                         
                                     ], 'notes': 'SIZE: 71.00MM; REF: 2393; OEM: 3005-250', 'years': list(range(1999, 2001))},
   ]
    
    #####By Single Models
    #{'make': 'Yamaha', 'models': ['SRX440'], 'notes': 'SIZE: 68.50MM; ', 'years': list(range(1978, 1981))},
    #By Multiple Models
    #{'make': 'Yamaha', 'models': ['EX570 Exciter', 
    #                                'EX570 Exciter II', 
     #                               'EX570E Exciter Deluxe', 
      #                              'EX570E Exciter II LE', 
       #                             'EX570E Exciter LE', 

        #                          ], 'notes': 'SIZE: 73.00MM; REF: 2335; OEM: 82M-11631-09-92', 'years': list(range(1987, 1991))},


# Create a list to store generated DataFrames
dfs = []

# Loop through each model and generate autodistribution data
for info in model_info:
    for model in info['models']:
        # Create an instance of Autodist_temp for the current model
        autodist_template = create_autodist_template(
            make=info['make'],
            model=model,
            year=None,  # 'year' is not used in the template directly
            vendor='',
            vendorcode='',
            position='',
            mpn='09-679',
            sku='9679PS',
            pro_type='PISTON KIT',
            vendornotes=info['notes']
        )
        
        # Create an instance of AutodistGenerator using the template, models, and years
        generator = AutodistGenerator(autodist_template, [model], info['years'])
        
        # Generate autodistribution data
        df = generator.generate_autodist()
        
        # Append the DataFrame to the list
        dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Print or display the generated DataFrame
final_df
